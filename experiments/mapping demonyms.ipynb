# %% [markdown]
# # mapping demonyms

# %%
import pandas as pd
import re
import string

def split_list_string(l: list):
    """
    Splits string separated by either commas or semicolons into a lowercase list.
    """

    return [
        re.sub(r"\?():", "", x.strip().lower())
        for x in str(l).replace(";", ",").replace("?", "").replace("/", ",").split(",")
        if x.strip() != ""
    ]

# %%
df = pd.read_pickle("../GITIGNORE_DATA/filtering_people_orgs_result.pkl")
nationalities = list(set(df.NATIONALITY.apply(split_list_string).sum()))

len(nationalities), nationalities[0:10]
# Out:
# (243,
#  ['argentinian',
#   'scotland',
#   'tasmanian',
#   'babylonian',
#   'zulu',
#   'kenya',
#   'nigerian',
#   'syrian',
#   'japanese',
#   'indian'])

# %%
demonym_mapping = pd.read_csv("https://raw.githubusercontent.com/knowitall/chunkedextractor/master/src/main/resources/edu/knowitall/chunkedextractor/demonyms.csv", header=None, names=['people', 'country'])
demonym_mapping = demonym_mapping.applymap(lambda i: str(i).lower())
demonym_mapping
# Out:
#             people   country
# 0     aalborgenser   aalborg
# 1       aberdonian  aberdeen
# 2           abkhaz  abkhazia
# 3        abkhazian  abkhazia
# 4         abrenian      abra
# ...            ...       ...
# 2139    zimbabwean  zimbabwe
# 2140       zintani    zintan
# 2141          zulu  zululand
# 2142      zuricher    zurich
# 2143     ecuadoran   ecuador
#
# [2144 rows x 2 columns]

# %%
failed = []

def country_from_nationality(n):
    if n in demonym_mapping.country.tolist():
        return n
    elif n in demonym_mapping.people.tolist():
        return demonym_mapping.loc[demonym_mapping['people'] == n, 'country'].values.tolist()[0]
    else:
        failed.append(n)
        return None
    
demonym_dict = {n: country_from_nationality(n) for n in nationalities}

# %%
import sys
sys.path.append("..")

from heritageconnector.entity_matching.lookup import DenonymConverter

# %%
dc = DenonymConverter()
{n: dc.get_country_from_nationality(n) for n in nationalities}
# Out:
# {'argentinian': 'argentina',
#  'scotland': 'scotland',
#  'tasmanian': 'tasmania',
#  'babylonian': 'babylonia',
#  'zulu': 'zululand',
#  'kenya': 'kenya',
#  'nigerian': 'nigeria',
#  'syrian': 'syria',
#  'japanese': 'japan',
#  'indian': 'india',
#  'jamaican': 'jamaica',
#  'hong kongese': None,
#  'northern irish': 'northern ireland',
#  'belarusian': 'belarus',
#  'nepalese': None,
#  'hindustani': None,
#  'german ()': None,
#  'european': 'europe',
#  'austria': 'austria',
#  'iraqi': 'iraq',
#  'andorran': 'andorra',
#  'japan': 'japan',
#  'jerseyan': 'jersey',
#  'brazilian': 'brazil',
#  'fuegian': None,
#  'irish': 'ireland',
#  'french': 'france',
#  'bavarian': 'bavaria',
#  'australian-born': None,
#  'britain': 'britain',
#  'tanzanian': 'tanzania',
#  'wesh': None,
#  'breton': 'brittany',
#  'ritish': None,
#  'netherlands': 'netherlands',
#  'briton': 'britain',
#  'austrian-american': None,
#  'multinational': None,
#  'german & polish': None,
#  'bechuanan': None,
#  'englsih': None,
#  'greek': 'greece',
#  'norman': 'normandy',
#  'macedonian': 'macedonia',
#  'hungarian': 'hungary',
#  'martiniquais': 'martinique',
#  'canadian-american': None,
#  'tunisian': 'tunisia',
#  'enlgish': None,
#  'alsacian': None,
#  'italian-american': None,
#  'british': 'united kingdom',
#  'roman': 'rome',
#  'swedish': 'sweden',
#  'germany': 'germany',
#  'anglo-german': None,
#  'malasyian': None,
#  'wales': 'wales',
#  'hong kong': 'hong kong',
#  '`british': None,
#  'german-american': None,
#  'egyptian': 'egypt',
#  'scottish': 'scotland',
#  'south american': 'south america',
#  'indian (mughal empire)': None,
#  'dutch boer': None,
#  'north american': 'north america',
#  'bolivian': 'bolivia',
#  'hellenic': 'greece',
#  'sbritish': None,
#  'savoyard': 'savoy',
#  'zimbabwean': 'zimbabwe',
#  'rhodesian': 'rhodesia',
#  'united kingdom': 'united kingdom',
#  '(portugeuse)': None,
#  'chines': None,
#  'latvian': 'latvia',
#  'international': None,
#  'london': 'london',
#  'danish': 'denmark',
#  'filipino': 'philippines',
#  'nan': None,
#  'german & france': None,
#  'british guianan': None,
#  'bajan': 'barbados',
#  'australian': 'australia',
#  'byzantine': 'byzantium',
#  'swazi': 'swaziland',
#  'anglo-italian': None,
#  'iranian': 'iran',
#  'flemish': 'flanders',
#  'spanish': 'spain',
#  'english': 'england',
#  'arabian': None,
#  'sicilian': 'sicily',
#  'german born': None,
#  'scottish-jamaican': None,
#  'german': 'germany',
#  'ottoman turkish': None,
#  'greco-roman': None,
#  'scandinavian': 'scandinavia',
#  'venetian': 'venice',
#  'iraq': 'iraq',
#  'cuban': 'cuba',
#  'fijian': 'fiji',
#  'american and german': None,
#  'andamanese': 'andaman and nicobar islands',
#  'belgian': 'belgium',
#  'croatian': 'croatia',
#  'peruvian': 'peru',
#  'austro-hungarian': 'austria–hungary',
#  'german-chilean': None,
#  'polish': 'poland',
#  'etruscan': 'etruria',
#  'finnish': 'finland',
#  'englisg': None,
#  'arab': 'haugesund',
#  'mozambican': 'mozambique',
#  'american': 'united states',
#  'bermudian': 'bermuda',
#  'america': None,
#  'bulgarian': 'bulgaria',
#  'anglo-american': None,
#  'chaldean': None,
#  'walloon': 'wallonia',
#  'russia': 'russia',
#  'african': 'africa',
#  'mughal': None,
#  'british (german)': None,
#  'south korean': 'south korea',
#  'armenian-american': None,
#  'berkshire': None,
#  'sri lankan': 'sri lanka',
#  'scotish': None,
#  'scots-irish': None,
#  'omani': 'oman',
#  'finish': None,
#  'assyrian': None,
#  'czech': 'czech republic',
#  'ghanaian': 'ghana',
#  'austrialian': None,
#  'ancient greek': None,
#  'american born': None,
#  'jewish': None,
#  'ancient egyptian': None,
#  'asian': 'asia',
#  'german french': None,
#  'chilean': 'chile',
#  'guernésiais': None,
#  'malaysian peninsular': None,
#  'india': 'india',
#  'manx': None,
#  'australian aboriginal': None,
#  'french-born': None,
#  'chinese': 'china',
#  'serbian': 'serbia',
#  'swedish corporation with british subsiduary': None,
#  'monegasque': None,
#  'swiss': 'switzerland',
#  'britsih': None,
#  'portugese': None,
#  'lithuanian': 'lithuania',
#  'mesopotamian': 'mesopotamia',
#  'medallist': None,
#  'england': 'england',
#  'british (english)': None,
#  'irish-american': None,
#  'norweigian': None,
#  'javanese': 'java',
#  'italian': 'italy',
#  'slovenian': 'slovenia',
#  'unknown': None,
#  'english: british': None,
#  'new zealand': 'new zealand',
#  'uk': 'united kingdom',
#  'a': None,
#  'franco-american': None,
#  'switzerland': 'switzerland',
#  'new zealander': 'new zealand',
#  'south african': 'south africa',
#  'iraq-born': None,
#  'colombian': 'colombia',
#  'georgian': 'georgia',
#  'american-canadian': None,
#  'norwegian': 'norway',
#  'prussian': 'prussia',
#  'malaysian': 'malaysia',
#  'czechoslovakian': 'czechoslovakia',
#  'sudanese': 'sudan',
#  'canadian': 'canada',
#  'persian': 'persia',
#  'cook islander': 'cook islands',
#  'bengali': 'bengal',
#  'itaian': None,
#  'american indian': None,
#  'venezuelan': 'venezuela',
#  'swiss-born': None,
#  'maltese': 'malta',
#  'uganda': 'uganda',
#  'portugeuse': None,
#  'bohemian': 'bohemia',
#  'estonian': 'estonia',
#  'france': 'france',
#  'russian-american': None,
#  'dutch': 'netherlands',
#  'pakistani': 'pakistan',
#  'anglo-irish': None,
#  'native american': None,
#  'zambian': 'zambia',
#  'turkish': 'turkey',
#  'amercian': None,
#  'austrian': 'austria',
#  'global operation': None,
#  'canarian': 'canary islands',
#  'ukranian': None,
#  'austrian-born': None,
#  'cypriot': 'cyprus',
#  'scottish (german)': None,
#  'french-american': None,
#  'portuguese': 'portugal',
#  'angolan': 'angola',
#  'anglo-dutch': None,
#  'romanian': 'romania',
#  'thai': 'thailand',
#  'germna': None,
#  'ukrainian': 'ukraine',
#  'russian': 'russia',
#  'trinidadian': 'trinidad and tobago',
#  'bermudan': 'bermuda',
#  'arabic': None,
#  'burmese': 'burma',
#  'taiwanese': 'taiwan',
#  'fench': None,
#  'welsh': 'wales',
#  'armenian': 'armenia',
#  'burgundian': 'burgundy',
#  'anglo-french': None,
#  'belgium': 'belgium',
#  'chuvash': None,
#  'israeli': 'israel',
#  'kenyan': 'kenya',
#  'autrian': None,
#  'west-indian': None}

# %%
def flatten_list_of_lists(l: list) -> list:
    """
    [[1, 2], [3]] -> [1, 2, 3]
    """
    
    res = []
    
    for item in l:
        if isinstance(item, list):
            res = res + item
        else:
            res.append(item)
            
    return res

# %%
flatten_list_of_lists(['abc'])
# Out:
# ['abc']
