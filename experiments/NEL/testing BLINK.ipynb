# %%
# %load_ext autoreload
# %autoreload 2

# es
import sys
sys.path.append("../..")
from heritageconnector import datastore
from heritageconnector.nlp.nel import BLINKServiceWrapper
from elasticsearch import helpers
from itertools import islice

# blink
import requests, json
import time

endpoint = "http://54.195.144.9:8000/blink/multiple"
headers = {
  'Content-Type': 'application/json'
}

# this is the number of unlinked entity mentions in all categories except for DATE, LANGUAGE and NORP
# as of 15.04.21 (using en_core_web_lg model)
no_unlinked_mentions = 462921
# Out:
# 2021-04-16 14:27:45,199 - heritageconnector.datastore - DEBUG - Connected to Elasticsearch cluster at https://c4241473f2f84e2ab15c5b7c81eb34a4.eu-west-1.aws.found.io:9243/

# %% [markdown]
# ## 1. Load unlinked entity mentions from Elasticsearch

# %%
entity_fields = [
    "graph.@hc:entityPERSON.@value", 
    "graph.@hc:entityORG.@value", 
    #"graph.@hc:entityDATE.@value", 
    "graph.@hc:entityLOC.@value", 
    #"graph.@hc:entityLANGUAGE.@value", 
    "graph.@hc:entityFAC.@value", 
    #"graph.@hc:entityNORP.@value", 
    "graph.@hc:entityOBJECT.@value"
]

fields_exist = [{"exists": {"field": field}} for field in entity_fields]

es_query = {
    "query": {
        "bool": {
            "should": fields_exist
        }
    }
}


doc_generator = helpers.scan(
            client=datastore.es,
            index='heritageconnector',
            query=es_query,
            preserve_order=True,
        )

# %%
def get_lookup_expressions_from_doc(doc, field_names):
    """Get descriptions with [[entities highlighted]] from an elasticsearch document and list of field names, representing the allowed entity types"""
    
    if 'graph' in field_names[0]:
        field_names = [i[6:-7] for i in field_names]
    
    # get description and entity mentions
    uri = doc['_id']
    description = doc['_source']['data']['http://www.w3.org/2001/XMLSchema#description']
    ent_mentions = []
    
    for field_name in field_names:
        field_val = doc['_source']['graph'][field_name]
        
        if isinstance(field_val, dict):
            ent_mentions.append((field_val['@value'], field_name))
        elif isinstance(field_val, list):
            ent_mentions += [(v['@value'], field_name) for v in field_val]
            
    # create modified descriptions with each mention [[highlighted]].
    # only the first mention is highlighted, if the entity mention occurs more than once in the description
    mod_descriptions = []
    
    for mention, label in ent_mentions:
        mod_desc = description.replace(mention, f"[[{mention}]]", 1)
        uid = uri# + "___" + mention.lower()
        mod_descriptions.append({"id": uid, "text": mod_desc, "metadata": {"mention": mention, "label": label}})
            
    return mod_descriptions

doc = next(doc_generator)
get_lookup_expressions_from_doc(doc, entity_fields)
# Out:
# [{'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co422089',
#   'text': 'Notice. British Railways (Southern Region). Suspension of trains between Waterloo and Clapham Junction on the Hounslow (via Brentford Central or Richmond), Shepperton and Teddington (via Richmond) and Windsor and [[Weybridge]] (via Richmond) routes due to engineering works, 5 May 1957. Green text on white background. BR (SR) ref: AD7407/B1-1/4/9457. Printed by The Baynard Press. Format: double royal. Dimensions: 40 x 25 inches, 1016 x 635mm.',
#   'metadata': {'mention': 'Weybridge', 'label': '@hc:entityPERSON'}},
#  {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co422089',
#   'text': 'Notice. British Railways (Southern Region). Suspension of trains between Waterloo and Clapham Junction on the Hounslow (via [[Brentford Central]] or Richmond), Shepperton and Teddington (via Richmond) and Windsor and Weybridge (via Richmond) routes due to engineering works, 5 May 1957. Green text on white background. BR (SR) ref: AD7407/B1-1/4/9457. Printed by The Baynard Press. Format: double royal. Dimensions: 40 x 25 inches, 1016 x 635mm.',
#   'metadata': {'mention': 'Brentford Central', 'label': '@hc:entityORG'}},
#  {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co422089',
#   'text': 'Notice. British Railways (Southern Region). Suspension of trains between Waterloo and Clapham Junction on the [[Hounslow]] (via Brentford Central or Richmond), Shepperton and Teddington (via Richmond) and Windsor and Weybridge (via Richmond) routes due to engineering works, 5 May 1957. Green text on white background. BR (SR) ref: AD7407/B1-1/4/9457. Printed by The Baynard Press. Format: double royal. Dimensions: 40 x 25 inches, 1016 x 635mm.',
#   'metadata': {'mention': 'Hounslow', 'label': '@hc:entityLOC'}},
#  {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co422089',
#   'text': 'Notice. British Railways (Southern Region). Suspension of trains between [[Waterloo]] and Clapham Junction on the Hounslow (via Brentford Central or Richmond), Shepperton and Teddington (via Richmond) and Windsor and Weybridge (via Richmond) routes due to engineering works, 5 May 1957. Green text on white background. BR (SR) ref: AD7407/B1-1/4/9457. Printed by The Baynard Press. Format: double royal. Dimensions: 40 x 25 inches, 1016 x 635mm.',
#   'metadata': {'mention': 'Waterloo', 'label': '@hc:entityLOC'}},
#  {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co422089',
#   'text': 'Notice. British Railways (Southern Region). Suspension of trains between Waterloo and Clapham Junction on the Hounslow (via Brentford Central or Richmond), Shepperton and [[Teddington]] (via Richmond) and Windsor and Weybridge (via Richmond) routes due to engineering works, 5 May 1957. Green text on white background. BR (SR) ref: AD7407/B1-1/4/9457. Printed by The Baynard Press. Format: double royal. Dimensions: 40 x 25 inches, 1016 x 635mm.',
#   'metadata': {'mention': 'Teddington', 'label': '@hc:entityLOC'}},
#  {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co422089',
#   'text': 'Notice. British Railways (Southern Region). Suspension of trains between Waterloo and Clapham Junction on the Hounslow (via Brentford Central or Richmond), [[Shepperton]] and Teddington (via Richmond) and Windsor and Weybridge (via Richmond) routes due to engineering works, 5 May 1957. Green text on white background. BR (SR) ref: AD7407/B1-1/4/9457. Printed by The Baynard Press. Format: double royal. Dimensions: 40 x 25 inches, 1016 x 635mm.',
#   'metadata': {'mention': 'Shepperton', 'label': '@hc:entityLOC'}},
#  {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co422089',
#   'text': 'Notice. British Railways (Southern Region). Suspension of trains between Waterloo and Clapham Junction on the Hounslow (via Brentford Central or [[Richmond]]), Shepperton and Teddington (via Richmond) and Windsor and Weybridge (via Richmond) routes due to engineering works, 5 May 1957. Green text on white background. BR (SR) ref: AD7407/B1-1/4/9457. Printed by The Baynard Press. Format: double royal. Dimensions: 40 x 25 inches, 1016 x 635mm.',
#   'metadata': {'mention': 'Richmond', 'label': '@hc:entityLOC'}},
#  {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co422089',
#   'text': 'Notice. British Railways (Southern Region). Suspension of trains between Waterloo and [[Clapham Junction]] on the Hounslow (via Brentford Central or Richmond), Shepperton and Teddington (via Richmond) and Windsor and Weybridge (via Richmond) routes due to engineering works, 5 May 1957. Green text on white background. BR (SR) ref: AD7407/B1-1/4/9457. Printed by The Baynard Press. Format: double royal. Dimensions: 40 x 25 inches, 1016 x 635mm.',
#   'metadata': {'mention': 'Clapham Junction', 'label': '@hc:entityFAC'}},
#  {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co422089',
#   'text': 'Notice. British Railways (Southern Region). Suspension of trains between Waterloo and Clapham Junction on the Hounslow (via Brentford Central or Richmond), Shepperton and Teddington (via Richmond) and Windsor and Weybridge (via Richmond) routes due to engineering works, 5 May 1957. Green text on white background. BR (SR) ref: [[AD7407]]/B1-1/4/9457. Printed by The Baynard Press. Format: double royal. Dimensions: 40 x 25 inches, 1016 x 635mm.',
#   'metadata': {'mention': 'AD7407', 'label': '@hc:entityOBJECT'}}]

# %% [markdown]
# ## 2. Query these mentions against BLINK
# - how good are the links?
# - how fast is it?

# %%
def make_blink_request(query: dict):
    request_len = len(query['items'])
    start = time.time()
    response_json = requests.request("POST", endpoint, headers=headers, data=json.dumps(query)).json()
    end = time.time()
    response_time = end-start
    response_rate = response_time/request_len
    
    time_wholecorpus = response_rate*no_unlinked_mentions
    
    print(f"{request_len} items processed in {round(response_time, 1)} seconds ({response_rate} seconds/item)")
    print(f"Predicted time to attempt to link all mentions: {int(time_wholecorpus)} seconds = {round(time_wholecorpus/3600, 1)} hours")
    return response_json

# %%
blink_service = BLINKServiceWrapper(
    endpoint,
    description_field = "data.http://www.w3.org/2001/XMLSchema#description", 
    entity_fields = entity_fields, 
)

# %%
no_docs = 10

items = []

for doc in islice(doc_generator, no_docs):
    items += get_lookup_expressions_from_doc(doc, entity_fields)

# %%
query = {
    "items": items,
    "threshold": 0.8,
}

# %%
blink_service.make_blink_request(query)
# Out:
# 2021-04-16 13:40:09,252 - heritageconnector.nlp.nel - INFO - 123 items processed in 70.5 seconds (0.5731584638114867 seconds/item)
# {'items': [{'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co226701',
#    'metadata': {'mention': 'Yorks', 'label': '@hc:entityPERSON'},
#    'text': 'Print. \'The New Elizabethan Era\' by Michael Turner. Mounted in folder  with accompanying text. A4 4-6-2 no 60022 Mallard hauling The Elizabethan passenger train in the cutting between Copenhagen  and Gasworks tunnels approaching Kings Cross. Other steam- hauled trains in the picture and carriages of another train passing out of view on overhead bridge. Factory chimney "Ebonite" in background. Published by Michael Benn & Associates   Ltd, Wetherby, [[Yorks]]. 255 x 310mm. Copyright: Michael Turner.  10 x 12.2047 in.',
#    'links': [{'title': 'Yorkshire',
#      'url': 'https://en.wikipedia.org/wiki/Yorkshire',
#      'score': 0.999674916267395,
#      'qid': 'Q163'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co226701',
#    'metadata': {'mention': 'Kings Cross', 'label': '@hc:entityORG'},
#    'text': 'Print. \'The New Elizabethan Era\' by Michael Turner. Mounted in folder  with accompanying text. A4 4-6-2 no 60022 Mallard hauling The Elizabethan passenger train in the cutting between Copenhagen  and Gasworks tunnels approaching [[Kings Cross]]. Other steam- hauled trains in the picture and carriages of another train passing out of view on overhead bridge. Factory chimney "Ebonite" in background. Published by Michael Benn & Associates   Ltd, Wetherby, Yorks. 255 x 310mm. Copyright: Michael Turner.  10 x 12.2047 in.',
#    'links': []},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co226701',
#    'metadata': {'mention': 'Wetherby', 'label': '@hc:entityLOC'},
#    'text': 'Print. \'The New Elizabethan Era\' by Michael Turner. Mounted in folder  with accompanying text. A4 4-6-2 no 60022 Mallard hauling The Elizabethan passenger train in the cutting between Copenhagen  and Gasworks tunnels approaching Kings Cross. Other steam- hauled trains in the picture and carriages of another train passing out of view on overhead bridge. Factory chimney "Ebonite" in background. Published by Michael Benn & Associates   Ltd, [[Wetherby]], Yorks. 255 x 310mm. Copyright: Michael Turner.  10 x 12.2047 in.',
#    'links': [{'title': 'Wetherby',
#      'url': 'https://en.wikipedia.org/wiki/Wetherby',
#      'score': 1.0,
#      'qid': 'Q817481'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co226701',
#    'metadata': {'mention': 'Copenhagen', 'label': '@hc:entityLOC'},
#    'text': 'Print. \'The New Elizabethan Era\' by Michael Turner. Mounted in folder  with accompanying text. A4 4-6-2 no 60022 Mallard hauling The Elizabethan passenger train in the cutting between [[Copenhagen]]  and Gasworks tunnels approaching Kings Cross. Other steam- hauled trains in the picture and carriages of another train passing out of view on overhead bridge. Factory chimney "Ebonite" in background. Published by Michael Benn & Associates   Ltd, Wetherby, Yorks. 255 x 310mm. Copyright: Michael Turner.  10 x 12.2047 in.',
#    'links': []},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co226701',
#    'metadata': {'mention': 'Gasworks', 'label': '@hc:entityFAC'},
#    'text': 'Print. \'The New Elizabethan Era\' by Michael Turner. Mounted in folder  with accompanying text. A4 4-6-2 no 60022 Mallard hauling The Elizabethan passenger train in the cutting between Copenhagen  and [[Gasworks]] tunnels approaching Kings Cross. Other steam- hauled trains in the picture and carriages of another train passing out of view on overhead bridge. Factory chimney "Ebonite" in background. Published by Michael Benn & Associates   Ltd, Wetherby, Yorks. 255 x 310mm. Copyright: Michael Turner.  10 x 12.2047 in.',
#    'links': [{'title': 'Gasworks',
#      'url': 'https://en.wikipedia.org/wiki/Gasworks',
#      'score': 0.9999728202819824,
#      'qid': 'Q1495738'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co226701',
#    'metadata': {'mention': 'Ebonite', 'label': '@hc:entityOBJECT'},
#    'text': 'Print. \'The New Elizabethan Era\' by Michael Turner. Mounted in folder  with accompanying text. A4 4-6-2 no 60022 Mallard hauling The Elizabethan passenger train in the cutting between Copenhagen  and Gasworks tunnels approaching Kings Cross. Other steam- hauled trains in the picture and carriages of another train passing out of view on overhead bridge. Factory chimney "[[Ebonite]]" in background. Published by Michael Benn & Associates   Ltd, Wetherby, Yorks. 255 x 310mm. Copyright: Michael Turner.  10 x 12.2047 in.',
#    'links': [{'title': 'Ebonite',
#      'url': 'https://en.wikipedia.org/wiki/Ebonite',
#      'score': 0.9999991655349731,
#      'qid': 'Q461714'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co199543',
#    'metadata': {'mention': 'John Bell', 'label': '@hc:entityPERSON'},
#    'text': "Glass bottle with glass topper for Laudanum (opium tincture) with traces remaining. 110 mm x 32 mm x 25 mm, 82 g. Early printed label reads, 'Laudanum/Laudanum/POISON/[[John Bell]] & Compy./338, Oxford Street,/ opposite Great Portland Street.' Produced by John Bell and Company, 338 Oxford Street, London, England, 1819-1850.",
#    'links': [{'title': 'John Bell (publisher)',
#      'url': 'https://en.wikipedia.org/wiki/John_Bell_(publisher)',
#      'score': 0.994189977645874,
#      'qid': 'Q15486584'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co199543',
#    'metadata': {'mention': 'Glass', 'label': '@hc:entityPERSON'},
#    'text': "[[Glass]] bottle with glass topper for Laudanum (opium tincture) with traces remaining. 110 mm x 32 mm x 25 mm, 82 g. Early printed label reads, 'Laudanum/Laudanum/POISON/John Bell & Compy./338, Oxford Street,/ opposite Great Portland Street.' Produced by John Bell and Company, 338 Oxford Street, London, England, 1819-1850.",
#    'links': [{'title': 'Glass',
#      'url': 'https://en.wikipedia.org/wiki/Glass',
#      'score': 0.9999996423721313,
#      'qid': 'Q11469'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co199543',
#    'metadata': {'mention': 'Company', 'label': '@hc:entityORG'},
#    'text': "Glass bottle with glass topper for Laudanum (opium tincture) with traces remaining. 110 mm x 32 mm x 25 mm, 82 g. Early printed label reads, 'Laudanum/Laudanum/POISON/John Bell & Compy./338, Oxford Street,/ opposite Great Portland Street.' Produced by John Bell and [[Company]], 338 Oxford Street, London, England, 1819-1850.",
#    'links': [{'title': 'Company',
#      'url': 'https://en.wikipedia.org/wiki/Company',
#      'score': 0.9726120829582214,
#      'qid': 'Q783794'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co199543',
#    'metadata': {'mention': 'London, England', 'label': '@hc:entityLOC'},
#    'text': "Glass bottle with glass topper for Laudanum (opium tincture) with traces remaining. 110 mm x 32 mm x 25 mm, 82 g. Early printed label reads, 'Laudanum/Laudanum/POISON/John Bell & Compy./338, Oxford Street,/ opposite Great Portland Street.' Produced by John Bell and Company, 338 Oxford Street, [[London, England]], 1819-1850.",
#    'links': [{'title': 'London',
#      'url': 'https://en.wikipedia.org/wiki/London',
#      'score': 0.9999973773956299,
#      'qid': 'Q84'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co199543',
#    'metadata': {'mention': 'Oxford', 'label': '@hc:entityLOC'},
#    'text': "Glass bottle with glass topper for Laudanum (opium tincture) with traces remaining. 110 mm x 32 mm x 25 mm, 82 g. Early printed label reads, 'Laudanum/Laudanum/POISON/John Bell & Compy./338, [[Oxford]] Street,/ opposite Great Portland Street.' Produced by John Bell and Company, 338 Oxford Street, London, England, 1819-1850.",
#    'links': [{'title': 'Oxford',
#      'url': 'https://en.wikipedia.org/wiki/Oxford',
#      'score': 0.999583899974823,
#      'qid': 'Q34217'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co199543',
#    'metadata': {'mention': 'Oxford Street', 'label': '@hc:entityFAC'},
#    'text': "Glass bottle with glass topper for Laudanum (opium tincture) with traces remaining. 110 mm x 32 mm x 25 mm, 82 g. Early printed label reads, 'Laudanum/Laudanum/POISON/John Bell & Compy./338, [[Oxford Street]],/ opposite Great Portland Street.' Produced by John Bell and Company, 338 Oxford Street, London, England, 1819-1850.",
#    'links': [{'title': 'Oxford Street',
#      'url': 'https://en.wikipedia.org/wiki/Oxford_Street',
#      'score': 0.9998795986175537,
#      'qid': 'Q209714'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co199543',
#    'metadata': {'mention': 'Great Portland Street', 'label': '@hc:entityFAC'},
#    'text': "Glass bottle with glass topper for Laudanum (opium tincture) with traces remaining. 110 mm x 32 mm x 25 mm, 82 g. Early printed label reads, 'Laudanum/Laudanum/POISON/John Bell & Compy./338, Oxford Street,/ opposite [[Great Portland Street]].' Produced by John Bell and Company, 338 Oxford Street, London, England, 1819-1850.",
#    'links': [{'title': 'Great Portland Street',
#      'url': 'https://en.wikipedia.org/wiki/Great_Portland_Street',
#      'score': 0.999984860420227,
#      'qid': 'Q4968916'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co199543',
#    'metadata': {'mention': 'Laudanum/Laudanum/POISON/John Bell & Compy./338',
#     'label': '@hc:entityOBJECT'},
#    'text': "Glass bottle with glass topper for Laudanum (opium tincture) with traces remaining. 110 mm x 32 mm x 25 mm, 82 g. Early printed label reads, '[[Laudanum/Laudanum/POISON/John Bell & Compy./338]], Oxford Street,/ opposite Great Portland Street.' Produced by John Bell and Company, 338 Oxford Street, London, England, 1819-1850.",
#    'links': [{'title': 'Number 1s... and Then Some',
#      'url': 'https://en.wikipedia.org/wiki/Number_1s..._and_Then_Some',
#      'score': 0.9021686911582947,
#      'qid': 'Q7069495'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co421045',
#    'metadata': {'mention': 'H Floury', 'label': '@hc:entityPERSON'},
#    'text': "Coloured engraving. La Voie Ferree de Manchester et Liverpool. Conduite de Convoi de marchandises, denrees, etc; Altirail de Chariots avec betail. Drawn by [[H Floury]]. Engraved by A Gillet. Paris - d'apres Duperry. Se vend a la Madelaine No 16. (Based on coloured aquatint entitled Travelling on the Liverpool and Manchester Railway. Plate II. A Train of Wagons with Goods, etc; A Train of Carriages with Cattle. Drawn by I Shaw, Liverpool. Engraved by S G Hughes. Published by Ackermann and Co, Strand, London. 1833/01).",
#    'links': []},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co421045',
#    'metadata': {'mention': 'Conduite de Convoi de marchandises',
#     'label': '@hc:entityPERSON'},
#    'text': "Coloured engraving. La Voie Ferree de Manchester et Liverpool. [[Conduite de Convoi de marchandises]], denrees, etc; Altirail de Chariots avec betail. Drawn by H Floury. Engraved by A Gillet. Paris - d'apres Duperry. Se vend a la Madelaine No 16. (Based on coloured aquatint entitled Travelling on the Liverpool and Manchester Railway. Plate II. A Train of Wagons with Goods, etc; A Train of Carriages with Cattle. Drawn by I Shaw, Liverpool. Engraved by S G Hughes. Published by Ackermann and Co, Strand, London. 1833/01).",
#    'links': []},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co421045',
#    'metadata': {'mention': 'Duperry', 'label': '@hc:entityPERSON'},
#    'text': "Coloured engraving. La Voie Ferree de Manchester et Liverpool. Conduite de Convoi de marchandises, denrees, etc; Altirail de Chariots avec betail. Drawn by H Floury. Engraved by A Gillet. Paris - d'apres [[Duperry]]. Se vend a la Madelaine No 16. (Based on coloured aquatint entitled Travelling on the Liverpool and Manchester Railway. Plate II. A Train of Wagons with Goods, etc; A Train of Carriages with Cattle. Drawn by I Shaw, Liverpool. Engraved by S G Hughes. Published by Ackermann and Co, Strand, London. 1833/01).",
#    'links': [{'title': 'Adolphe Duperly',
#      'url': 'https://en.wikipedia.org/wiki/Adolphe_Duperly',
#      'score': 0.9934917092323303,
#      'qid': 'Q22017216'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co421045',
#    'metadata': {'mention': 'Altirail de Chariots',
#     'label': '@hc:entityPERSON'},
#    'text': "Coloured engraving. La Voie Ferree de Manchester et Liverpool. Conduite de Convoi de marchandises, denrees, etc; [[Altirail de Chariots]] avec betail. Drawn by H Floury. Engraved by A Gillet. Paris - d'apres Duperry. Se vend a la Madelaine No 16. (Based on coloured aquatint entitled Travelling on the Liverpool and Manchester Railway. Plate II. A Train of Wagons with Goods, etc; A Train of Carriages with Cattle. Drawn by I Shaw, Liverpool. Engraved by S G Hughes. Published by Ackermann and Co, Strand, London. 1833/01).",
#    'links': [{'title': 'Chariot',
#      'url': 'https://en.wikipedia.org/wiki/Chariot',
#      'score': 0.840197741985321,
#      'qid': 'Q203788'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co421045',
#    'metadata': {'mention': 'La Voie Ferree de Manchester et',
#     'label': '@hc:entityPERSON'},
#    'text': "Coloured engraving. [[La Voie Ferree de Manchester et]] Liverpool. Conduite de Convoi de marchandises, denrees, etc; Altirail de Chariots avec betail. Drawn by H Floury. Engraved by A Gillet. Paris - d'apres Duperry. Se vend a la Madelaine No 16. (Based on coloured aquatint entitled Travelling on the Liverpool and Manchester Railway. Plate II. A Train of Wagons with Goods, etc; A Train of Carriages with Cattle. Drawn by I Shaw, Liverpool. Engraved by S G Hughes. Published by Ackermann and Co, Strand, London. 1833/01).",
#    'links': [{'title': 'History of Liverpool',
#      'url': 'https://en.wikipedia.org/wiki/History_of_Liverpool',
#      'score': 0.8069530725479126,
#      'qid': 'Q5865291'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co421045',
#    'metadata': {'mention': 'Gillet', 'label': '@hc:entityORG'},
#    'text': "Coloured engraving. La Voie Ferree de Manchester et Liverpool. Conduite de Convoi de marchandises, denrees, etc; Altirail de Chariots avec betail. Drawn by H Floury. Engraved by A [[Gillet]]. Paris - d'apres Duperry. Se vend a la Madelaine No 16. (Based on coloured aquatint entitled Travelling on the Liverpool and Manchester Railway. Plate II. A Train of Wagons with Goods, etc; A Train of Carriages with Cattle. Drawn by I Shaw, Liverpool. Engraved by S G Hughes. Published by Ackermann and Co, Strand, London. 1833/01).",
#    'links': [{'title': 'Louis Gillet',
#      'url': 'https://en.wikipedia.org/wiki/Louis_Gillet',
#      'score': 0.9282563328742981,
#      'qid': 'Q3262035'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co421045',
#    'metadata': {'mention': 'Train of Wagons with Goods',
#     'label': '@hc:entityORG'},
#    'text': "Coloured engraving. La Voie Ferree de Manchester et Liverpool. Conduite de Convoi de marchandises, denrees, etc; Altirail de Chariots avec betail. Drawn by H Floury. Engraved by A Gillet. Paris - d'apres Duperry. Se vend a la Madelaine No 16. (Based on coloured aquatint entitled Travelling on the Liverpool and Manchester Railway. Plate II. A [[Train of Wagons with Goods]], etc; A Train of Carriages with Cattle. Drawn by I Shaw, Liverpool. Engraved by S G Hughes. Published by Ackermann and Co, Strand, London. 1833/01).",
#    'links': []},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co421045',
#    'metadata': {'mention': 'A Train of Carriages with Cattle',
#     'label': '@hc:entityORG'},
#    'text': "Coloured engraving. La Voie Ferree de Manchester et Liverpool. Conduite de Convoi de marchandises, denrees, etc; Altirail de Chariots avec betail. Drawn by H Floury. Engraved by A Gillet. Paris - d'apres Duperry. Se vend a la Madelaine No 16. (Based on coloured aquatint entitled Travelling on the Liverpool and Manchester Railway. Plate II. A Train of Wagons with Goods, etc; [[A Train of Carriages with Cattle]]. Drawn by I Shaw, Liverpool. Engraved by S G Hughes. Published by Ackermann and Co, Strand, London. 1833/01).",
#    'links': []},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co421045',
#    'metadata': {'mention': 'Shaw', 'label': '@hc:entityORG'},
#    'text': "Coloured engraving. La Voie Ferree de Manchester et Liverpool. Conduite de Convoi de marchandises, denrees, etc; Altirail de Chariots avec betail. Drawn by H Floury. Engraved by A Gillet. Paris - d'apres Duperry. Se vend a la Madelaine No 16. (Based on coloured aquatint entitled Travelling on the Liverpool and Manchester Railway. Plate II. A Train of Wagons with Goods, etc; A Train of Carriages with Cattle. Drawn by I [[Shaw]], Liverpool. Engraved by S G Hughes. Published by Ackermann and Co, Strand, London. 1833/01).",
#    'links': []},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co421045',
#    'metadata': {'mention': 'London', 'label': '@hc:entityLOC'},
#    'text': "Coloured engraving. La Voie Ferree de Manchester et Liverpool. Conduite de Convoi de marchandises, denrees, etc; Altirail de Chariots avec betail. Drawn by H Floury. Engraved by A Gillet. Paris - d'apres Duperry. Se vend a la Madelaine No 16. (Based on coloured aquatint entitled Travelling on the Liverpool and Manchester Railway. Plate II. A Train of Wagons with Goods, etc; A Train of Carriages with Cattle. Drawn by I Shaw, Liverpool. Engraved by S G Hughes. Published by Ackermann and Co, Strand, [[London]]. 1833/01).",
#    'links': [{'title': 'London',
#      'url': 'https://en.wikipedia.org/wiki/London',
#      'score': 0.9999828338623047,
#      'qid': 'Q84'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co421045',
#    'metadata': {'mention': 'Liverpool', 'label': '@hc:entityLOC'},
#    'text': "Coloured engraving. La Voie Ferree de Manchester et [[Liverpool]]. Conduite de Convoi de marchandises, denrees, etc; Altirail de Chariots avec betail. Drawn by H Floury. Engraved by A Gillet. Paris - d'apres Duperry. Se vend a la Madelaine No 16. (Based on coloured aquatint entitled Travelling on the Liverpool and Manchester Railway. Plate II. A Train of Wagons with Goods, etc; A Train of Carriages with Cattle. Drawn by I Shaw, Liverpool. Engraved by S G Hughes. Published by Ackermann and Co, Strand, London. 1833/01).",
#    'links': [{'title': 'Liverpool',
#      'url': 'https://en.wikipedia.org/wiki/Liverpool',
#      'score': 0.9999939203262329,
#      'qid': 'Q24826'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co421045',
#    'metadata': {'mention': 'Paris', 'label': '@hc:entityLOC'},
#    'text': "Coloured engraving. La Voie Ferree de Manchester et Liverpool. Conduite de Convoi de marchandises, denrees, etc; Altirail de Chariots avec betail. Drawn by H Floury. Engraved by A Gillet. [[Paris]] - d'apres Duperry. Se vend a la Madelaine No 16. (Based on coloured aquatint entitled Travelling on the Liverpool and Manchester Railway. Plate II. A Train of Wagons with Goods, etc; A Train of Carriages with Cattle. Drawn by I Shaw, Liverpool. Engraved by S G Hughes. Published by Ackermann and Co, Strand, London. 1833/01).",
#    'links': [{'title': 'Paris',
#      'url': 'https://en.wikipedia.org/wiki/Paris',
#      'score': 0.9999933242797852,
#      'qid': 'Q90'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co421045',
#    'metadata': {'mention': 'Manchester Railway', 'label': '@hc:entityFAC'},
#    'text': "Coloured engraving. La Voie Ferree de Manchester et Liverpool. Conduite de Convoi de marchandises, denrees, etc; Altirail de Chariots avec betail. Drawn by H Floury. Engraved by A Gillet. Paris - d'apres Duperry. Se vend a la Madelaine No 16. (Based on coloured aquatint entitled Travelling on the Liverpool and [[Manchester Railway]]. Plate II. A Train of Wagons with Goods, etc; A Train of Carriages with Cattle. Drawn by I Shaw, Liverpool. Engraved by S G Hughes. Published by Ackermann and Co, Strand, London. 1833/01).",
#    'links': [{'title': 'Liverpool and Manchester Railway',
#      'url': 'https://en.wikipedia.org/wiki/Liverpool_and_Manchester_Railway',
#      'score': 0.999861478805542,
#      'qid': 'Q1398696'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co421045',
#    'metadata': {'mention': 'Travelling', 'label': '@hc:entityOBJECT'},
#    'text': "Coloured engraving. La Voie Ferree de Manchester et Liverpool. Conduite de Convoi de marchandises, denrees, etc; Altirail de Chariots avec betail. Drawn by H Floury. Engraved by A Gillet. Paris - d'apres Duperry. Se vend a la Madelaine No 16. (Based on coloured aquatint entitled [[Travelling]] on the Liverpool and Manchester Railway. Plate II. A Train of Wagons with Goods, etc; A Train of Carriages with Cattle. Drawn by I Shaw, Liverpool. Engraved by S G Hughes. Published by Ackermann and Co, Strand, London. 1833/01).",
#    'links': [{'title': 'Travel',
#      'url': 'https://en.wikipedia.org/wiki/Travel',
#      'score': 0.9976346492767334,
#      'qid': 'Q61509'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co8034284',
#    'metadata': {'mention': 'Engraving Stellarum Fixarum Hemisphaerium Australe',
#     'label': '@hc:entityPERSON'},
#    'text': "print. engraving. [[Engraving Stellarum Fixarum Hemisphaerium Australe]].  In plano Eclipticae depictum omnes catalagi Britannici stellus exhibens, una cum iis quas Cl. Hallius in in insuala Stae. Helenae observavit, eo situ delineatas quem anno 1690 habuerunt. London, John Senex, Printed for J[oh]n Bowles at No 13 in Cornhill, C Bowles in St Paul's Church Yard.  & Rob[er]t Sayer in Fleet Street, re-issue, 1750-1760. 85 x 66cm",
#    'links': []},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co8034284',
#    'metadata': {'mention': 'J[oh]n Bowles', 'label': '@hc:entityPERSON'},
#    'text': "print. engraving. Engraving Stellarum Fixarum Hemisphaerium Australe.  In plano Eclipticae depictum omnes catalagi Britannici stellus exhibens, una cum iis quas Cl. Hallius in in insuala Stae. Helenae observavit, eo situ delineatas quem anno 1690 habuerunt. London, John Senex, Printed for [[J[oh]n Bowles]] at No 13 in Cornhill, C Bowles in St Paul's Church Yard.  & Rob[er]t Sayer in Fleet Street, re-issue, 1750-1760. 85 x 66cm",
#    'links': []},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co8034284',
#    'metadata': {'mention': 'Helenae', 'label': '@hc:entityPERSON'},
#    'text': "print. engraving. Engraving Stellarum Fixarum Hemisphaerium Australe.  In plano Eclipticae depictum omnes catalagi Britannici stellus exhibens, una cum iis quas Cl. Hallius in in insuala Stae. [[Helenae]] observavit, eo situ delineatas quem anno 1690 habuerunt. London, John Senex, Printed for J[oh]n Bowles at No 13 in Cornhill, C Bowles in St Paul's Church Yard.  & Rob[er]t Sayer in Fleet Street, re-issue, 1750-1760. 85 x 66cm",
#    'links': []},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co8034284',
#    'metadata': {'mention': "St Paul's Church Yard", 'label': '@hc:entityORG'},
#    'text': "print. engraving. Engraving Stellarum Fixarum Hemisphaerium Australe.  In plano Eclipticae depictum omnes catalagi Britannici stellus exhibens, una cum iis quas Cl. Hallius in in insuala Stae. Helenae observavit, eo situ delineatas quem anno 1690 habuerunt. London, John Senex, Printed for J[oh]n Bowles at No 13 in Cornhill, C Bowles in [[St Paul's Church Yard]].  & Rob[er]t Sayer in Fleet Street, re-issue, 1750-1760. 85 x 66cm",
#    'links': []},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co8034284',
#    'metadata': {'mention': 'Hallius', 'label': '@hc:entityORG'},
#    'text': "print. engraving. Engraving Stellarum Fixarum Hemisphaerium Australe.  In plano Eclipticae depictum omnes catalagi Britannici stellus exhibens, una cum iis quas Cl. [[Hallius]] in in insuala Stae. Helenae observavit, eo situ delineatas quem anno 1690 habuerunt. London, John Senex, Printed for J[oh]n Bowles at No 13 in Cornhill, C Bowles in St Paul's Church Yard.  & Rob[er]t Sayer in Fleet Street, re-issue, 1750-1760. 85 x 66cm",
#    'links': []},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co8034284',
#    'metadata': {'mention': 'Cornhill', 'label': '@hc:entityLOC'},
#    'text': "print. engraving. Engraving Stellarum Fixarum Hemisphaerium Australe.  In plano Eclipticae depictum omnes catalagi Britannici stellus exhibens, una cum iis quas Cl. Hallius in in insuala Stae. Helenae observavit, eo situ delineatas quem anno 1690 habuerunt. London, John Senex, Printed for J[oh]n Bowles at No 13 in [[Cornhill]], C Bowles in St Paul's Church Yard.  & Rob[er]t Sayer in Fleet Street, re-issue, 1750-1760. 85 x 66cm",
#    'links': [{'title': 'Cornhill, London',
#      'url': 'https://en.wikipedia.org/wiki/Cornhill,_London',
#      'score': 0.9999977350234985,
#      'qid': 'Q1782039'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co8034284',
#    'metadata': {'mention': 'London', 'label': '@hc:entityLOC'},
#    'text': "print. engraving. Engraving Stellarum Fixarum Hemisphaerium Australe.  In plano Eclipticae depictum omnes catalagi Britannici stellus exhibens, una cum iis quas Cl. Hallius in in insuala Stae. Helenae observavit, eo situ delineatas quem anno 1690 habuerunt. [[London]], John Senex, Printed for J[oh]n Bowles at No 13 in Cornhill, C Bowles in St Paul's Church Yard.  & Rob[er]t Sayer in Fleet Street, re-issue, 1750-1760. 85 x 66cm",
#    'links': [{'title': 'London',
#      'url': 'https://en.wikipedia.org/wiki/London',
#      'score': 0.9979022741317749,
#      'qid': 'Q84'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co8034284',
#    'metadata': {'mention': 'Fleet Street', 'label': '@hc:entityFAC'},
#    'text': "print. engraving. Engraving Stellarum Fixarum Hemisphaerium Australe.  In plano Eclipticae depictum omnes catalagi Britannici stellus exhibens, una cum iis quas Cl. Hallius in in insuala Stae. Helenae observavit, eo situ delineatas quem anno 1690 habuerunt. London, John Senex, Printed for J[oh]n Bowles at No 13 in Cornhill, C Bowles in St Paul's Church Yard.  & Rob[er]t Sayer in [[Fleet Street]], re-issue, 1750-1760. 85 x 66cm",
#    'links': [{'title': 'Fleet Street',
#      'url': 'https://en.wikipedia.org/wiki/Fleet_Street',
#      'score': 0.9999998807907104,
#      'qid': 'Q846686'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co8034284',
#    'metadata': {'mention': 'Eclipticae', 'label': '@hc:entityOBJECT'},
#    'text': "print. engraving. Engraving Stellarum Fixarum Hemisphaerium Australe.  In plano [[Eclipticae]] depictum omnes catalagi Britannici stellus exhibens, una cum iis quas Cl. Hallius in in insuala Stae. Helenae observavit, eo situ delineatas quem anno 1690 habuerunt. London, John Senex, Printed for J[oh]n Bowles at No 13 in Cornhill, C Bowles in St Paul's Church Yard.  & Rob[er]t Sayer in Fleet Street, re-issue, 1750-1760. 85 x 66cm",
#    'links': [{'title': 'Ecliptic',
#      'url': 'https://en.wikipedia.org/wiki/Ecliptic',
#      'score': 0.9911677837371826,
#      'qid': 'Q79852'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/people/cp18012',
#    'metadata': {'mention': 'Ludgate St.', 'label': '@hc:entityPERSON'},
#    'text': "REF: Clifton, G., Directory of British Scientific Instrument Makers 1550-1851 (Zwemmer, 1995) \n  \n Traded at  The Great Toy, Spectacle Chinaware and Print Shop next the Dog Tavern, corner of [[Ludgate St.]], nr. St. Paul's (1709-15) & The Great Toy, Spectacle and Print Shop at the corner of Ludgate St., nr. St. Paul's (1709-15) & Archimedes & Globe, Ludgate St., all London, England",
#    'links': []},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/people/cp18012',
#    'metadata': {'mention': 'Zwemmer,', 'label': '@hc:entityORG'},
#    'text': "REF: Clifton, G., Directory of British Scientific Instrument Makers 1550-1851 ([[Zwemmer,]] 1995) \n  \n Traded at  The Great Toy, Spectacle Chinaware and Print Shop next the Dog Tavern, corner of Ludgate St., nr. St. Paul's (1709-15) & The Great Toy, Spectacle and Print Shop at the corner of Ludgate St., nr. St. Paul's (1709-15) & Archimedes & Globe, Ludgate St., all London, England",
#    'links': []},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/people/cp18012',
#    'metadata': {'mention': 'Print Shop', 'label': '@hc:entityORG'},
#    'text': "REF: Clifton, G., Directory of British Scientific Instrument Makers 1550-1851 (Zwemmer, 1995) \n  \n Traded at  The Great Toy, Spectacle Chinaware and [[Print Shop]] next the Dog Tavern, corner of Ludgate St., nr. St. Paul's (1709-15) & The Great Toy, Spectacle and Print Shop at the corner of Ludgate St., nr. St. Paul's (1709-15) & Archimedes & Globe, Ludgate St., all London, England",
#    'links': []},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/people/cp18012',
#    'metadata': {'mention': "St. Paul's", 'label': '@hc:entityORG'},
#    'text': "REF: Clifton, G., Directory of British Scientific Instrument Makers 1550-1851 (Zwemmer, 1995) \n  \n Traded at  The Great Toy, Spectacle Chinaware and Print Shop next the Dog Tavern, corner of Ludgate St., nr. [[St. Paul's]] (1709-15) & The Great Toy, Spectacle and Print Shop at the corner of Ludgate St., nr. St. Paul's (1709-15) & Archimedes & Globe, Ludgate St., all London, England",
#    'links': [{'title': "St Paul's Cathedral",
#      'url': "https://en.wikipedia.org/wiki/St_Paul's_Cathedral",
#      'score': 0.9835228323936462,
#      'qid': 'Q173882'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/people/cp18012',
#    'metadata': {'mention': 'London, England', 'label': '@hc:entityLOC'},
#    'text': "REF: Clifton, G., Directory of British Scientific Instrument Makers 1550-1851 (Zwemmer, 1995) \n  \n Traded at  The Great Toy, Spectacle Chinaware and Print Shop next the Dog Tavern, corner of Ludgate St., nr. St. Paul's (1709-15) & The Great Toy, Spectacle and Print Shop at the corner of Ludgate St., nr. St. Paul's (1709-15) & Archimedes & Globe, Ludgate St., all [[London, England]]",
#    'links': [{'title': 'London',
#      'url': 'https://en.wikipedia.org/wiki/London',
#      'score': 0.999980092048645,
#      'qid': 'Q84'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/people/cp18012',
#    'metadata': {'mention': 'Clifton', 'label': '@hc:entityLOC'},
#    'text': "REF: [[Clifton]], G., Directory of British Scientific Instrument Makers 1550-1851 (Zwemmer, 1995) \n  \n Traded at  The Great Toy, Spectacle Chinaware and Print Shop next the Dog Tavern, corner of Ludgate St., nr. St. Paul's (1709-15) & The Great Toy, Spectacle and Print Shop at the corner of Ludgate St., nr. St. Paul's (1709-15) & Archimedes & Globe, Ludgate St., all London, England",
#    'links': []},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/people/cp18012',
#    'metadata': {'mention': 'Ludgate St.', 'label': '@hc:entityFAC'},
#    'text': "REF: Clifton, G., Directory of British Scientific Instrument Makers 1550-1851 (Zwemmer, 1995) \n  \n Traded at  The Great Toy, Spectacle Chinaware and Print Shop next the Dog Tavern, corner of [[Ludgate St.]], nr. St. Paul's (1709-15) & The Great Toy, Spectacle and Print Shop at the corner of Ludgate St., nr. St. Paul's (1709-15) & Archimedes & Globe, Ludgate St., all London, England",
#    'links': []},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/people/cp18012',
#    'metadata': {'mention': 'The Great Toy', 'label': '@hc:entityOBJECT'},
#    'text': "REF: Clifton, G., Directory of British Scientific Instrument Makers 1550-1851 (Zwemmer, 1995) \n  \n Traded at  [[The Great Toy]], Spectacle Chinaware and Print Shop next the Dog Tavern, corner of Ludgate St., nr. St. Paul's (1709-15) & The Great Toy, Spectacle and Print Shop at the corner of Ludgate St., nr. St. Paul's (1709-15) & Archimedes & Globe, Ludgate St., all London, England",
#    'links': []},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/people/cp38651',
#    'metadata': {'mention': 'Howard Florey', 'label': '@hc:entityPERSON'},
#    'text': 'ODNB: E. P. Abraham, ‘Chain, Sir Ernst Boris (1906–1979)’, rev., Oxford Dictionary of National Biography, Oxford University Press, 2004 [http://www.oxforddnb.com/view/article/30913, accessed 18 Dec 2008] Sir Ernst Boris Chain (1906–1979): doi:10.1093/ref:odnb/30913; NOBEL: \n  \n Ernst Chain was a German-British biochemist who in 1945 won the Nobel Prize for his work with Alexander Fleming and [[Howard Florey]] on the development and application of penicillin.  Penicillin is one of the most important discoveries in medicine. However, it was not until ten years after its discovery by Alexander Fleming in 1928 that its benefits were actually realised.  Chain, along with Howard Florey and their team, produced enough penicillin in 1940 to experiment with its effects on mice. They tried to persuade British drug companies to manufacture penicillin, but the Second World War (1939-45) meant that companies preoccupied with wartime production could not produce enough. Florey and Chain turned their department at Oxford into a penicillin factory. Trials of penicillin were held at the Radcliffe Infirmary in Oxford from 1941 and were successful.',
#    'links': [{'title': 'Howard Florey',
#      'url': 'https://en.wikipedia.org/wiki/Howard_Florey',
#      'score': 1.0,
#      'qid': 'Q137106'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/people/cp38651',
#    'metadata': {'mention': 'E. P. Abraham', 'label': '@hc:entityPERSON'},
#    'text': 'ODNB: [[E. P. Abraham]], ‘Chain, Sir Ernst Boris (1906–1979)’, rev., Oxford Dictionary of National Biography, Oxford University Press, 2004 [http://www.oxforddnb.com/view/article/30913, accessed 18 Dec 2008] Sir Ernst Boris Chain (1906–1979): doi:10.1093/ref:odnb/30913; NOBEL: \n  \n Ernst Chain was a German-British biochemist who in 1945 won the Nobel Prize for his work with Alexander Fleming and Howard Florey on the development and application of penicillin.  Penicillin is one of the most important discoveries in medicine. However, it was not until ten years after its discovery by Alexander Fleming in 1928 that its benefits were actually realised.  Chain, along with Howard Florey and their team, produced enough penicillin in 1940 to experiment with its effects on mice. They tried to persuade British drug companies to manufacture penicillin, but the Second World War (1939-45) meant that companies preoccupied with wartime production could not produce enough. Florey and Chain turned their department at Oxford into a penicillin factory. Trials of penicillin were held at the Radcliffe Infirmary in Oxford from 1941 and were successful.',
#    'links': []},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/people/cp38651',
#    'metadata': {'mention': 'Ernst Boris Chain', 'label': '@hc:entityPERSON'},
#    'text': 'ODNB: E. P. Abraham, ‘Chain, Sir Ernst Boris (1906–1979)’, rev., Oxford Dictionary of National Biography, Oxford University Press, 2004 [http://www.oxforddnb.com/view/article/30913, accessed 18 Dec 2008] Sir [[Ernst Boris Chain]] (1906–1979): doi:10.1093/ref:odnb/30913; NOBEL: \n  \n Ernst Chain was a German-British biochemist who in 1945 won the Nobel Prize for his work with Alexander Fleming and Howard Florey on the development and application of penicillin.  Penicillin is one of the most important discoveries in medicine. However, it was not until ten years after its discovery by Alexander Fleming in 1928 that its benefits were actually realised.  Chain, along with Howard Florey and their team, produced enough penicillin in 1940 to experiment with its effects on mice. They tried to persuade British drug companies to manufacture penicillin, but the Second World War (1939-45) meant that companies preoccupied with wartime production could not produce enough. Florey and Chain turned their department at Oxford into a penicillin factory. Trials of penicillin were held at the Radcliffe Infirmary in Oxford from 1941 and were successful.',
#    'links': [{'title': 'Ernst Chain',
#      'url': 'https://en.wikipedia.org/wiki/Ernst_Chain',
#      'score': 1.0,
#      'qid': 'Q58054'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/people/cp38651',
#    'metadata': {'mention': 'Ernst Boris', 'label': '@hc:entityPERSON'},
#    'text': 'ODNB: E. P. Abraham, ‘Chain, Sir [[Ernst Boris]] (1906–1979)’, rev., Oxford Dictionary of National Biography, Oxford University Press, 2004 [http://www.oxforddnb.com/view/article/30913, accessed 18 Dec 2008] Sir Ernst Boris Chain (1906–1979): doi:10.1093/ref:odnb/30913; NOBEL: \n  \n Ernst Chain was a German-British biochemist who in 1945 won the Nobel Prize for his work with Alexander Fleming and Howard Florey on the development and application of penicillin.  Penicillin is one of the most important discoveries in medicine. However, it was not until ten years after its discovery by Alexander Fleming in 1928 that its benefits were actually realised.  Chain, along with Howard Florey and their team, produced enough penicillin in 1940 to experiment with its effects on mice. They tried to persuade British drug companies to manufacture penicillin, but the Second World War (1939-45) meant that companies preoccupied with wartime production could not produce enough. Florey and Chain turned their department at Oxford into a penicillin factory. Trials of penicillin were held at the Radcliffe Infirmary in Oxford from 1941 and were successful.',
#    'links': [{'title': 'Ernst Chain',
#      'url': 'https://en.wikipedia.org/wiki/Ernst_Chain',
#      'score': 1.0,
#      'qid': 'Q58054'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/people/cp38651',
#    'metadata': {'mention': 'the Second World War', 'label': '@hc:entityORG'},
#    'text': 'ODNB: E. P. Abraham, ‘Chain, Sir Ernst Boris (1906–1979)’, rev., Oxford Dictionary of National Biography, Oxford University Press, 2004 [http://www.oxforddnb.com/view/article/30913, accessed 18 Dec 2008] Sir Ernst Boris Chain (1906–1979): doi:10.1093/ref:odnb/30913; NOBEL: \n  \n Ernst Chain was a German-British biochemist who in 1945 won the Nobel Prize for his work with Alexander Fleming and Howard Florey on the development and application of penicillin.  Penicillin is one of the most important discoveries in medicine. However, it was not until ten years after its discovery by Alexander Fleming in 1928 that its benefits were actually realised.  Chain, along with Howard Florey and their team, produced enough penicillin in 1940 to experiment with its effects on mice. They tried to persuade British drug companies to manufacture penicillin, but [[the Second World War]] (1939-45) meant that companies preoccupied with wartime production could not produce enough. Florey and Chain turned their department at Oxford into a penicillin factory. Trials of penicillin were held at the Radcliffe Infirmary in Oxford from 1941 and were successful.',
#    'links': [{'title': 'World War II',
#      'url': 'https://en.wikipedia.org/wiki/World_War_II',
#      'score': 0.999998927116394,
#      'qid': 'Q362'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/people/cp38651',
#    'metadata': {'mention': 'Chain', 'label': '@hc:entityORG'},
#    'text': 'ODNB: E. P. Abraham, ‘[[Chain]], Sir Ernst Boris (1906–1979)’, rev., Oxford Dictionary of National Biography, Oxford University Press, 2004 [http://www.oxforddnb.com/view/article/30913, accessed 18 Dec 2008] Sir Ernst Boris Chain (1906–1979): doi:10.1093/ref:odnb/30913; NOBEL: \n  \n Ernst Chain was a German-British biochemist who in 1945 won the Nobel Prize for his work with Alexander Fleming and Howard Florey on the development and application of penicillin.  Penicillin is one of the most important discoveries in medicine. However, it was not until ten years after its discovery by Alexander Fleming in 1928 that its benefits were actually realised.  Chain, along with Howard Florey and their team, produced enough penicillin in 1940 to experiment with its effects on mice. They tried to persuade British drug companies to manufacture penicillin, but the Second World War (1939-45) meant that companies preoccupied with wartime production could not produce enough. Florey and Chain turned their department at Oxford into a penicillin factory. Trials of penicillin were held at the Radcliffe Infirmary in Oxford from 1941 and were successful.',
#    'links': [{'title': 'Ernst Chain',
#      'url': 'https://en.wikipedia.org/wiki/Ernst_Chain',
#      'score': 1.0,
#      'qid': 'Q58054'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/people/cp38651',
#    'metadata': {'mention': 'Oxford', 'label': '@hc:entityORG'},
#    'text': 'ODNB: E. P. Abraham, ‘Chain, Sir Ernst Boris (1906–1979)’, rev., [[Oxford]] Dictionary of National Biography, Oxford University Press, 2004 [http://www.oxforddnb.com/view/article/30913, accessed 18 Dec 2008] Sir Ernst Boris Chain (1906–1979): doi:10.1093/ref:odnb/30913; NOBEL: \n  \n Ernst Chain was a German-British biochemist who in 1945 won the Nobel Prize for his work with Alexander Fleming and Howard Florey on the development and application of penicillin.  Penicillin is one of the most important discoveries in medicine. However, it was not until ten years after its discovery by Alexander Fleming in 1928 that its benefits were actually realised.  Chain, along with Howard Florey and their team, produced enough penicillin in 1940 to experiment with its effects on mice. They tried to persuade British drug companies to manufacture penicillin, but the Second World War (1939-45) meant that companies preoccupied with wartime production could not produce enough. Florey and Chain turned their department at Oxford into a penicillin factory. Trials of penicillin were held at the Radcliffe Infirmary in Oxford from 1941 and were successful.',
#    'links': [{'title': 'Oxford',
#      'url': 'https://en.wikipedia.org/wiki/Oxford',
#      'score': 0.9995997548103333,
#      'qid': 'Q34217'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/people/cp38651',
#    'metadata': {'mention': 'Oxford', 'label': '@hc:entityLOC'},
#    'text': 'ODNB: E. P. Abraham, ‘Chain, Sir Ernst Boris (1906–1979)’, rev., [[Oxford]] Dictionary of National Biography, Oxford University Press, 2004 [http://www.oxforddnb.com/view/article/30913, accessed 18 Dec 2008] Sir Ernst Boris Chain (1906–1979): doi:10.1093/ref:odnb/30913; NOBEL: \n  \n Ernst Chain was a German-British biochemist who in 1945 won the Nobel Prize for his work with Alexander Fleming and Howard Florey on the development and application of penicillin.  Penicillin is one of the most important discoveries in medicine. However, it was not until ten years after its discovery by Alexander Fleming in 1928 that its benefits were actually realised.  Chain, along with Howard Florey and their team, produced enough penicillin in 1940 to experiment with its effects on mice. They tried to persuade British drug companies to manufacture penicillin, but the Second World War (1939-45) meant that companies preoccupied with wartime production could not produce enough. Florey and Chain turned their department at Oxford into a penicillin factory. Trials of penicillin were held at the Radcliffe Infirmary in Oxford from 1941 and were successful.',
#    'links': [{'title': 'Oxford',
#      'url': 'https://en.wikipedia.org/wiki/Oxford',
#      'score': 0.9995997548103333,
#      'qid': 'Q34217'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/people/cp38651',
#    'metadata': {'mention': 'the Radcliffe Infirmary',
#     'label': '@hc:entityFAC'},
#    'text': 'ODNB: E. P. Abraham, ‘Chain, Sir Ernst Boris (1906–1979)’, rev., Oxford Dictionary of National Biography, Oxford University Press, 2004 [http://www.oxforddnb.com/view/article/30913, accessed 18 Dec 2008] Sir Ernst Boris Chain (1906–1979): doi:10.1093/ref:odnb/30913; NOBEL: \n  \n Ernst Chain was a German-British biochemist who in 1945 won the Nobel Prize for his work with Alexander Fleming and Howard Florey on the development and application of penicillin.  Penicillin is one of the most important discoveries in medicine. However, it was not until ten years after its discovery by Alexander Fleming in 1928 that its benefits were actually realised.  Chain, along with Howard Florey and their team, produced enough penicillin in 1940 to experiment with its effects on mice. They tried to persuade British drug companies to manufacture penicillin, but the Second World War (1939-45) meant that companies preoccupied with wartime production could not produce enough. Florey and Chain turned their department at Oxford into a penicillin factory. Trials of penicillin were held at [[the Radcliffe Infirmary]] in Oxford from 1941 and were successful.',
#    'links': [{'title': 'Radcliffe Infirmary',
#      'url': 'https://en.wikipedia.org/wiki/Radcliffe_Infirmary',
#      'score': 0.9993332028388977,
#      'qid': 'Q7280027'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/people/cp38651',
#    'metadata': {'mention': 'the Nobel Prize', 'label': '@hc:entityOBJECT'},
#    'text': 'ODNB: E. P. Abraham, ‘Chain, Sir Ernst Boris (1906–1979)’, rev., Oxford Dictionary of National Biography, Oxford University Press, 2004 [http://www.oxforddnb.com/view/article/30913, accessed 18 Dec 2008] Sir Ernst Boris Chain (1906–1979): doi:10.1093/ref:odnb/30913; NOBEL: \n  \n Ernst Chain was a German-British biochemist who in 1945 won [[the Nobel Prize]] for his work with Alexander Fleming and Howard Florey on the development and application of penicillin.  Penicillin is one of the most important discoveries in medicine. However, it was not until ten years after its discovery by Alexander Fleming in 1928 that its benefits were actually realised.  Chain, along with Howard Florey and their team, produced enough penicillin in 1940 to experiment with its effects on mice. They tried to persuade British drug companies to manufacture penicillin, but the Second World War (1939-45) meant that companies preoccupied with wartime production could not produce enough. Florey and Chain turned their department at Oxford into a penicillin factory. Trials of penicillin were held at the Radcliffe Infirmary in Oxford from 1941 and were successful.',
#    'links': [{'title': 'Nobel Prize',
#      'url': 'https://en.wikipedia.org/wiki/Nobel_Prize',
#      'score': 0.9902177453041077,
#      'qid': 'Q7191'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co226729',
#    'metadata': {'mention': 'Medt', 'label': '@hc:entityPERSON'},
#    'text': 'Painting, oils on canvas, The accident to the Irish Mail Train, 20 August 1868, with the loss of 33 lives, at Abergele, Rhyl, by E F Holt, 1868.  Naive depiction of the derailed Irish Mail train with the tender upside down, several carriages and wagons on fire, and passengers trying to escape.  Two wagons remain on the track, one of them laden with barrels of paraffin.  Three men run to the scene.  In the background are the wooded hills around Gwrych Castle.  Title inscribed across the top of the painting.  Signed "E.F. Holt 1868 Prize [[Medt]]. R.A."  Unframed.',
#    'links': []},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co226729',
#    'metadata': {'mention': 'the Irish Mail Train', 'label': '@hc:entityORG'},
#    'text': 'Painting, oils on canvas, The accident to [[the Irish Mail Train]], 20 August 1868, with the loss of 33 lives, at Abergele, Rhyl, by E F Holt, 1868.  Naive depiction of the derailed Irish Mail train with the tender upside down, several carriages and wagons on fire, and passengers trying to escape.  Two wagons remain on the track, one of them laden with barrels of paraffin.  Three men run to the scene.  In the background are the wooded hills around Gwrych Castle.  Title inscribed across the top of the painting.  Signed "E.F. Holt 1868 Prize Medt. R.A."  Unframed.',
#    'links': [{'title': 'Irish Mail',
#      'url': 'https://en.wikipedia.org/wiki/Irish_Mail',
#      'score': 0.9996088147163391,
#      'qid': 'Q60784997'}]},
# ...
#    'links': [{'title': 'London',
#      'url': 'https://en.wikipedia.org/wiki/London',
#      'score': 0.9999951124191284,
#      'qid': 'Q84'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co117460',
#    'metadata': {'mention': 'Europa', 'label': '@hc:entityLOC'},
#    'text': 'Collection of publications from the library of Dr. Ludwig Koch consisting of:  BBC Natural History Recordings (London: BBC, 1961) Berry, M.F. and Brock, D.W.E. Hunting by Ear (London: H.F. & G. Witherby, 1937). Chapuis, Alfred. Automates. Machines Automatiques et Machinisme (Geneva: Publications Techniques, 1928) Clark, Ronald W. The Huxleys (London:  Heinemann, 1968) Delamain, Jacques. Portraits D’Oiseaux (Paris: Editions Stock, 1938) Delépinne, Berthe. Elizabeth. Reine des Belges (Brussels: Willy Godenne, 1954) Holder, Artur. Leonard Bernstein (Berlin: Rembrandt, 1961) Howard, Len. Birds as Individuals (London: Collins, 1952) Huxley, Julian. At the Zoo (Woking: Unwin, 1936) Leakey, J.H. School Errant (London: Dulwich College Preparatory School, 1951)  MacDonald, Malcolm. The Birds of Brewery Creek (London: Oxford University Press, 1947) Michaelberten, Walter. Musik und Mikrophon (Dusseldorf: Schwann, 1951) Radio and Television Who’s Who, 1950-1951 (London: Vox Mundi, 1950) Raphaël, Samson. Pour Poser un Diagnostic (Brussels: Meddens, [no date]) Reiss, Curt. Knaurs Weltgeschichte der Schallplatte (Zurich: Droemersche, 1966) Seton-Thompson, Ernest. Wild Animals I Have Known (London: David Nutt, 1901) Silberman, Fred. Jungles and Skyscrapers (London: [no publisher], 1940) Stern-Rubarth, Edgar. Drei Männer suchen [[Europa]] (Munich: Willi Weismann, 1947) Tiessen, Heinz. Musik der Natur (Freiburg: Atlantis, 1953)',
#    'links': []},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co117460',
#    'metadata': {'mention': 'Dusseldorf', 'label': '@hc:entityLOC'},
#    'text': 'Collection of publications from the library of Dr. Ludwig Koch consisting of:  BBC Natural History Recordings (London: BBC, 1961) Berry, M.F. and Brock, D.W.E. Hunting by Ear (London: H.F. & G. Witherby, 1937). Chapuis, Alfred. Automates. Machines Automatiques et Machinisme (Geneva: Publications Techniques, 1928) Clark, Ronald W. The Huxleys (London:  Heinemann, 1968) Delamain, Jacques. Portraits D’Oiseaux (Paris: Editions Stock, 1938) Delépinne, Berthe. Elizabeth. Reine des Belges (Brussels: Willy Godenne, 1954) Holder, Artur. Leonard Bernstein (Berlin: Rembrandt, 1961) Howard, Len. Birds as Individuals (London: Collins, 1952) Huxley, Julian. At the Zoo (Woking: Unwin, 1936) Leakey, J.H. School Errant (London: Dulwich College Preparatory School, 1951)  MacDonald, Malcolm. The Birds of Brewery Creek (London: Oxford University Press, 1947) Michaelberten, Walter. Musik und Mikrophon ([[Dusseldorf]]: Schwann, 1951) Radio and Television Who’s Who, 1950-1951 (London: Vox Mundi, 1950) Raphaël, Samson. Pour Poser un Diagnostic (Brussels: Meddens, [no date]) Reiss, Curt. Knaurs Weltgeschichte der Schallplatte (Zurich: Droemersche, 1966) Seton-Thompson, Ernest. Wild Animals I Have Known (London: David Nutt, 1901) Silberman, Fred. Jungles and Skyscrapers (London: [no publisher], 1940) Stern-Rubarth, Edgar. Drei Männer suchen Europa (Munich: Willi Weismann, 1947) Tiessen, Heinz. Musik der Natur (Freiburg: Atlantis, 1953)',
#    'links': [{'title': 'Düsseldorf',
#      'url': 'https://en.wikipedia.org/wiki/Düsseldorf',
#      'score': 0.9999927282333374,
#      'qid': 'Q1718'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co117460',
#    'metadata': {'mention': 'Berlin', 'label': '@hc:entityLOC'},
#    'text': 'Collection of publications from the library of Dr. Ludwig Koch consisting of:  BBC Natural History Recordings (London: BBC, 1961) Berry, M.F. and Brock, D.W.E. Hunting by Ear (London: H.F. & G. Witherby, 1937). Chapuis, Alfred. Automates. Machines Automatiques et Machinisme (Geneva: Publications Techniques, 1928) Clark, Ronald W. The Huxleys (London:  Heinemann, 1968) Delamain, Jacques. Portraits D’Oiseaux (Paris: Editions Stock, 1938) Delépinne, Berthe. Elizabeth. Reine des Belges (Brussels: Willy Godenne, 1954) Holder, Artur. Leonard Bernstein ([[Berlin]]: Rembrandt, 1961) Howard, Len. Birds as Individuals (London: Collins, 1952) Huxley, Julian. At the Zoo (Woking: Unwin, 1936) Leakey, J.H. School Errant (London: Dulwich College Preparatory School, 1951)  MacDonald, Malcolm. The Birds of Brewery Creek (London: Oxford University Press, 1947) Michaelberten, Walter. Musik und Mikrophon (Dusseldorf: Schwann, 1951) Radio and Television Who’s Who, 1950-1951 (London: Vox Mundi, 1950) Raphaël, Samson. Pour Poser un Diagnostic (Brussels: Meddens, [no date]) Reiss, Curt. Knaurs Weltgeschichte der Schallplatte (Zurich: Droemersche, 1966) Seton-Thompson, Ernest. Wild Animals I Have Known (London: David Nutt, 1901) Silberman, Fred. Jungles and Skyscrapers (London: [no publisher], 1940) Stern-Rubarth, Edgar. Drei Männer suchen Europa (Munich: Willi Weismann, 1947) Tiessen, Heinz. Musik der Natur (Freiburg: Atlantis, 1953)',
#    'links': [{'title': 'Berlin',
#      'url': 'https://en.wikipedia.org/wiki/Berlin',
#      'score': 0.9997429251670837,
#      'qid': 'Q64'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co117460',
#    'metadata': {'mention': 'Freiburg', 'label': '@hc:entityLOC'},
#    'text': 'Collection of publications from the library of Dr. Ludwig Koch consisting of:  BBC Natural History Recordings (London: BBC, 1961) Berry, M.F. and Brock, D.W.E. Hunting by Ear (London: H.F. & G. Witherby, 1937). Chapuis, Alfred. Automates. Machines Automatiques et Machinisme (Geneva: Publications Techniques, 1928) Clark, Ronald W. The Huxleys (London:  Heinemann, 1968) Delamain, Jacques. Portraits D’Oiseaux (Paris: Editions Stock, 1938) Delépinne, Berthe. Elizabeth. Reine des Belges (Brussels: Willy Godenne, 1954) Holder, Artur. Leonard Bernstein (Berlin: Rembrandt, 1961) Howard, Len. Birds as Individuals (London: Collins, 1952) Huxley, Julian. At the Zoo (Woking: Unwin, 1936) Leakey, J.H. School Errant (London: Dulwich College Preparatory School, 1951)  MacDonald, Malcolm. The Birds of Brewery Creek (London: Oxford University Press, 1947) Michaelberten, Walter. Musik und Mikrophon (Dusseldorf: Schwann, 1951) Radio and Television Who’s Who, 1950-1951 (London: Vox Mundi, 1950) Raphaël, Samson. Pour Poser un Diagnostic (Brussels: Meddens, [no date]) Reiss, Curt. Knaurs Weltgeschichte der Schallplatte (Zurich: Droemersche, 1966) Seton-Thompson, Ernest. Wild Animals I Have Known (London: David Nutt, 1901) Silberman, Fred. Jungles and Skyscrapers (London: [no publisher], 1940) Stern-Rubarth, Edgar. Drei Männer suchen Europa (Munich: Willi Weismann, 1947) Tiessen, Heinz. Musik der Natur ([[Freiburg]]: Atlantis, 1953)',
#    'links': [{'title': 'Freiburg im Breisgau',
#      'url': 'https://en.wikipedia.org/wiki/Freiburg_im_Breisgau',
#      'score': 0.9922900795936584,
#      'qid': 'Q2833'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co117460',
#    'metadata': {'mention': 'Munich', 'label': '@hc:entityLOC'},
#    'text': 'Collection of publications from the library of Dr. Ludwig Koch consisting of:  BBC Natural History Recordings (London: BBC, 1961) Berry, M.F. and Brock, D.W.E. Hunting by Ear (London: H.F. & G. Witherby, 1937). Chapuis, Alfred. Automates. Machines Automatiques et Machinisme (Geneva: Publications Techniques, 1928) Clark, Ronald W. The Huxleys (London:  Heinemann, 1968) Delamain, Jacques. Portraits D’Oiseaux (Paris: Editions Stock, 1938) Delépinne, Berthe. Elizabeth. Reine des Belges (Brussels: Willy Godenne, 1954) Holder, Artur. Leonard Bernstein (Berlin: Rembrandt, 1961) Howard, Len. Birds as Individuals (London: Collins, 1952) Huxley, Julian. At the Zoo (Woking: Unwin, 1936) Leakey, J.H. School Errant (London: Dulwich College Preparatory School, 1951)  MacDonald, Malcolm. The Birds of Brewery Creek (London: Oxford University Press, 1947) Michaelberten, Walter. Musik und Mikrophon (Dusseldorf: Schwann, 1951) Radio and Television Who’s Who, 1950-1951 (London: Vox Mundi, 1950) Raphaël, Samson. Pour Poser un Diagnostic (Brussels: Meddens, [no date]) Reiss, Curt. Knaurs Weltgeschichte der Schallplatte (Zurich: Droemersche, 1966) Seton-Thompson, Ernest. Wild Animals I Have Known (London: David Nutt, 1901) Silberman, Fred. Jungles and Skyscrapers (London: [no publisher], 1940) Stern-Rubarth, Edgar. Drei Männer suchen Europa ([[Munich]]: Willi Weismann, 1947) Tiessen, Heinz. Musik der Natur (Freiburg: Atlantis, 1953)',
#    'links': [{'title': 'Munich',
#      'url': 'https://en.wikipedia.org/wiki/Munich',
#      'score': 0.9999984502792358,
#      'qid': 'Q1726'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co117460',
#    'metadata': {'mention': 'Brussels', 'label': '@hc:entityLOC'},
#    'text': 'Collection of publications from the library of Dr. Ludwig Koch consisting of:  BBC Natural History Recordings (London: BBC, 1961) Berry, M.F. and Brock, D.W.E. Hunting by Ear (London: H.F. & G. Witherby, 1937). Chapuis, Alfred. Automates. Machines Automatiques et Machinisme (Geneva: Publications Techniques, 1928) Clark, Ronald W. The Huxleys (London:  Heinemann, 1968) Delamain, Jacques. Portraits D’Oiseaux (Paris: Editions Stock, 1938) Delépinne, Berthe. Elizabeth. Reine des Belges ([[Brussels]]: Willy Godenne, 1954) Holder, Artur. Leonard Bernstein (Berlin: Rembrandt, 1961) Howard, Len. Birds as Individuals (London: Collins, 1952) Huxley, Julian. At the Zoo (Woking: Unwin, 1936) Leakey, J.H. School Errant (London: Dulwich College Preparatory School, 1951)  MacDonald, Malcolm. The Birds of Brewery Creek (London: Oxford University Press, 1947) Michaelberten, Walter. Musik und Mikrophon (Dusseldorf: Schwann, 1951) Radio and Television Who’s Who, 1950-1951 (London: Vox Mundi, 1950) Raphaël, Samson. Pour Poser un Diagnostic (Brussels: Meddens, [no date]) Reiss, Curt. Knaurs Weltgeschichte der Schallplatte (Zurich: Droemersche, 1966) Seton-Thompson, Ernest. Wild Animals I Have Known (London: David Nutt, 1901) Silberman, Fred. Jungles and Skyscrapers (London: [no publisher], 1940) Stern-Rubarth, Edgar. Drei Männer suchen Europa (Munich: Willi Weismann, 1947) Tiessen, Heinz. Musik der Natur (Freiburg: Atlantis, 1953)',
#    'links': [{'title': 'Brussels',
#      'url': 'https://en.wikipedia.org/wiki/Brussels',
#      'score': 0.9999544620513916,
#      'qid': 'Q240'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co117460',
#    'metadata': {'mention': 'Paris', 'label': '@hc:entityLOC'},
#    'text': 'Collection of publications from the library of Dr. Ludwig Koch consisting of:  BBC Natural History Recordings (London: BBC, 1961) Berry, M.F. and Brock, D.W.E. Hunting by Ear (London: H.F. & G. Witherby, 1937). Chapuis, Alfred. Automates. Machines Automatiques et Machinisme (Geneva: Publications Techniques, 1928) Clark, Ronald W. The Huxleys (London:  Heinemann, 1968) Delamain, Jacques. Portraits D’Oiseaux ([[Paris]]: Editions Stock, 1938) Delépinne, Berthe. Elizabeth. Reine des Belges (Brussels: Willy Godenne, 1954) Holder, Artur. Leonard Bernstein (Berlin: Rembrandt, 1961) Howard, Len. Birds as Individuals (London: Collins, 1952) Huxley, Julian. At the Zoo (Woking: Unwin, 1936) Leakey, J.H. School Errant (London: Dulwich College Preparatory School, 1951)  MacDonald, Malcolm. The Birds of Brewery Creek (London: Oxford University Press, 1947) Michaelberten, Walter. Musik und Mikrophon (Dusseldorf: Schwann, 1951) Radio and Television Who’s Who, 1950-1951 (London: Vox Mundi, 1950) Raphaël, Samson. Pour Poser un Diagnostic (Brussels: Meddens, [no date]) Reiss, Curt. Knaurs Weltgeschichte der Schallplatte (Zurich: Droemersche, 1966) Seton-Thompson, Ernest. Wild Animals I Have Known (London: David Nutt, 1901) Silberman, Fred. Jungles and Skyscrapers (London: [no publisher], 1940) Stern-Rubarth, Edgar. Drei Männer suchen Europa (Munich: Willi Weismann, 1947) Tiessen, Heinz. Musik der Natur (Freiburg: Atlantis, 1953)',
#    'links': [{'title': 'Paris',
#      'url': 'https://en.wikipedia.org/wiki/Paris',
#      'score': 0.9999856948852539,
#      'qid': 'Q90'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co117460',
#    'metadata': {'mention': 'the Zoo (Woking', 'label': '@hc:entityFAC'},
#    'text': 'Collection of publications from the library of Dr. Ludwig Koch consisting of:  BBC Natural History Recordings (London: BBC, 1961) Berry, M.F. and Brock, D.W.E. Hunting by Ear (London: H.F. & G. Witherby, 1937). Chapuis, Alfred. Automates. Machines Automatiques et Machinisme (Geneva: Publications Techniques, 1928) Clark, Ronald W. The Huxleys (London:  Heinemann, 1968) Delamain, Jacques. Portraits D’Oiseaux (Paris: Editions Stock, 1938) Delépinne, Berthe. Elizabeth. Reine des Belges (Brussels: Willy Godenne, 1954) Holder, Artur. Leonard Bernstein (Berlin: Rembrandt, 1961) Howard, Len. Birds as Individuals (London: Collins, 1952) Huxley, Julian. At [[the Zoo (Woking]]: Unwin, 1936) Leakey, J.H. School Errant (London: Dulwich College Preparatory School, 1951)  MacDonald, Malcolm. The Birds of Brewery Creek (London: Oxford University Press, 1947) Michaelberten, Walter. Musik und Mikrophon (Dusseldorf: Schwann, 1951) Radio and Television Who’s Who, 1950-1951 (London: Vox Mundi, 1950) Raphaël, Samson. Pour Poser un Diagnostic (Brussels: Meddens, [no date]) Reiss, Curt. Knaurs Weltgeschichte der Schallplatte (Zurich: Droemersche, 1966) Seton-Thompson, Ernest. Wild Animals I Have Known (London: David Nutt, 1901) Silberman, Fred. Jungles and Skyscrapers (London: [no publisher], 1940) Stern-Rubarth, Edgar. Drei Männer suchen Europa (Munich: Willi Weismann, 1947) Tiessen, Heinz. Musik der Natur (Freiburg: Atlantis, 1953)',
#    'links': [{'title': 'Woking',
#      'url': 'https://en.wikipedia.org/wiki/Woking',
#      'score': 0.9254078269004822,
#      'qid': 'Q646225'}]},
#   {'id': 'https://collection.sciencemuseumgroup.org.uk/objects/co117460',
#    'metadata': {'mention': 'Atlantis', 'label': '@hc:entityOBJECT'},
#    'text': 'Collection of publications from the library of Dr. Ludwig Koch consisting of:  BBC Natural History Recordings (London: BBC, 1961) Berry, M.F. and Brock, D.W.E. Hunting by Ear (London: H.F. & G. Witherby, 1937). Chapuis, Alfred. Automates. Machines Automatiques et Machinisme (Geneva: Publications Techniques, 1928) Clark, Ronald W. The Huxleys (London:  Heinemann, 1968) Delamain, Jacques. Portraits D’Oiseaux (Paris: Editions Stock, 1938) Delépinne, Berthe. Elizabeth. Reine des Belges (Brussels: Willy Godenne, 1954) Holder, Artur. Leonard Bernstein (Berlin: Rembrandt, 1961) Howard, Len. Birds as Individuals (London: Collins, 1952) Huxley, Julian. At the Zoo (Woking: Unwin, 1936) Leakey, J.H. School Errant (London: Dulwich College Preparatory School, 1951)  MacDonald, Malcolm. The Birds of Brewery Creek (London: Oxford University Press, 1947) Michaelberten, Walter. Musik und Mikrophon (Dusseldorf: Schwann, 1951) Radio and Television Who’s Who, 1950-1951 (London: Vox Mundi, 1950) Raphaël, Samson. Pour Poser un Diagnostic (Brussels: Meddens, [no date]) Reiss, Curt. Knaurs Weltgeschichte der Schallplatte (Zurich: Droemersche, 1966) Seton-Thompson, Ernest. Wild Animals I Have Known (London: David Nutt, 1901) Silberman, Fred. Jungles and Skyscrapers (London: [no publisher], 1940) Stern-Rubarth, Edgar. Drei Männer suchen Europa (Munich: Willi Weismann, 1947) Tiessen, Heinz. Musik der Natur (Freiburg: [[Atlantis]], 1953)',
#    'links': []}],
#  'threshold': 0.8,
#  'get_qids': True}

# %% [markdown]
# ## 3. A full wrapper around unlinked entities and BLINK

# %%
blink_service = BLINKServiceWrapper(
    endpoint,
    description_field = "data.http://www.w3.org/2001/XMLSchema#description", 
    entity_fields = entity_fields, 
    wiki_link_threshold=0.8
)

# %%
blink_service.process_unlinked_entity_mentions(output_path="./test_output.jsonl", page_size=5, limit=20)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
