# %% [markdown]
# # Analysing Unlinked Entities

# %%
import sys
sys.path.append("../../..")

from heritageconnector.utils.sparql import get_sparql_results
from heritageconnector.datastore import es

import pandas as pd
from IPython.display import display

# Wikifier
import requests
from urllib.parse import quote
import json

# analysing description samples (s3)
from tqdm.auto import tqdm
from collections import Counter
from heritageconnector.utils.generic import flatten_list_of_lists

# %%
endpoint = "http://63.33.68.17:3030/heritage-connector/sparql"

# %%
query = """
PREFIX hc: <http://www.heritageconnector.org/RDF/>

SELECT ?entityName ?p (COUNT(?entityName) AS ?nameCount) WHERE {
  {SELECT DISTINCT ?p WHERE{
     FILTER(STRSTARTS(STR(?p), "http://www.heritageconnector.org/RDF/entity")).
     FILTER(!STRENDS(STR(?p), "DATE")).
     FILTER(!STRENDS(STR(?p), "LANGUAGE")).
     FILTER(!STRENDS(STR(?p), "NORP")).
     # ?s ?p ?o.
    }
  }
  # ?subject ?p ?entityName.
  FILTER(!STRSTARTS(STR(?entityName), "http")).

} GROUP BY ?entityName ?p ORDER BY DESC(?nameCount) LIMIT 500
"""

def run_query(query):
    query_res_df = pd.json_normalize(get_sparql_results(endpoint, query)['results']['bindings'])
    query_res_df = query_res_df[[col for col in query_res_df.columns if col.endswith("value")]]
    query_res_df = query_res_df.rename(columns=lambda i: i.replace(".value", ""))
    
    return query_res_df
     
res = run_query(query)
res['p'] = res['p'].apply(lambda i: i.replace("http://www.heritageconnector.org/RDF/", ""))
res['nameCount'] = res['nameCount'].astype(int)

res
# Out:
#                         entityName             p  nameCount
# 0                           London     entityLOC      17315
# 1                          England     entityLOC       8809
# 2                            Glass  entityPERSON       7178
# 3               John Pollock & Co.     entityORG       4008
# 4                           Bronze  entityPERSON       3068
# ..                             ...           ...        ...
# 495                   Siebe Gorman  entityPERSON         71
# 496                      Sons Ltd.     entityORG         71
# 497                         Uganda     entityLOC         71
# 498  the Common Cold Research Unit   entityEVENT         71
# 499                    Alston Moor  entityPERSON         70
#
# [500 rows x 3 columns]

# %% [markdown]
# ## 1. Get Top 30 Unlinked Entities for each type

# %%
n = 30

for p in res.p.unique():
    display(res[res['p'] == p].sort_values('nameCount', ascending=False).head(n))
# Out:
#                   entityName          p  nameCount
# 0                     London  entityLOC      17315
# 1                    England  entityLOC       8809
# 5            London, England  entityLOC       2863
# 7                      Paris  entityLOC       2507
# 8                    Germany  entityLOC       1759
# 9                     France  entityLOC       1744
# 11                 Sheffield  entityLOC       1685
# 12                Birmingham  entityLOC       1677
# 13                Manchester  entityLOC       1584
# 14                    Europe  entityLOC       1537
# 15                     India  entityLOC       1205
# 18                 Liverpool  entityLOC        915
# 20                   Britain  entityLOC        860
# 21                      York  entityLOC        822
# 22                  Scotland  entityLOC        775
# 23                 Newcastle  entityLOC        731
# 25                 Edinburgh  entityLOC        706
# 26     North Eastern Railway  entityLOC        700
# 27                     Italy  entityLOC        697
# 29                     China  entityLOC        666
# 30                     Leeds  entityLOC        655
# 32             Paris, France  entityLOC        632
# 33                   Glasgow  entityLOC        615
# 34  Bradford, West Yorkshire  entityLOC        608
# 36            United Kingdom  entityLOC        583
# 37                     Spain  entityLOC        552
# 38                    Berlin  entityLOC        538
# 39                  New York  entityLOC        535
# 40                     Japan  entityLOC        512
# 43             United States  entityLOC        485
#                              entityName             p  nameCount
# 2                                 Glass  entityPERSON       7178
# 4                                Bronze  entityPERSON       3068
# 6                                Bottle  entityPERSON       2516
# 19                         Sarah Wilson  entityPERSON        910
# 28                                Roman  entityPERSON        694
# 42                        Eastman Kodak  entityPERSON        492
# 61             Patrick Stephens Limited  entityPERSON        390
# 64                                Mayer  entityPERSON        381
# 65                       Wellingborough  entityPERSON        378
# 67                     Laurence Olivier  entityPERSON        354
# 72                               S. Maw  entityPERSON        320
# 74                         Vivien Leigh  entityPERSON        306
# 81                     Edward Schunck's  entityPERSON        275
# 82                           Dimensions  entityPERSON        270
# 88                        Spencer Wells  entityPERSON        258
# 89                         John Andrews  entityPERSON        257
# 94                               Trocar  entityPERSON        248
# 98                              Meltzer  entityPERSON        240
# 114                                 Cap  entityPERSON        217
# 133                         H.W. Florey  entityPERSON        198
# 150                              C. Ash  entityPERSON        177
# 151                                Dean  entityPERSON        177
# 153                 Actien Gesellschaft  entityPERSON        174
# 159                                Ross  entityPERSON        172
# 160                          Down Bros.  entityPERSON        171
# 163                  Anilin Fabrikation  entityPERSON        168
# 164  H. H. Prince Nikita Alexandrovitch  entityPERSON        167
# 165                          Becca Hall  entityPERSON        166
# 167               Locomotive Worksplate  entityPERSON        166
# 175                             Curette  entityPERSON        157
#                                       entityName          p  nameCount
# 3                             John Pollock & Co.  entityORG       4008
# 16             London Midland & Scottish Railway  entityORG       1150
# 31                                    Lithograph  entityORG        638
# 35                             the Colour Museum  entityORG        599
# 41   Manchester Sheffield & Lincolnshire Railway  entityORG        501
# 45                                        Lancet  entityORG        468
# 48             the Russian Imperial Royal Family  entityORG        464
# 50                                Elkington & Co  entityORG        459
# 51                                  Ferranti Ltd  entityORG        439
# 52                         North Eastern Railway  entityORG        436
# 53                                       Mercury  entityORG        421
# 55                               Midland Railway  entityORG        407
# 56                                      Speculum  entityORG        406
# 57                                      Ferranti  entityORG        405
# 62                             Sforza collection  entityORG        383
# 66                     British Railway Companies  entityORG        360
# 68                       Wade Bequest collection  entityORG        345
# 71                            Hamonic collection  entityORG        334
# 73                                        Button  entityORG        306
# 76                                           Co.  entityORG        287
# 78                                       Railway  entityORG        286
# 79                                        Talbot  entityORG        285
# 80                                        Bausch  entityORG        275
# 90                         Great Eastern Railway  entityORG        256
# 95                the Health Education Authority  entityORG        248
# 96                                    Moore Ltd.  entityORG        245
# 99             the Royal Commission on Accidents  entityORG        240
# 102                   Burroughs Wellcome and Co.  entityORG        233
# 103                                 Barker & Co.  entityORG        231
# 105                                Grand Duchess  entityORG        231
#                entityName             p  nameCount
# 10                  Roman  entityOBJECT       1742
# 162               BR35014  entityOBJECT        169
# 195                  Lomb  entityOBJECT        147
# 458  The Non-Conformists'  entityOBJECT         76
# 468            Dimensions  entityOBJECT         74
#                     entityName          p  nameCount
# 17            Southern Railway  entityFAC        972
# 24       Great Western Railway  entityFAC        720
# 83      Great Northern Railway  entityFAC        269
# 100         Birmingham Railway  entityFAC        236
# 108            Midland Railway  entityFAC        224
# 120      Great Central Railway  entityFAC        212
# 129               Fleet Street  entityFAC        204
# 146         Manchester Railway  entityFAC        186
# 158      Great Eastern Railway  entityFAC        172
# 204            Belgrave Square  entityFAC        142
# 239  the Great Western Railway  entityFAC        130
# 244              Oxford Street  entityFAC        128
# 297           Carlisle Railway  entityFAC        107
# 302              Regent Street  entityFAC        106
# 332           Highland Railway  entityFAC         98
# 341         Manchester Airport  entityFAC         97
# 382    the Impressions Gallery  entityFAC         89
# 395              London Bridge  entityFAC         86
# 420         Caledonian Railway  entityFAC         81
# 442             Wigmore Street  entityFAC         78
# 451       the Southern Railway  entityFAC         77
# 470      North Eastern Railway  entityFAC         74
# 480      South Eastern Railway  entityFAC         73
#                                    entityName            p  nameCount
# 227  ICI Photography Awards (European Section  entityEVENT        134
# 258                       the First World War  entityEVENT        122
# 354                              World War II  entityEVENT         94
# 387                        the Herschel Album  entityEVENT         88
# 397                      the Second World War  entityEVENT         86
# 400                    ICI Photography Awards  entityEVENT         85
# 498             the Common Cold Research Unit  entityEVENT         71

# %% [markdown]
# ## 2. Try Wikifier for linking these entities

# %%
wikifier_endpoint = "http://www.wikifier.org/annotate-article?"
wikifier_userkey = "znmgsoqelkdxlhpznnyfplptrrjxnk"

# %%
def get_wikifier_results(text, ent_text_filter: str = None, min_pagerank = 0.015, min_linkprob = 0.8):

    payload=f'userKey={wikifier_userkey}&text={quote(text)}&lang=en&pageRankSqThreshold=0.015&applyPageRankSqThreshold=true&nWordsToIgnoreFromList=200&nTopDfValuesToIgnore=200'
    headers = {
      'Content-Type': 'application/x-www-form-urlencoded'
    }

    response = requests.request("POST", wikifier_endpoint, headers=headers, data=payload).json()['ranges']
    
    filtered_wikifier_res = []
    
    for item in response:
        for candidate in item['candidates']:
            if candidate['pageRank'] >= min_pagerank and candidate['linkProb'] >= min_linkprob:# and candidate['title'].lower() in text.lower():
                candidate.update({"wFrom": item["wFrom"], "wTo": item["wTo"], "wordsUsed": item["wordsUsed"]})
                filtered_wikifier_res.append(candidate)
    
    # ent_text_filter only keeps Wikipedia pages with titles with at least one token in common to the filter
    if ent_text_filter is not None:
        filtered_wikifier_res = [item for item in filtered_wikifier_res if set([i.lower() for i in item['wordsUsed']]).intersection(set(ent_text_filter.lower().split(" ")))]
                
    return filtered_wikifier_res

# text = "Bowman's suction curette, for soft cataract, plated metal and glass, on leather case, by John Weiss and Son, 287 Oxford Street, London, England, 1901-1930."
text = "First World War dressing, treated with cyanide, German"

wikifier_res = get_wikifier_results(text)

wikifier_res
# Out:
# [{'title': 'World War I',
#   'url': 'http://en.wikipedia.org/wiki/World_War_I',
#   'cosine': 0.1618937172520808,
#   'linkCount': 25623,
#   'pageRank': 0.06862261463189895,
#   'prbConfidence': 0.3274557393324211,
#   'linPr': 1,
#   'linkProb': 0.9960349854227405,
#   'logLinkProb': 0.9996438531377602,
#   'score2': 0.06862261463189895,
#   'isBestCand': True,
#   'wFrom': 0,
#   'wTo': 2,
#   'wordsUsed': ['First', 'World', 'War']},
#  {'title': 'Cyanide',
#   'url': 'http://en.wikipedia.org/wiki/Cyanide',
#   'cosine': 0.5082312238087592,
#   'linkCount': 668,
#   'pageRank': 0.03730919440121017,
#   'prbConfidence': 0.4171264401628262,
#   'linPr': 0.9913793103448276,
#   'linkProb': 0.9421720733427362,
#   'logLinkProb': 0.9921247368109379,
#   'score2': 0.03730919440121017,
#   'isBestCand': True,
#   'wFrom': 7,
#   'wTo': 7,
#   'wordsUsed': ['cyanide']}]

# %% [markdown]
# ## 3. Sample descriptions for unlinked entities and test Wikifier results
# - how accurate are they?
# - how homogeneous are they?

# %%
def get_descriptions(text: str, entity_predicate: str, n: int, random_seed: int = 42):
    query = {
        "query": { 
            "function_score": {
                "query": {
                    "match": {
                        f"graph.@hc:{entity_predicate}.@value.keyword": {
                            "query": text 
                        }
                    }
                },
                "random_score": {"seed": random_seed, "field": "_seq_no"},
            }
        }
    }
    
    res = es.search(
        index='heritageconnector',
        body=query,
        size=n
    )['hits']['hits']
    
    descriptions = [item['_source']['data']['http://www.w3.org/2001/XMLSchema#description'] for item in res]
    
    return descriptions

descriptions = get_descriptions("London", "entityLOC", 100)

len(descriptions), descriptions[0]
# Out:
# (100,
#  'Brass Gregorian reflecting telescope of 2 1/2-inch aperture by James Short, London [244/1063=9.6], on an altazimuth mounting with box foot stand made from telescope case containing 2 eyepieces, brass mirror box and accessories.')

# %%
def get_url_count_for_entity_mention(mention_text: str, entity_predicate: str, no_per_mention: str, random_seed: int = 42):
    mention_descriptions = get_descriptions(mention_text, entity_predicate, no_per_mention)
    
    mention_urls = {}

    for desc in mention_descriptions:
        wikifier_res = get_wikifier_results(desc, ent_text_filter=mention_text)

        if len(wikifier_res) > 0:
            mention_urls.update({desc: list(set([item['url'] for item in wikifier_res]))})
    
    return Counter(flatten_list_of_lists(mention_urls.values()))

get_url_count_for_entity_mention("London", "entityLOC", 5)
# Out:
# Counter({'http://en.wikipedia.org/wiki/London': 4})

# %%
top_n_per_predicate = 10

wikifier_counts_data = {}

for p in res.p.unique():
    print(f"---{p}---")
    wikifier_counts_data[p] = {}
    
    prop_df = res[res['p'] == p].sort_values('nameCount', ascending=False).head(top_n_per_predicate)
    
    for _, row in tqdm(prop_df.iterrows(), total=len(prop_df)):
        mention_count = get_url_count_for_entity_mention(row['entityName'], row['p'], no_per_mention=25)
        wikifier_counts_data[p][row["entityName"]] = mention_count
# Out:
# ---entityLOC---
#   0%|          | 0/10 [00:00<?, ?it/s]
# ---entityPERSON---
#   0%|          | 0/10 [00:00<?, ?it/s]
# ---entityORG---
#   0%|          | 0/10 [00:00<?, ?it/s]
# ---entityOBJECT---
#   0%|          | 0/5 [00:00<?, ?it/s]
# ---entityFAC---
#   0%|          | 0/10 [00:00<?, ?it/s]
# ---entityEVENT---
#   0%|          | 0/7 [00:00<?, ?it/s]

# %%
wikifier_counts_data
# Out:
# {'entityLOC': {'London': Counter({'http://en.wikipedia.org/wiki/London': 19,
#            'http://en.wikipedia.org/wiki/London_and_North_Eastern_Railway': 1,
#            'http://en.wikipedia.org/wiki/London_North_Eastern_Railway': 1,
#            'http://en.wikipedia.org/wiki/University_College_London': 1,
#            'http://en.wikipedia.org/wiki/Imperial_College_London': 1,
#            'http://en.wikipedia.org/wiki/Grosvenor_Square': 1,
#            'http://en.wikipedia.org/wiki/London_and_Birmingham_Railway': 1,
#            'http://en.wikipedia.org/wiki/%2elondon': 1,
#            'http://en.wikipedia.org/wiki/Strand,_London': 1}),
#   'England': Counter({'http://en.wikipedia.org/wiki/England': 23,
#            'http://en.wikipedia.org/wiki/Middlesex': 1,
#            'http://en.wikipedia.org/wiki/London': 3,
#            'http://en.wikipedia.org/wiki/Manchester': 6,
#            'http://en.wikipedia.org/wiki/Warwickshire': 1,
#            'http://en.wikipedia.org/wiki/Wembley': 1}),
#   'London, England': Counter({'http://en.wikipedia.org/wiki/London': 22,
#            'http://en.wikipedia.org/wiki/England': 22,
#            'http://en.wikipedia.org/wiki/Manchester': 4,
#            'http://en.wikipedia.org/wiki/Strand,_London': 1}),
#   'Paris': Counter({'http://en.wikipedia.org/wiki/Paris': 23,
#            'http://en.wikipedia.org/wiki/%2eparis': 2,
#            'http://en.wikipedia.org/wiki/Plaster': 1,
#            'http://en.wikipedia.org/wiki/National_Museum_of_Natural_History,_France': 1,
#            'http://en.wikipedia.org/wiki/University_of_Paris': 1,
#            'http://en.wikipedia.org/wiki/Rue_de_Rivoli': 1}),
#   'Germany': Counter({'http://en.wikipedia.org/wiki/Hanover': 1,
#            'http://en.wikipedia.org/wiki/Germany': 20,
#            'http://en.wikipedia.org/wiki/Schleswig-Holstein': 1,
#            'http://en.wikipedia.org/wiki/Elberfeld': 1}),
#   'France': Counter({'http://en.wikipedia.org/wiki/France': 24,
#            'http://en.wikipedia.org/wiki/Paris': 4}),
#   'Sheffield': Counter({'http://en.wikipedia.org/wiki/Sheffield': 24,
#            'http://en.wikipedia.org/wiki/Manchester,_Sheffield_and_Lincolnshire_Railway': 1}),
#   'Birmingham': Counter({'http://en.wikipedia.org/wiki/London_and_Birmingham_Railway': 1}),
#   'Manchester': Counter({'http://en.wikipedia.org/wiki/Manchester': 24,
#            'http://en.wikipedia.org/wiki/Manchester,_Connecticut': 1,
#            'http://en.wikipedia.org/wiki/Manchester,_Sheffield_and_Lincolnshire_Railway': 1}),
#   'Europe': Counter({'http://en.wikipedia.org/wiki/Europe': 22})},
#  'entityPERSON': {'Glass': Counter({'http://en.wikipedia.org/wiki/Jar': 1,
#            'http://en.wikipedia.org/wiki/Glass_harmonica': 1,
#            'http://en.wikipedia.org/wiki/Glass_bottle': 9,
#            'http://en.wikipedia.org/wiki/Glass': 1,
#            'http://en.wikipedia.org/wiki/Ocular_prosthesis': 1}),
#   'Bronze': Counter(),
#   'Bottle': Counter(),
#   'Sarah Wilson': Counter({'http://en.wikipedia.org/wiki/Sarah_Wilson_(war_correspondent)': 2}),
#   'Roman': Counter(),
#   'Eastman Kodak': Counter({'http://en.wikipedia.org/wiki/Kodak': 25}),
#   'Patrick Stephens Limited': Counter(),
#   'Mayer': Counter(),
#   'Wellingborough': Counter(),
#   'Laurence Olivier': Counter({'http://en.wikipedia.org/wiki/Laurence_Olivier': 24,
#            'http://en.wikipedia.org/wiki/Vivien_Leigh': 1})},
#  'entityORG': {'John Pollock & Co.': Counter(),
#   'London Midland & Scottish Railway': Counter({'http://en.wikipedia.org/wiki/London': 17,
#            'http://en.wikipedia.org/wiki/London,_Midland_and_Scottish_Railway': 23,
#            'http://en.wikipedia.org/wiki/Stratford,_London': 1,
#            'http://en.wikipedia.org/wiki/Rail_transport': 3,
#            'http://en.wikipedia.org/wiki/London_Midland': 1,
#            'http://en.wikipedia.org/wiki/Rail_transport_modelling': 2}),
#   'Lithograph': Counter({'http://en.wikipedia.org/wiki/Lithography': 17}),
#   'the Colour Museum': Counter({'http://en.wikipedia.org/wiki/Colour_Experience': 25}),
#   'Manchester Sheffield & Lincolnshire Railway': Counter({'http://en.wikipedia.org/wiki/Manchester': 25,
#            'http://en.wikipedia.org/wiki/Sheffield': 25,
#            'http://en.wikipedia.org/wiki/Manchester,_Sheffield_and_Lincolnshire_Railway': 25,
#            'http://en.wikipedia.org/wiki/Lincolnshire': 25,
#            'http://en.wikipedia.org/wiki/Manchester_Piccadilly_station': 1}),
#   'Lancet': Counter({'http://en.wikipedia.org/wiki/The_Lancet': 15}),
#   'the Russian Imperial Royal Family': Counter(),
#   'Elkington & Co': Counter({'http://en.wikipedia.org/wiki/London,_Midland_and_Scottish_Railway': 6,
#            'http://en.wikipedia.org/wiki/London_and_North_Western_Railway': 1,
#            'http://en.wikipedia.org/wiki/Glasgow_and_South_Western_Railway': 1,
#            'http://en.wikipedia.org/wiki/Cobalt': 1}),
#   'Ferranti Ltd': Counter({'http://en.wikipedia.org/wiki/Ferranti': 22}),
#   'North Eastern Railway': Counter({'http://en.wikipedia.org/wiki/North_Eastern_Railway_(United_Kingdom)': 20,
#            'http://en.wikipedia.org/wiki/Rail_transport': 14,
#            'http://en.wikipedia.org/wiki/London_and_North_Eastern_Railway': 4,
#            'http://en.wikipedia.org/wiki/Railway_Clearing_House': 1,
#            'http://en.wikipedia.org/wiki/Railroad_car': 3,
#            'http://en.wikipedia.org/wiki/Rail_transport_modelling': 2,
#            'http://en.wikipedia.org/wiki/North_Eastern_Railway_War_Memorial': 1,
#            'http://en.wikipedia.org/wiki/The_Railway_Magazine': 1})},
#  'entityOBJECT': {'Roman': Counter(),
#   'BR35014': Counter(),
#   'Lomb': Counter({'http://en.wikipedia.org/wiki/Bausch_%26_Lomb': 12}),
#   "The Non-Conformists'": Counter(),
#   'Dimensions': Counter({'http://en.wikipedia.org/wiki/Dimension': 2})},
#  'entityFAC': {'Southern Railway': Counter({'http://en.wikipedia.org/wiki/Rail_transport': 10,
#            'http://en.wikipedia.org/wiki/Rail_transport_modelling': 2,
#            'http://en.wikipedia.org/wiki/Southern_(Govia_Thameslink_Railway)': 4,
#            'http://en.wikipedia.org/wiki/Railroad_car': 1}),
#   'Great Western Railway': Counter({'http://en.wikipedia.org/wiki/Rail_transport': 19,
#            'http://en.wikipedia.org/wiki/Great_Western_Railway': 25,
#            'http://en.wikipedia.org/wiki/London,_Midland_and_Scottish_Railway': 1,
#            'http://en.wikipedia.org/wiki/Rail_transport_modelling': 2,
#            'http://en.wikipedia.org/wiki/Railway_signal': 1}),
#   'Great Northern Railway': Counter({'http://en.wikipedia.org/wiki/Great_Central_Railway': 1,
#            'http://en.wikipedia.org/wiki/Midland_Railway': 1,
#            'http://en.wikipedia.org/wiki/Rail_transport': 17,
#            'http://en.wikipedia.org/wiki/Great_Northern_Railway_(Great_Britain)': 4}),
#   'Birmingham Railway': Counter({'http://en.wikipedia.org/wiki/London_and_Birmingham_Railway': 24,
#            'http://en.wikipedia.org/wiki/Rail_transport': 1,
#            'http://en.wikipedia.org/wiki/London,_Midland_and_Scottish_Railway': 1}),
#   'Midland Railway': Counter({'http://en.wikipedia.org/wiki/Midland_Railway': 24,
#            'http://en.wikipedia.org/wiki/Rail_transport': 14,
#            'http://en.wikipedia.org/wiki/Great_Central_Railway': 1,
#            'http://en.wikipedia.org/wiki/London_and_North_Western_Railway': 1,
#            'http://en.wikipedia.org/wiki/Great_Western_Railway': 1,
#            'http://en.wikipedia.org/wiki/National_Railway_Museum': 1}),
#   'Great Central Railway': Counter({'http://en.wikipedia.org/wiki/Great_Central_Railway': 24,
#            'http://en.wikipedia.org/wiki/Midland_Railway': 1,
#            'http://en.wikipedia.org/wiki/Rail_transport': 12,
#            'http://en.wikipedia.org/wiki/Railroad_car': 2,
#            'http://en.wikipedia.org/wiki/Rail_transport_modelling': 2,
#            'http://en.wikipedia.org/wiki/Great_Central_Railway_(heritage_railway)': 1,
#            'http://en.wikipedia.org/wiki/North_Yorkshire_Moors_Railway': 1}),
#   'Fleet Street': Counter({'http://en.wikipedia.org/wiki/Fleet_Street': 19}),
#   'Manchester Railway': Counter({'http://en.wikipedia.org/wiki/Manchester': 18,
#            'http://en.wikipedia.org/wiki/Liverpool_and_Manchester_Railway': 24,
#            'http://en.wikipedia.org/wiki/Opening_of_the_Liverpool_and_Manchester_Railway': 1,
#            'http://en.wikipedia.org/wiki/Rail_transport': 3}),
#   'Great Eastern Railway': Counter({'http://en.wikipedia.org/wiki/Rail_transport': 18,
#            'http://en.wikipedia.org/wiki/Great_Eastern_Railway': 24,
#            'http://en.wikipedia.org/wiki/Midland_and_Great_Northern_Joint_Railway': 1}),
#   'Belgrave Square': Counter({'http://en.wikipedia.org/wiki/Belgrave_Square': 25})},
#  'entityEVENT': {'ICI Photography Awards (European Section': Counter({'http://en.wikipedia.org/wiki/Photography': 13,
#            'http://en.wikipedia.org/wiki/Imperial_Chemical_Industries': 24}),
#   'the First World War': Counter({'http://en.wikipedia.org/wiki/World_War_I': 13,
#            'http://en.wikipedia.org/wiki/Royal_Air_Force': 1,
#            'http://en.wikipedia.org/wiki/Admiralty': 1}),
#   'World War II': Counter({'http://en.wikipedia.org/wiki/World_War_II': 20,
#            'http://en.wikipedia.org/wiki/Pacific_War': 1,
#            'http://en.wikipedia.org/wiki/War_Agricultural_Executive_Committee': 1}),
#   'the Herschel Album': Counter({'http://en.wikipedia.org/wiki/John_Herschel': 24}),
#   'the Second World War': Counter({'http://en.wikipedia.org/wiki/World_War_II': 15,
#            'http://en.wikipedia.org/wiki/War_Office': 1,
#            'http://en.wikipedia.org/wiki/BBC': 1}),
#   'ICI Photography Awards': Counter({'http://en.wikipedia.org/wiki/Imperial_Chemical_Industries': 20,
#            'http://en.wikipedia.org/wiki/Photography': 6}),
#   'the Common Cold Research Unit': Counter({'http://en.wikipedia.org/wiki/Research': 6,
#            'http://en.wikipedia.org/wiki/Common_cold': 2})}}

# %%
import json

# with open('unlinked entities analysis.json', 'w') as f:
#     json.dump(wikifier_counts_data, f)

# %%
json.dumps({
    "text": "text_doc",
    "spans": [(41, 16)]
}
)
# Out:
# '{"text": "text_doc", "spans": [[41, 16]]}'
