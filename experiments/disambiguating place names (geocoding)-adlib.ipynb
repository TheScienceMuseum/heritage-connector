# %%
# !pip install geocoder
# Out:
# Collecting geocoder
#   Downloading geocoder-1.38.1-py2.py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 934 kB/s eta 0:00:011
# Requirement already satisfied: click in /Users/kalyan/.pyenv/versions/3.9.1/envs/hc/lib/python3.9/site-packages (from geocoder) (7.1.2)
# Requirement already satisfied: requests in /Users/kalyan/.pyenv/versions/3.9.1/envs/hc/lib/python3.9/site-packages (from geocoder) (2.24.0)
# Requirement already satisfied: six in /Users/kalyan/.pyenv/versions/3.9.1/envs/hc/lib/python3.9/site-packages (from geocoder) (1.15.0)
# Collecting future
#   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 1.3 MB/s eta 0:00:01
# Collecting ratelim
#   Downloading ratelim-0.1.6-py2.py3-none-any.whl (4.0 kB)
# Requirement already satisfied: decorator in /Users/kalyan/.pyenv/versions/3.9.1/envs/hc/lib/python3.9/site-packages (from ratelim->geocoder) (4.4.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kalyan/.pyenv/versions/3.9.1/envs/hc/lib/python3.9/site-packages (from requests->geocoder) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/kalyan/.pyenv/versions/3.9.1/envs/hc/lib/python3.9/site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/kalyan/.pyenv/versions/3.9.1/envs/hc/lib/python3.9/site-packages (from requests->geocoder) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/kalyan/.pyenv/versions/3.9.1/envs/hc/lib/python3.9/site-packages (from requests->geocoder) (1.25.11)
# Building wheels for collected packages: future
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491059 sha256=593e0236bb42dbf74ad8c12c62ca7e7d306c38f92dc6de42e4922183318a3b30
#   Stored in directory: /Users/kalyan/Library/Caches/pip/wheels/2f/a0/d3/4030d9f80e6b3be787f19fc911b8e7aa462986a40ab1e4bb94
# Successfully built future
# Installing collected packages: ratelim, future, geocoder
# Successfully installed future-0.18.2 geocoder-1.38.1 ratelim-0.1.6
# WARNING: You are using pip version 20.3.3; however, version 21.1.1 is available.
# You should consider upgrading via the '/Users/kalyan/.pyenv/versions/3.9.1/envs/hc/bin/python -m pip install --upgrade pip' command.

# %%
import sys
sys.path.append("..")

from heritageconnector.utils.generic import paginate_list

import geocoder
import pandas as pd
from collections import Counter
from tqdm.auto import tqdm

tqdm.pandas()
# Out:
# /Users/kalyan/.pyenv/versions/3.9.1/envs/hc/lib/python3.9/site-packages/tqdm/std.py:702: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
def get_id_and_countryid(loc: str):
    g = geocoder.geonames(loc, key='heritageconnector')

    if g.error:
        raise Exception(f"Rate limit met. {g.error}")

    try:
        address = g.json.get('address', None)
        # found label must be in requested label
        # the API sometimes does weird things like 'sussex' -> 'eastbourne'
        assert address.lower() in loc.lower()
    except:
        # try disambiguating one level up e.g. "debden, essex, england" -> "essex, england"
        if "," in loc:
            loc = ", ".join(loc.split(", ")[1:])
            return get_id_and_countryid(loc)
        else:
            return {}
        
    return {"name": loc, "geonames_address":address, "geonames_id": g.geonames_id, "country_id": g.json.get('raw', {}).get('countryId', None)}

# %% [markdown]
# ## 1. Create place names dataframe and save to disk

# %%
df = pd.read_csv("../GITIGNORE_DATA/adlib-people-dump.csv")
df.columns
# Out:
# Index(['status', 'description.0.type', 'description.0.value',
#        'deduplication.0.value', 'deduplication.0.rule', 'admin.added',
#        'admin.uid', 'admin.stream', 'admin.created', 'admin.modified',
#        'admin.previous_status', 'admin.source', 'admin.version',
#        'admin.processed', 'admin.id', 'admin.uuid', 'type.base', 'type.type',
#        'conformance', 'summary_title', 'name.0.note.0.value', 'name.0.type',
#        'name.0.primary', 'name.0.value', 'name.0.last_name',
#        'address.0.street_address', 'gender', 'name.0.first_name',
#        'nationality.0', 'lifecycle.death.0.date.0.earliest',
#        'lifecycle.death.0.date.0.value', 'lifecycle.death.0.date.0.latest',
#        'name.0.title_prefix', 'identifier.0.source', 'identifier.0.value',
#        'lifecycle.birth.0.date.0.earliest', 'lifecycle.birth.0.date.0.value',
#        'lifecycle.birth.0.date.0.latest', 'admin.analytics.count.total',
#        'use.0.admin.uuid', 'use.0.admin.id', 'use.0.admin.uid',
#        'use.0.@link.type', 'use.0.summary_title', 'address.0.postcode',
#        'address.1.postcode', 'address.1.street_address', 'name.0.note.0.type',
#        'name.0.note.1.value', 'lifecycle.death.0.note.0.value',
#        'lifecycle.birth.0.place.0.admin.id',
#        'lifecycle.birth.0.place.0.admin.uuid',
#        'lifecycle.birth.0.place.0.@link.type',
#        'lifecycle.birth.0.place.0.summary_title',
#        'lifecycle.birth.0.place.0.name.0.primary',
#        'lifecycle.birth.0.place.0.name.0.value',
#        'lifecycle.death.0.date.0.to.earliest',
#        'lifecycle.death.0.date.0.to.value',
#        'lifecycle.death.0.date.0.to.latest', 'lifecycle.death.0.date.0.range',
#        'lifecycle.death.0.date.0.from.earliest',
#        'lifecycle.death.0.date.0.from.value',
#        'lifecycle.death.0.date.0.from.latest',
#        'lifecycle.death.0.place.0.admin.id',
#        'lifecycle.death.0.place.0.admin.uuid',
#        'lifecycle.death.0.place.0.@link.type',
#        'lifecycle.death.0.place.0.summary_title',
#        'lifecycle.death.0.place.0.name.0.primary',
#        'lifecycle.death.0.place.0.name.0.value', 'admin.analytics.count.last',
#        'address.2.street_address', 'lifecycle.birth.0.note.0.value',
#        'contact.telephone.0.value', 'nationality.1', 'address.2.postcode',
#        'identifier.1.source', 'identifier.1.value', 'identifier.2.source',
#        'identifier.2.value', 'lifecycle.birth.0.date.0.to.earliest',
#        'lifecycle.birth.0.date.0.to.value',
#        'lifecycle.birth.0.date.0.to.latest', 'lifecycle.birth.0.date.0.range',
#        'lifecycle.birth.0.date.0.from.earliest',
#        'lifecycle.birth.0.date.0.from.value',
#        'lifecycle.birth.0.date.0.from.latest', 'contact.telephone.1.value',
#        'identifier.1.type', 'identifier.0.type'],
#       dtype='object')

# %%
def process_place_name(loc):
    """Split by semicolon and return unique values"""
    if isinstance(loc, str):
        loc = loc.lower()
    
    if str(loc) == "nan":
        return loc
    else:
        split = loc.split("; ")
        return list(set(split))

df["lifecycle.birth.0.place.0.summary_title_list"] = df["lifecycle.birth.0.place.0.summary_title"].apply(process_place_name)
df["lifecycle.death.0.place.0.summary_title_list"] = df["lifecycle.death.0.place.0.summary_title"].apply(process_place_name)

# %%
places_counts = Counter(df['lifecycle.birth.0.place.0.summary_title_list'].dropna().sum() + df['lifecycle.death.0.place.0.summary_title_list'].dropna().sum())
places_unique = list(places_counts.keys())
len(places_counts)
# Out:
# 219

# %%
places_df = pd.DataFrame(pd.Series(places_counts).sort_values(ascending=False) / sum(places_counts.values()) * 100).reset_index().rename(columns={'index': 'place name', 0: '% collection'})
places_df.head()
# Out:
#    place name  % collection
# 0      london     18.000000
# 1  manchester      7.333333
# 2     salford      2.000000
# 3     glasgow      1.555556
# 4      surrey      1.555556

# %%
percentage_cumulative = places_df["% collection"].cumsum()

def no_records_to_reach_percent(percent):
    return percentage_cumulative[percentage_cumulative > percent].index.min()

for p in [50, 75, 85, 95, 99]:
    n = no_records_to_reach_percent(p)
    print(f"{n} ({int(n/len(places_df)*100)}%) records required to reach {p}%")
# Out:
# 26 (11%) records required to reach 50%
# 106 (48%) records required to reach 75%
# 151 (68%) records required to reach 85%
# 196 (89%) records required to reach 95%
# 214 (97%) records required to reach 99%

# %%
places_df.to_pickle("../GITIGNORE_DATA/adlib_places_disambiguation.pkl")

# %% [markdown]
# ## 2. Load place names dataframe from disk and fill
# We have to this in chunks as the geonames API has a rate limit of 1000 queries per hour.

# %%
places_df = pd.read_pickle("../GITIGNORE_DATA/adlib_places_disambiguation.pkl")
idx_paginated = paginate_list(places_df.index.tolist(), 300)

df_pages_list = [places_df.loc[page] for page in idx_paginated]

print(len(df_pages_list))
df_pages_list[0]
# Out:
# 1
#      place name  % collection
# 0        london     18.000000
# 1    manchester      7.333333
# 2       salford      2.000000
# 3       glasgow      1.555556
# 4        surrey      1.555556
# ..          ...           ...
# 214       cairo      0.222222
# 215    new york      0.222222
# 216        bury      0.222222
# 217     chester      0.222222
# 218        oxon      0.222222
#
# [219 rows x 2 columns]

# %%
places_df.to_csv("../GITIGNORE_DATA/adlib_placenames_to_qids.csv")

# %%
PAGE_NO = 0

df_page = df_pages_list[PAGE_NO]
df_page['result'] = ""
df_page['result'] = df_page['result'].astype(object)

for idx, row in tqdm(df_page.iterrows(), total=len(df_page)):
    df_page.at[idx, "result"] = get_id_and_countryid(df_page.loc[idx, "place name"])
# Out:
#   0%|          | 0/219 [00:00<?, ?it/s]
# Status code Unknown from http://api.geonames.org/searchJSON: ERROR - HTTPConnectionPool(host='api.geonames.org', port=80): Read timed out. (read timeout=5.0)
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-13-a4701160bf46> in <module>
#       6
#       7 for idx, row in tqdm(df_page.iterrows(), total=len(df_page)):
# ----> 8     df_page.at[idx, "result"] = get_id_and_countryid(df_page.loc[idx, "place name"])
#
# <ipython-input-4-a198c788e061> in get_id_and_countryid(loc)
#       3
#       4     if g.error:
# ----> 5         raise Exception(f"Rate limit met. {g.error}")
#       6
#       7     try:
#
# Exception: Rate limit met. ERROR - HTTPConnectionPool(host='api.geonames.org', port=80): Read timed out. (read timeout=5.0)

# %%
df_page = pd.concat([df_page, df_page['result'].apply(pd.Series)], axis=1)

df_page.drop(columns='result')
# Out:
#      place name  % collection    0 country_id geonames_address  geonames_id  \
# 0        london     18.000000  NaN    2635167           London    2643743.0
# 1    manchester      7.333333  NaN        NaN              NaN          NaN
# 2       salford      2.000000  NaN    2635167          Salford    2638671.0
# 3       glasgow      1.555556  NaN    2635167          Glasgow    2648579.0
# 4        surrey      1.555556  NaN        NaN              NaN          NaN
# ..          ...           ...  ...        ...              ...          ...
# 214       cairo      0.222222             NaN              NaN          NaN
# 215    new york      0.222222             NaN              NaN          NaN
# 216        bury      0.222222             NaN              NaN          NaN
# 217     chester      0.222222             NaN              NaN          NaN
# 218        oxon      0.222222             NaN              NaN          NaN
#
#         name
# 0     london
# 1        NaN
# 2    salford
# 3    glasgow
# 4        NaN
# ..       ...
# 214      NaN
# 215      NaN
# 216      NaN
# 217      NaN
# 218      NaN
#
# [219 rows x 7 columns]

# %%
# df_page.drop(columns='result').to_csv("./places/5.csv")

# %% [markdown]
# ## 3. Reconcile geonames IDs to Wikidata entities

# %%
from heritageconnector.utils.generic import paginate_list
from heritageconnector.utils.wikidata import get_sparql_results
from heritageconnector.config import config

# %%
results = pd.read_csv("./places/0_to_5.csv", index_col=0)
results[['geonames_id', 'country_id']] = results[['geonames_id', 'country_id']].applymap(lambda i: int(i) if not pd.isna(i) else i)
results.head()
# Out:
#                                           place name  % collection  \
# 0    london, greater london, england, united kingdom     16.353221
# 1                            england, united kingdom      8.322525
# 2                                     united kingdom      4.790470
# 3                                             france      4.418350
# 4  manchester, manchester urban district, greater...      4.233834
#
#                                               name    geonames_address  \
# 0  london, greater london, england, united kingdom              London
# 1                                   united kingdom      United Kingdom
# 2                                   united kingdom      United Kingdom
# 3                                           france              France
# 4      greater manchester, england, united kingdom  Greater Manchester
#
#    geonames_id  country_id
# 0    2643743.0   2635167.0
# 1    2635167.0   2635167.0
# 2    2635167.0   2635167.0
# 3    3017382.0   3017382.0
# 4    2648108.0   2635167.0

# %%
geonames_ids = list(set(results.geonames_id.dropna().tolist() + results.country_id.dropna().tolist()))
geonames_ids = [int(i) for i in geonames_ids]
len(geonames_ids)
# Out:
# 1137

# %%
geonames_paginated = paginate_list(geonames_ids, 100)
geoname_wikidata_mapping = {}

# %%
make_geonames_list = lambda l: " ".join([f""" "{item}" """ for item in l])

for page in tqdm(geonames_paginated):
    query = f"""SELECT * WHERE {{
      VALUES ?geonames_id {{{make_geonames_list(page)}}}.
      # ?qid wdt:P1566 ?geonames_id .  
    }}
    """

    for item in get_sparql_results(config.WIKIDATA_SPARQL_ENDPOINT, query)['results']['bindings']:
        geoname_wikidata_mapping.update({item['geonames_id']['value']: item['qid']['value']})
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=12.0), HTML(value='')))

# %%
geoname_wikidata_mapping
# Out:
# {'1605651': 'http://www.wikidata.org/entity/Q869',
#  '2652221': 'http://www.wikidata.org/entity/Q6225',
#  '3489854': 'http://www.wikidata.org/entity/Q34692',
#  '1257592': 'http://www.wikidata.org/entity/Q117196',
#  '878675': 'http://www.wikidata.org/entity/Q954',
#  '6457407': 'http://www.wikidata.org/entity/Q202174',
#  '2168866': 'http://www.wikidata.org/entity/Q28224086',
#  '149590': 'http://www.wikidata.org/entity/Q924',
#  '2650228': 'http://www.wikidata.org/entity/Q149651',
#  '614540': 'http://www.wikidata.org/entity/Q230',
#  '163843': 'http://www.wikidata.org/entity/Q858',
#  '3174530': 'http://www.wikidata.org/entity/Q3969986',
#  '2654312': 'http://www.wikidata.org/entity/Q2019274',
#  '2637918': 'http://www.wikidata.org/entity/Q1027127',
#  '3033123': 'http://www.wikidata.org/entity/Q37776',
#  '2838632': 'http://www.wikidata.org/entity/Q1194',
#  '5101717': 'http://www.wikidata.org/entity/Q138338',
#  '352260': 'http://www.wikidata.org/entity/Q463871',
#  '2646057': 'http://www.wikidata.org/entity/Q184775',
#  '2969679': 'http://www.wikidata.org/entity/Q621',
#  '5410952': 'http://www.wikidata.org/entity/Q180402',
#  '2637853': 'http://www.wikidata.org/entity/Q995647',
#  '2973783': 'http://www.wikidata.org/entity/Q6602',
#  '2938913': 'http://www.wikidata.org/entity/Q32067893',
#  '2629691': 'http://www.wikidata.org/entity/Q189',
#  '2635785': 'http://www.wikidata.org/entity/Q1684337',
#  '2652204': 'http://www.wikidata.org/entity/Q587996',
#  '2656402': 'http://www.wikidata.org/entity/Q54809',
#  '2639996': 'http://www.wikidata.org/entity/Q72259',
#  '6690877': 'http://www.wikidata.org/entity/Q146690',
#  '2646088': 'http://www.wikidata.org/entity/Q160493',
#  '2633749': 'http://www.wikidata.org/entity/Q1861278',
#  '6690829': 'http://www.wikidata.org/entity/Q2321706',
#  '8128646': 'http://www.wikidata.org/entity/Q2407244',
#  '2650236': 'http://www.wikidata.org/entity/Q3047556',
#  '3489940': 'http://www.wikidata.org/entity/Q766',
#  '2963597': 'http://www.wikidata.org/entity/Q27',
#  '2654225': 'http://www.wikidata.org/entity/Q1857589',
#  '1816670': 'http://www.wikidata.org/entity/Q956',
#  '2017370': 'http://www.wikidata.org/entity/Q159',
#  '2654264': 'http://www.wikidata.org/entity/Q209096',
#  '3170336': 'http://www.wikidata.org/entity/Q43332',
#  '3014728': 'http://www.wikidata.org/entity/Q1289',
#  '2633771': 'http://www.wikidata.org/entity/Q1012031',
#  '2658434': 'http://www.wikidata.org/entity/Q39',
#  '2644120': 'http://www.wikidata.org/entity/Q996492',
#  '2637825': 'http://www.wikidata.org/entity/Q2695621',
#  '2633883': 'http://www.wikidata.org/entity/Q2011497',
#  '2648154': 'http://www.wikidata.org/entity/Q948813',
#  '2639912': 'http://www.wikidata.org/entity/Q184090',
#  '2648208': 'http://www.wikidata.org/entity/Q846683',
#  '2650225': 'http://www.wikidata.org/entity/Q23436',
#  '3172394': 'http://www.wikidata.org/entity/Q49295418',
#  '2633858': 'http://www.wikidata.org/entity/Q172157',
#  '2648108': 'http://www.wikidata.org/entity/Q23099',
#  '2633866': 'http://www.wikidata.org/entity/Q736742',
#  '2652222': 'http://www.wikidata.org/entity/Q55019',
#  '6690827': 'http://www.wikidata.org/entity/Q2144907',
#  '5509151': 'http://www.wikidata.org/entity/Q1227',
#  '2641942': 'http://www.wikidata.org/entity/Q37718',
#  '2656284': 'http://www.wikidata.org/entity/Q54212',
#  '2656406': 'http://www.wikidata.org/entity/Q806160',
#  '2639928': 'http://www.wikidata.org/entity/Q1976655',
#  '2633810': 'http://www.wikidata.org/entity/Q2011679',
#  '2797656': 'http://www.wikidata.org/entity/Q31590146',
#  '2648187': 'http://www.wikidata.org/entity/Q676689',
#  '2949186': 'http://www.wikidata.org/entity/Q31912389',
#  '1796236': 'http://www.wikidata.org/entity/Q8686',
#  '2998286': 'http://www.wikidata.org/entity/Q45656',
#  '2644021': 'http://www.wikidata.org/entity/Q1002793',
#  '2644128': 'http://www.wikidata.org/entity/Q13644928',
#  '2656333': 'http://www.wikidata.org/entity/Q377720',
#  '2652191': 'http://www.wikidata.org/entity/Q1953777',
#  '2648215': 'http://www.wikidata.org/entity/Q617845',
#  '2656397': 'http://www.wikidata.org/entity/Q234178',
#  '2654308': 'http://www.wikidata.org/entity/Q1014934',
#  '2639970': 'http://www.wikidata.org/entity/Q19775',
#  '2945024': 'http://www.wikidata.org/entity/Q32067886',
#  '4843564': 'http://www.wikidata.org/entity/Q49169',
#  '2656281': 'http://www.wikidata.org/entity/Q808532',
#  '2644100': 'http://www.wikidata.org/entity/Q990125',
#  '6690869': 'http://www.wikidata.org/entity/Q1058698',
#  '7290958': 'http://www.wikidata.org/entity/Q5137172',
#  '11610205': 'http://www.wikidata.org/entity/Q11790843',
#  '6690865': 'http://www.wikidata.org/entity/Q5639401',
#  '11550821': 'http://www.wikidata.org/entity/Q880829',
#  '2510911': 'http://www.wikidata.org/entity/Q55893348',
#  '4055067': 'http://www.wikidata.org/entity/Q111266',
#  '6555780': 'http://www.wikidata.org/entity/Q550693',
#  '2656295': 'http://www.wikidata.org/entity/Q2884709',
#  '7295064': 'http://www.wikidata.org/entity/Q24665308',
#  '2633842': 'http://www.wikidata.org/entity/Q464955',
#  '2637891': 'http://www.wikidata.org/entity/Q201970',
#  '6690817': 'http://www.wikidata.org/entity/Q146849',
#  '6690866': 'http://www.wikidata.org/entity/Q2453259',
#  '366755': 'http://www.wikidata.org/entity/Q1049',
#  '6254926': 'http://www.wikidata.org/entity/Q771',
#  '2953504': 'http://www.wikidata.org/entity/Q4100',
#  '4436296': 'http://www.wikidata.org/entity/Q1494',
#  '4954380': 'http://www.wikidata.org/entity/Q49190',
#  '51537': 'http://www.wikidata.org/entity/Q1045',
#  '2640091': 'http://www.wikidata.org/entity/Q248173',
#  '2654539': 'http://www.wikidata.org/entity/Q267054',
#  '2644208': 'http://www.wikidata.org/entity/Q801124',
#  '2656594': 'http://www.wikidata.org/entity/Q789348',
#  '2648372': 'http://www.wikidata.org/entity/Q909146',
#  '6947041': 'http://www.wikidata.org/entity/Q880861',
#  '2646316': 'http://www.wikidata.org/entity/Q967166',
#  '2646272': 'http://www.wikidata.org/entity/Q1020951',
#  '2654545': 'http://www.wikidata.org/entity/Q990677',
#  '2640140': 'http://www.wikidata.org/entity/Q7227719',
#  '2145234': 'http://www.wikidata.org/entity/Q36687',
#  '2636049': 'http://www.wikidata.org/entity/Q1026304',
#  '1278253': 'http://www.wikidata.org/entity/Q1164',
#  '2990440': 'http://www.wikidata.org/entity/Q33959',
#  '1562822': 'http://www.wikidata.org/entity/Q881',
#  '2650396': 'http://www.wikidata.org/entity/Q731069',
#  '2363686': 'http://www.wikidata.org/entity/Q945',
#  '2650386': 'http://www.wikidata.org/entity/Q207257',
#  '2642149': 'http://www.wikidata.org/entity/Q6915606',
#  '2644210': 'http://www.wikidata.org/entity/Q24826',
#  '3029162': 'http://www.wikidata.org/entity/Q6454',
#  '3688689': 'http://www.wikidata.org/entity/Q2841',
#  '3369157': 'http://www.wikidata.org/entity/Q5465',
#  '3451190': 'http://www.wikidata.org/entity/Q8678',
#  '2638077': 'http://www.wikidata.org/entity/Q42448',
#  '2646325': 'http://www.wikidata.org/entity/Q123738',
#  '3932488': 'http://www.wikidata.org/entity/Q419',
#  '3166548': 'http://www.wikidata.org/entity/Q49280771',
#  '2650278': 'http://www.wikidata.org/entity/Q2342197',
#  '2633948': 'http://www.wikidata.org/entity/Q208143',
#  '2640194': 'http://www.wikidata.org/entity/Q43382',
#  '1880251': 'http://www.wikidata.org/entity/Q334',
#  '1880252': 'http://www.wikidata.org/entity/Q49755161',
#  '1642673': 'http://www.wikidata.org/entity/Q3757',
#  '2642182': 'http://www.wikidata.org/entity/Q736785',
#  '2633954': 'http://www.wikidata.org/entity/Q1022741',
#  '2636062': 'http://www.wikidata.org/entity/Q954764',
#  '2640045': 'http://www.wikidata.org/entity/Q950671',
#  '8468728': 'http://www.wikidata.org/entity/Q155921',
#  '7293141': 'http://www.wikidata.org/entity/Q24662957',
#  '2654409': 'http://www.wikidata.org/entity/Q42182',
#  '11591953': 'http://www.wikidata.org/entity/Q48038',
#  '2640101': 'http://www.wikidata.org/entity/Q203349',
#  '2636101': 'http://www.wikidata.org/entity/Q614560',
#  '2644319': 'http://www.wikidata.org/entity/Q990112',
#  '2648258': 'http://www.wikidata.org/entity/Q1414040',
#  '2642096': 'http://www.wikidata.org/entity/Q1612169',
#  '2638047': 'http://www.wikidata.org/entity/Q2694932',
#  '1270101': 'http://www.wikidata.org/entity/Q1177',
#  '2642214': 'http://www.wikidata.org/entity/Q985279',
#  '2652437': 'http://www.wikidata.org/entity/Q2080364',
#  '2650405': 'http://www.wikidata.org/entity/Q654226',
#  '2646327': 'http://www.wikidata.org/entity/Q2080165',
#  '2648404': 'http://www.wikidata.org/entity/Q170497',
#  '6269133': 'http://www.wikidata.org/entity/Q7204',
#  '2593105': 'http://www.wikidata.org/entity/Q26253',
#  '2633939': 'http://www.wikidata.org/entity/Q9679',
#  '3831997': 'http://www.wikidata.org/entity/Q16580129',
#  '2654500': 'http://www.wikidata.org/entity/Q990947',
#  '2652464': 'http://www.wikidata.org/entity/Q1125738',
#  '2640132': 'http://www.wikidata.org/entity/Q1009235',
#  '6254930': 'http://www.wikidata.org/entity/Q407199',
#  '2650470': 'http://www.wikidata.org/entity/Q302893',
#  '4155751': 'http://www.wikidata.org/entity/Q812',
#  '6254925': 'http://www.wikidata.org/entity/Q1603',
#  '1694008': 'http://www.wikidata.org/entity/Q928',
#  '2328926': 'http://www.wikidata.org/entity/Q1033',
#  '5101798': 'http://www.wikidata.org/entity/Q25395',
#  '2633907': 'http://www.wikidata.org/entity/Q146702',
#  '2636032': 'http://www.wikidata.org/entity/Q237250',
#  '2634021': 'http://www.wikidata.org/entity/Q964785',
#  '2648280': 'http://www.wikidata.org/entity/Q5586936',
#  '5122365': 'http://www.wikidata.org/entity/Q2640064',
#  '6690989': 'http://www.wikidata.org/entity/Q124204',
#  '2646277': 'http://www.wikidata.org/entity/Q2297044',
#  '2642233': 'http://www.wikidata.org/entity/Q3323858',
#  '2636083': 'http://www.wikidata.org/entity/Q1248924',
#  '5667009': 'http://www.wikidata.org/entity/Q1212',
#  '2935022': 'http://www.wikidata.org/entity/Q1731',
#  '2642189': 'http://www.wikidata.org/entity/Q1021179',
#  '6695270': 'http://www.wikidata.org/entity/Q1520620',
#  '2945356': 'http://www.wikidata.org/entity/Q1208',
#  '4393217': 'http://www.wikidata.org/entity/Q41819',
#  '4509884': 'http://www.wikidata.org/entity/Q34739',
#  '4563243': 'http://www.wikidata.org/entity/Q49281760',
#  '2638081': 'http://www.wikidata.org/entity/Q1003196',
#  '5099836': 'http://www.wikidata.org/entity/Q26339',
#  '2633708': 'http://www.wikidata.org/entity/Q1000679',
#  '7301290': 'http://www.wikidata.org/entity/Q24674714',
#  '2648272': 'http://www.wikidata.org/entity/Q936263',
#  '5253352': 'http://www.wikidata.org/entity/Q985584',
#  '1814991': 'http://www.wikidata.org/entity/Q148',
#  '2134431': 'http://www.wikidata.org/entity/Q686',
#  '1857910': 'http://www.wikidata.org/entity/Q34600',
#  '4180439': 'http://www.wikidata.org/entity/Q23556',
#  '4835797': 'http://www.wikidata.org/entity/Q33486',
#  '993800': 'http://www.wikidata.org/entity/Q34647',
#  '2640368': 'http://www.wikidata.org/entity/Q83294',
#  '2634112': 'http://www.wikidata.org/entity/Q124539',
#  '2640358': 'http://www.wikidata.org/entity/Q203000',
#  '2634202': 'http://www.wikidata.org/entity/Q661619',
#  '2656708': 'http://www.wikidata.org/entity/Q654216',
#  '2634135': 'http://www.wikidata.org/entity/Q852778',
#  '5165418': 'http://www.wikidata.org/entity/Q1397',
#  '2656666': 'http://www.wikidata.org/entity/Q2514944',
#  '2634204': 'http://www.wikidata.org/entity/Q1754096',
#  '192950': 'http://www.wikidata.org/entity/Q114',
#  '5345743': 'http://www.wikidata.org/entity/Q49349589',
#  '5128581': 'http://www.wikidata.org/entity/Q60',
#  '1733045': 'http://www.wikidata.org/entity/Q833',
#  '1249748': 'http://www.wikidata.org/entity/Q4937400',
#  '2650567': 'http://www.wikidata.org/entity/Q83726',
#  '2210247': 'http://www.wikidata.org/entity/Q31894814',
#  '3164604': 'http://www.wikidata.org/entity/Q1243',
#  '4512203': 'http://www.wikidata.org/entity/Q998459',
#  '2646542': 'http://www.wikidata.org/entity/Q1630298',
#  '2650497': 'http://www.wikidata.org/entity/Q208262',
#  '2654650': 'http://www.wikidata.org/entity/Q4972196',
#  '5378538': 'http://www.wikidata.org/entity/Q17042',
#  '2650517': 'http://www.wikidata.org/entity/Q1277696',
#  '2642414': 'http://www.wikidata.org/entity/Q687798',
#  '3144096': 'http://www.wikidata.org/entity/Q20',
#  '2638360': 'http://www.wikidata.org/entity/Q22',
#  '1853909': 'http://www.wikidata.org/entity/Q35765',
#  '2640354': 'http://www.wikidata.org/entity/Q172438',
#  '2644487': 'http://www.wikidata.org/entity/Q180057',
#  '2542007': 'http://www.wikidata.org/entity/Q1028',
#  '2634217': 'http://www.wikidata.org/entity/Q817481',
#  '2636276': 'http://www.wikidata.org/entity/Q704864',
#  '2638221': 'http://www.wikidata.org/entity/Q1788078',
#  '756135': 'http://www.wikidata.org/entity/Q270',
#  '4931972': 'http://www.wikidata.org/entity/Q49111',
#  '5206379': 'http://www.wikidata.org/entity/Q1342',
#  '6554000': 'http://www.wikidata.org/entity/Q564277',
#  '3625428': 'http://www.wikidata.org/entity/Q717',
#  '4921868': 'http://www.wikidata.org/entity/Q1415',
#  '4839822': 'http://www.wikidata.org/entity/Q54217',
#  '2654710': 'http://www.wikidata.org/entity/Q131491',
#  '2648579': 'http://www.wikidata.org/entity/Q4093',
#  '2650628': 'http://www.wikidata.org/entity/Q179815',
#  '2648559': 'http://www.wikidata.org/entity/Q210891',
#  '2642450': 'http://www.wikidata.org/entity/Q1020217',
#  '2636250': 'http://www.wikidata.org/entity/Q992474',
#  '2029969': 'http://www.wikidata.org/entity/Q711',
#  '2646517': 'http://www.wikidata.org/entity/Q2022317',
#  '1149361': 'http://www.wikidata.org/entity/Q889',
#  '2646404': 'http://www.wikidata.org/entity/Q4216697',
#  '5110266': 'http://www.wikidata.org/entity/Q18426',
#  '5392900': 'http://www.wikidata.org/entity/Q49244',
#  '2636147': 'http://www.wikidata.org/entity/Q2281721',
#  '2652688': 'http://www.wikidata.org/entity/Q949561',
#  '2644497': 'http://www.wikidata.org/entity/Q123741',
#  '2646458': 'http://www.wikidata.org/entity/Q201812',
#  '2654635': 'http://www.wikidata.org/entity/Q922739',
#  '6691227': 'http://www.wikidata.org/entity/Q968937',
#  '2867714': 'http://www.wikidata.org/entity/Q1726',
#  '1810821': 'http://www.wikidata.org/entity/Q68481',
#  '2654596': 'http://www.wikidata.org/entity/Q2338272',
#  '7297523': 'http://www.wikidata.org/entity/Q2221580',
#  '2654728': 'http://www.wikidata.org/entity/Q527391',
#  '3078610': 'http://www.wikidata.org/entity/Q14960',
#  '2986493': 'http://www.wikidata.org/entity/Q954076',
#  '4299276': 'http://www.wikidata.org/entity/Q43668',
#  '2640377': 'http://www.wikidata.org/entity/Q208209',
#  '4831725': 'http://www.wikidata.org/entity/Q779',
#  '2654675': 'http://www.wikidata.org/entity/Q23154',
#  '2822542': 'http://www.wikidata.org/entity/Q1205',
#  '6941036': 'http://www.wikidata.org/entity/Q124046',
#  '2652618': 'http://www.wikidata.org/entity/Q184163',
#  '2638235': 'http://www.wikidata.org/entity/Q527846',
#  '2640348': 'http://www.wikidata.org/entity/Q1247815',
#  '6691254': 'http://www.wikidata.org/entity/Q12067007',
#  '2654579': 'http://www.wikidata.org/entity/Q1190876',
#  '2873759': 'http://www.wikidata.org/entity/Q32121710',
#  '3037692': 'http://www.wikidata.org/entity/Q1419026',
#  '2646504': 'http://www.wikidata.org/entity/Q989616',
#  '2634219': 'http://www.wikidata.org/entity/Q23083',
#  '2699767': 'http://www.wikidata.org/entity/Q103732',
#  '5446023': 'http://www.wikidata.org/entity/Q377181',
#  '2634096': 'http://www.wikidata.org/entity/Q1012481',
#  '2656719': 'http://www.wikidata.org/entity/Q213474',
#  '2638187': 'http://www.wikidata.org/entity/Q939838',
#  '2636177': 'http://www.wikidata.org/entity/Q845619',
#  '3996063': 'http://www.wikidata.org/entity/Q96',
#  '6941038': 'http://www.wikidata.org/entity/Q124007',
#  '2562770': 'http://www.wikidata.org/entity/Q233',
#  '2802361': 'http://www.wikidata.org/entity/Q31',
#  '2921044': 'http://www.wikidata.org/entity/Q183',
#  '2755251': 'http://www.wikidata.org/entity/Q749',
#  '2873891': 'http://www.wikidata.org/entity/Q2119',
#  '281133': 'http://www.wikidata.org/entity/Q49277093',
#  '2650797': 'http://www.wikidata.org/entity/Q126514',
#  '2650732': 'http://www.wikidata.org/entity/Q211950',
#  '2636335': 'http://www.wikidata.org/entity/Q784467',
#  '2650657': 'http://www.wikidata.org/entity/Q919778',
#  '3234498': 'http://www.wikidata.org/entity/Q2987335',
#  '1811017': 'http://www.wikidata.org/entity/Q41705',
#  '2464461': 'http://www.wikidata.org/entity/Q948',
#  '5102118': 'http://www.wikidata.org/entity/Q795396',
#  '2650752': 'http://www.wikidata.org/entity/Q123709',
#  '2634341': 'http://www.wikidata.org/entity/Q21768374',
#  '1643084': 'http://www.wikidata.org/entity/Q252',
#  '660013': 'http://www.wikidata.org/entity/Q33',
#  '2648773': 'http://www.wikidata.org/entity/Q216372',
#  '2644688': 'http://www.wikidata.org/entity/Q39121',
#  '6255150': 'http://www.wikidata.org/entity/Q18',
#  '6255146': 'http://www.wikidata.org/entity/Q15',
#  '5368361': 'http://www.wikidata.org/entity/Q49280127',
#  '2644652': 'http://www.wikidata.org/entity/Q2462645',
#  '2640572': 'http://www.wikidata.org/entity/Q7147894',
#  '2646557': 'http://www.wikidata.org/entity/Q177544',
#  '2656915': 'http://www.wikidata.org/entity/Q659803',
#  '2646720': 'http://www.wikidata.org/entity/Q1010169',
#  '4928096': 'http://www.wikidata.org/entity/Q166481',
#  '2638419': 'http://www.wikidata.org/entity/Q743521',
#  '2656867': 'http://www.wikidata.org/entity/Q649838',
#  '1036973': 'http://www.wikidata.org/entity/Q1029',
#  '4885186': 'http://www.wikidata.org/entity/Q577829',
#  '1278629': 'http://www.wikidata.org/entity/Q1159',
#  '1856057': 'http://www.wikidata.org/entity/Q11751',
#  '2640416': 'http://www.wikidata.org/entity/Q798906',
#  '3117735': 'http://www.wikidata.org/entity/Q2807',
#  '2636389': 'http://www.wikidata.org/entity/Q200942',
#  '6255147': 'http://www.wikidata.org/entity/Q48',
#  '8354456': 'http://www.wikidata.org/entity/Q2277',
#  '5380748': 'http://www.wikidata.org/entity/Q47265',
#  '2656946': 'http://www.wikidata.org/entity/Q202348',
#  '2652708': 'http://www.wikidata.org/entity/Q1104283',
#  '2640413': 'http://www.wikidata.org/entity/Q1025788',
#  '2636484': 'http://www.wikidata.org/entity/Q2119187',
#  '2652843': 'http://www.wikidata.org/entity/Q2376216',
#  '2966154': 'http://www.wikidata.org/entity/Q865849',
#  '2761369': 'http://www.wikidata.org/entity/Q1741',
#  '2644531': 'http://www.wikidata.org/entity/Q207371',
#  '4094490': 'http://www.wikidata.org/entity/Q79718',
#  '4197000': 'http://www.wikidata.org/entity/Q1428',
#  '2642607': 'http://www.wikidata.org/entity/Q171866',
#  '2644559': 'http://www.wikidata.org/entity/Q246884',
#  '2646595': 'http://www.wikidata.org/entity/Q1628403',
#  '5001836': 'http://www.wikidata.org/entity/Q1166',
#  '2634308': 'http://www.wikidata.org/entity/Q845623',
#  '2642514': 'http://www.wikidata.org/entity/Q149688',
#  '2820693': 'http://www.wikidata.org/entity/Q15987',
#  '2636486': 'http://www.wikidata.org/entity/Q868196',
#  '2931276': 'http://www.wikidata.org/entity/Q702259',
#  '2642487': 'http://www.wikidata.org/entity/Q123620',
#  '3658394': 'http://www.wikidata.org/entity/Q736',
#  '4829764': 'http://www.wikidata.org/entity/Q173',
#  '4971068': 'http://www.wikidata.org/entity/Q724',
#  '6255149': 'http://www.wikidata.org/entity/Q49',
#  '690791': 'http://www.wikidata.org/entity/Q133356',
#  '2642465': 'http://www.wikidata.org/entity/Q204234',
#  '2656955': 'http://www.wikidata.org/entity/Q725261',
#  '2652730': 'http://www.wikidata.org/entity/Q996502',
#  '1210997': 'http://www.wikidata.org/entity/Q902',
#  '2073124': 'http://www.wikidata.org/entity/Q11568',
#  '6255148': 'http://www.wikidata.org/entity/Q46',
#  '2996944': 'http://www.wikidata.org/entity/Q456',
#  '2656924': 'http://www.wikidata.org/entity/Q2220778',
#  '3355338': 'http://www.wikidata.org/entity/Q1030',
#  '2638542': 'http://www.wikidata.org/entity/Q26163',
#  '6957697': 'http://www.wikidata.org/entity/Q31945',
#  '8063571': 'http://www.wikidata.org/entity/Q5139008',
#  '5110302': 'http://www.wikidata.org/entity/Q18419',
#  '2640409': 'http://www.wikidata.org/entity/Q1227477',
#  '6931071': 'http://www.wikidata.org/entity/Q1477163',
#  '2992741': 'http://www.wikidata.org/entity/Q45240',
#  '3017382': 'http://www.wikidata.org/entity/Q142',
#  '2644668': 'http://www.wikidata.org/entity/Q83065',
#  '1856177': 'http://www.wikidata.org/entity/Q49295299',
#  '2634403': 'http://www.wikidata.org/entity/Q939617',
#  '6173331': 'http://www.wikidata.org/entity/Q24639',
#  '2634330': 'http://www.wikidata.org/entity/Q146833',
#  '4348599': 'http://www.wikidata.org/entity/Q584451',
#  '2644547': 'http://www.wikidata.org/entity/Q2569138',
#  '2644641': 'http://www.wikidata.org/entity/Q1018540',
#  '3031582': 'http://www.wikidata.org/entity/Q1479',
#  '2646673': 'http://www.wikidata.org/entity/Q3050619',
#  '2636432': 'http://www.wikidata.org/entity/Q23051',
#  '2638488': 'http://www.wikidata.org/entity/Q7427481',
#  '4887398': 'http://www.wikidata.org/entity/Q1297',
#  '4942618': 'http://www.wikidata.org/entity/Q49162',
#  '2634569': 'http://www.wikidata.org/entity/Q212283',
#  '2654991': 'http://www.wikidata.org/entity/Q896940',
#  '2644746': 'http://www.wikidata.org/entity/Q1931690',
#  '226074': 'http://www.wikidata.org/entity/Q1036',
#  '1227603': 'http://www.wikidata.org/entity/Q854',
#  '2634560': 'http://www.wikidata.org/entity/Q1024911',
#  '1162005': 'http://www.wikidata.org/entity/Q191333',
#  '2990969': 'http://www.wikidata.org/entity/Q12191',
#  '1264521': 'http://www.wikidata.org/entity/Q228405',
#  '1856215': 'http://www.wikidata.org/entity/Q49295298',
#  '2655095': 'http://www.wikidata.org/entity/Q170478',
#  '2857807': 'http://www.wikidata.org/entity/Q32205427',
#  '3042142': 'http://www.wikidata.org/entity/Q785',
#  '2642705': 'http://www.wikidata.org/entity/Q752762',
#  '2634552': 'http://www.wikidata.org/entity/Q19789',
#  '1862415': 'http://www.wikidata.org/entity/Q49295248',
#  '3099434': 'http://www.wikidata.org/entity/Q1792',
#  '2634575': 'http://www.wikidata.org/entity/Q1026685',
#  '5380838': 'http://www.wikidata.org/entity/Q57964419',
#  '2634549': 'http://www.wikidata.org/entity/Q146858',
#  '2652995': 'http://www.wikidata.org/entity/Q852772',
#  '2654993': 'http://www.wikidata.org/entity/Q22905',
#  '2782113': 'http://www.wikidata.org/entity/Q40',
#  '2589581': 'http://www.wikidata.org/entity/Q262',
#  '2646826': 'http://www.wikidata.org/entity/Q19798',
#  '2990999': 'http://www.wikidata.org/entity/Q40898',
#  '2646914': 'http://www.wikidata.org/entity/Q64116',
#  '2640692': 'http://www.wikidata.org/entity/Q124230',
#  '6697863': 'http://www.wikidata.org/entity/Q188617',
#  '2648945': 'http://www.wikidata.org/entity/Q288082',
#  '2638652': 'http://www.wikidata.org/entity/Q838920',
#  '2652974': 'http://www.wikidata.org/entity/Q985833',
#  '2636564': 'http://www.wikidata.org/entity/Q1021319',
#  '2464470': 'http://www.wikidata.org/entity/Q3572',
#  '5454711': 'http://www.wikidata.org/entity/Q34804',
#  '2651033': 'http://www.wikidata.org/entity/Q125344',
#  '2892518': 'http://www.wikidata.org/entity/Q32067925',
#  '3169070': 'http://www.wikidata.org/entity/Q220',
#  '2077456': 'http://www.wikidata.org/entity/Q408',
#  '1327865': 'http://www.wikidata.org/entity/Q836',
#  '2655097': 'http://www.wikidata.org/entity/Q2059003',
#  '2655009': 'http://www.wikidata.org/entity/Q783210',
#  '2650839': 'http://www.wikidata.org/entity/Q213832',
#  '5073708': 'http://www.wikidata.org/entity/Q1553',
#  '1264542': 'http://www.wikidata.org/entity/Q1188',
#  '1850147': 'http://www.wikidata.org/entity/Q308891',
#  '2646742': 'http://www.wikidata.org/entity/Q4499107',
#  '2634491': 'http://www.wikidata.org/entity/Q212826',
#  '4907907': 'http://www.wikidata.org/entity/Q577878',
#  '7299881': 'http://www.wikidata.org/entity/Q1519560',
#  '2652890': 'http://www.wikidata.org/entity/Q1022447',
#  '2638650': 'http://www.wikidata.org/entity/Q2332298',
#  '3865483': 'http://www.wikidata.org/entity/Q414',
#  '2185983': 'http://www.wikidata.org/entity/Q118863',
#  '2652951': 'http://www.wikidata.org/entity/Q146659',
#  '1831722': 'http://www.wikidata.org/entity/Q424',
#  '2921232': 'http://www.wikidata.org/entity/Q32029631',
#  '2646781': 'http://www.wikidata.org/entity/Q16985641',
#  '4647802': 'http://www.wikidata.org/entity/Q7127683',
#  '2655123': 'http://www.wikidata.org/entity/Q4949032',
#  '2413451': 'http://www.wikidata.org/entity/Q1005',
#  '2638635': 'http://www.wikidata.org/entity/Q7406147',
#  '2757345': 'http://www.wikidata.org/entity/Q33432813',
#  '2300660': 'http://www.wikidata.org/entity/Q117',
#  '2636531': 'http://www.wikidata.org/entity/Q188304',
#  '2982652': 'http://www.wikidata.org/entity/Q30974',
#  '5110629': 'http://www.wikidata.org/entity/Q40435',
#  '5294810': 'http://www.wikidata.org/entity/Q79842',
#  '3042058': 'http://www.wikidata.org/entity/Q347',
#  '2642713': 'http://www.wikidata.org/entity/Q23100',
#  '2644737': 'http://www.wikidata.org/entity/Q546635',
#  '2644726': 'http://www.wikidata.org/entity/Q1810766',
#  '7645989': 'http://www.wikidata.org/entity/Q3552816',
#  '2634636': 'http://www.wikidata.org/entity/Q2589602',
#  '2636616': 'http://www.wikidata.org/entity/Q281749',
#  '2634617': 'http://www.wikidata.org/entity/Q501023',
#  '2646807': 'http://www.wikidata.org/entity/Q1477061',
#  '2648997': 'http://www.wikidata.org/entity/Q3367868',
#  '932692': 'http://www.wikidata.org/entity/Q1013',
#  '5331835': 'http://www.wikidata.org/entity/Q39561',
#  '5454627': 'http://www.wikidata.org/entity/Q467617',
#  '2521978': 'http://www.wikidata.org/entity/Q3555926',
#  '2638671': 'http://www.wikidata.org/entity/Q47952',
#  '2640729': 'http://www.wikidata.org/entity/Q34217',
#  '2638664': 'http://www.wikidata.org/entity/Q160642',
#  '2638559': 'http://www.wikidata.org/entity/Q2006803',
#  '5174035': 'http://www.wikidata.org/entity/Q49239',
#  '6695705': 'http://www.wikidata.org/entity/Q275',
#  '2655237': 'http://www.wikidata.org/entity/Q184579',
#  '2657306': 'http://www.wikidata.org/entity/Q202177',
#  '2636769': 'http://www.wikidata.org/entity/Q661707',
#  '2640857': 'http://www.wikidata.org/entity/Q658902',
#  '2647048': 'http://www.wikidata.org/entity/Q1016813',
#  '2950159': 'http://www.wikidata.org/entity/Q64',
#  '1172451': 'http://www.wikidata.org/entity/Q11739',
#  '2642910': 'http://www.wikidata.org/entity/Q1337703',
#  '2640894': 'http://www.wikidata.org/entity/Q123977',
#  '2651048': 'http://www.wikidata.org/entity/Q179224',
#  '2653229': 'http://www.wikidata.org/entity/Q2220767',
#  '2847736': 'http://www.wikidata.org/entity/Q3085',
#  '2892794': 'http://www.wikidata.org/entity/Q1040',
#  '2651095': 'http://www.wikidata.org/entity/Q540333',
#  '1282988': 'http://www.wikidata.org/entity/Q837',
#  '2636840': 'http://www.wikidata.org/entity/Q302613',
#  '2651149': 'http://www.wikidata.org/entity/Q146440',
#  '2778067': 'http://www.wikidata.org/entity/Q21871155',
#  '2634739': 'http://www.wikidata.org/entity/Q215733',
#  '2233387': 'http://www.wikidata.org/entity/Q1009',
#  '719819': 'http://www.wikidata.org/entity/Q28',
#  '2245662': 'http://www.wikidata.org/entity/Q1041',
#  '2655273': 'http://www.wikidata.org/entity/Q889888',
#  '2651123': 'http://www.wikidata.org/entity/Q58900',
#  '2655186': 'http://www.wikidata.org/entity/Q19773',
#  '2657324': 'http://www.wikidata.org/entity/Q492805',
#  '2640861': 'http://www.wikidata.org/entity/Q1009221',
#  '3333137': 'http://www.wikidata.org/entity/Q1026448',
#  '2647057': 'http://www.wikidata.org/entity/Q929286',
#  '2653121': 'http://www.wikidata.org/entity/Q845015',
#  '3175395': 'http://www.wikidata.org/entity/Q38',
#  '2186224': 'http://www.wikidata.org/entity/Q664',
#  '4699066': 'http://www.wikidata.org/entity/Q16555',
#  '2638867': 'http://www.wikidata.org/entity/Q6226',
#  '2638785': 'http://www.wikidata.org/entity/Q153647',
#  '2636713': 'http://www.wikidata.org/entity/Q189288',
#  '2638878': 'http://www.wikidata.org/entity/Q183329',
#  '2638864': 'http://www.wikidata.org/entity/Q207736',
#  '2653192': 'http://www.wikidata.org/entity/Q207639',
#  '2638855': 'http://www.wikidata.org/entity/Q548248',
#  '2655262': 'http://www.wikidata.org/entity/Q890621',
#  '2657215': 'http://www.wikidata.org/entity/Q630668',
#  '2638778': 'http://www.wikidata.org/entity/Q724182',
#  '2653131': 'http://www.wikidata.org/entity/Q2316216',
#  '2653204': 'http://www.wikidata.org/entity/Q2297876',
#  '2649069': 'http://www.wikidata.org/entity/Q2428909',
#  '99237': 'http://www.wikidata.org/entity/Q3041595',
#  '2642930': 'http://www.wikidata.org/entity/Q6781187',
#  '1819730': 'http://www.wikidata.org/entity/Q8646',
#  '2792413': 'http://www.wikidata.org/entity/Q21765571',
#  '3345438': 'http://www.wikidata.org/entity/Q385060',
#  '3474414': 'http://www.wikidata.org/entity/Q9648',
#  '2653144': 'http://www.wikidata.org/entity/Q775299',
#  '5282804': 'http://www.wikidata.org/entity/Q49174',
#  '3345437': 'http://www.wikidata.org/entity/Q149836',
#  '2395170': 'http://www.wikidata.org/entity/Q962',
#  '2653225': 'http://www.wikidata.org/entity/Q823600',
#  '1139715': 'http://www.wikidata.org/entity/Q183303',
#  '2636843': 'http://www.wikidata.org/entity/Q2483346',
#  '2640908': 'http://www.wikidata.org/entity/Q1020958',
#  '2636795': 'http://www.wikidata.org/entity/Q787279',
#  '7535618': 'http://www.wikidata.org/entity/Q3054692',
#  '2653228': 'http://www.wikidata.org/entity/Q170263',
#  '2642904': 'http://www.wikidata.org/entity/Q1020265',
#  '2657310': 'http://www.wikidata.org/entity/Q168159',
#  '2644972': 'http://www.wikidata.org/entity/Q205905',
#  '895949': 'http://www.wikidata.org/entity/Q953',
#  '3345325': 'http://www.wikidata.org/entity/Q4923812',
#  '2634715': 'http://www.wikidata.org/entity/Q1018448',
#  '6695868': 'http://www.wikidata.org/entity/Q1068693',
#  '2929670': 'http://www.wikidata.org/entity/Q31997476',
#  '3374084': 'http://www.wikidata.org/entity/Q244',
#  '2634677': 'http://www.wikidata.org/entity/Q2598',
#  '4250542': 'http://www.wikidata.org/entity/Q28515',
#  '2747373': 'http://www.wikidata.org/entity/Q41795540',
#  '7302144': 'http://www.wikidata.org/entity/Q2153507',
#  '2133000': 'http://www.wikidata.org/entity/Q1127200',
#  '2647074': 'http://www.wikidata.org/entity/Q204720',
#  '2636841': 'http://www.wikidata.org/entity/Q134902',
#  '2954172': 'http://www.wikidata.org/entity/Q2749',
#  '2860049': 'http://www.wikidata.org/entity/Q521397',
#  '2636714': 'http://www.wikidata.org/entity/Q676136',
#  '2636882': 'http://www.wikidata.org/entity/Q18655',
#  '4574324': 'http://www.wikidata.org/entity/Q47716',
#  '2653346': 'http://www.wikidata.org/entity/Q117810',
#  '1668284': 'http://www.wikidata.org/entity/Q865',
#  '2653256': 'http://www.wikidata.org/entity/Q771986',
#  '2641036': 'http://www.wikidata.org/entity/Q1857563',
#  '2653261': 'http://www.wikidata.org/entity/Q206988',
#  '2964574': 'http://www.wikidata.org/entity/Q1761',
#  '2655333': 'http://www.wikidata.org/entity/Q150120',
#  '6087892': 'http://www.wikidata.org/entity/Q274120',
#  '3923057': 'http://www.wikidata.org/entity/Q750',
#  '2634812': 'http://www.wikidata.org/entity/Q2166359',
#  '1252558': 'http://www.wikidata.org/entity/Q5451',
#  '2657438': 'http://www.wikidata.org/entity/Q1002826',
#  '2655438': 'http://www.wikidata.org/entity/Q122767',
#  '2911298': 'http://www.wikidata.org/entity/Q1055',
#  '2651269': 'http://www.wikidata.org/entity/Q1009242',
#  '5106834': 'http://www.wikidata.org/entity/Q24861',
#  '2639015': 'http://www.wikidata.org/entity/Q2338847',
#  '2639018': 'http://www.wikidata.org/entity/Q19804',
#  '2653335': 'http://www.wikidata.org/entity/Q937918',
#  '2657408': 'http://www.wikidata.org/entity/Q443840',
#  '2647116': 'http://www.wikidata.org/entity/Q149787',
#  '3177617': 'http://www.wikidata.org/entity/Q30025412',
#  '2640955': 'http://www.wikidata.org/entity/Q7096545',
#  '2645072': 'http://www.wikidata.org/entity/Q1230765',
#  '2673730': 'http://www.wikidata.org/entity/Q1754',
#  '2657427': 'http://www.wikidata.org/entity/Q2560190',
#  '2653266': 'http://www.wikidata.org/entity/Q210985',
#  '2634910': 'http://www.wikidata.org/entity/Q216638',
#  '2647138': 'http://www.wikidata.org/entity/Q3532',
#  '2651294': 'http://www.wikidata.org/entity/Q1026699',
#  '2653239': 'http://www.wikidata.org/entity/Q1070428',
#  '2991214': 'http://www.wikidata.org/entity/Q79815',
#  '3077311': 'http://www.wikidata.org/entity/Q213',
#  '3054643': 'http://www.wikidata.org/entity/Q1781',
#  '4508722': 'http://www.wikidata.org/entity/Q43196',
#  '2634853': 'http://www.wikidata.org/entity/Q504530',
#  '2638978': 'http://www.wikidata.org/entity/Q623765',
#  '3333208': 'http://www.wikidata.org/entity/Q1423078',
#  '2651349': 'http://www.wikidata.org/entity/Q2308650',
#  '2509954': 'http://www.wikidata.org/entity/Q8818',
#  '2647239': 'http://www.wikidata.org/entity/Q3090863',
#  '453733': 'http://www.wikidata.org/entity/Q191',
#  '1168579': 'http://www.wikidata.org/entity/Q843',
#  '2651347': 'http://www.wikidata.org/entity/Q43475',
#  '2651286': 'http://www.wikidata.org/entity/Q525508',
#  '2647248': 'http://www.wikidata.org/entity/Q920646',
#  '2655315': 'http://www.wikidata.org/entity/Q886899',
#  '2636910': 'http://www.wikidata.org/entity/Q49277094',
#  '2649258': 'http://www.wikidata.org/entity/Q375314',
#  '2063523': 'http://www.wikidata.org/entity/Q3183',
#  '3179626': 'http://www.wikidata.org/entity/Q49281774',
#  '3173435': 'http://www.wikidata.org/entity/Q49295412',
#  '498817': 'http://www.wikidata.org/entity/Q656',
#  '2618425': 'http://www.wikidata.org/entity/Q1748',
#  '2643003': 'http://www.wikidata.org/entity/Q508998',
#  '6620310': 'http://www.wikidata.org/entity/Q1210672',
#  '2655413': 'http://www.wikidata.org/entity/Q804282',
#  '3333170': 'http://www.wikidata.org/entity/Q797782',
#  '2636876': 'http://www.wikidata.org/entity/Q989418',
#  '2638909': 'http://www.wikidata.org/entity/Q1020800',
#  '2651289': 'http://www.wikidata.org/entity/Q1245018',
#  '2661493': 'http://www.wikidata.org/entity/Q22551193',
#  '3042362': 'http://www.wikidata.org/entity/Q25230',
#  '2634838': 'http://www.wikidata.org/entity/Q2321784',
#  '2643142': 'http://www.wikidata.org/entity/Q280506',
#  '2657402': 'http://www.wikidata.org/entity/Q445058',
#  '2643044': 'http://www.wikidata.org/entity/Q618045',
#  '2657356': 'http://www.wikidata.org/entity/Q470188',
#  '2647207': 'http://www.wikidata.org/entity/Q1023948',
#  '2636963': 'http://www.wikidata.org/entity/Q7605979',
#  '2659496': 'http://www.wikidata.org/entity/Q69345',
#  '2636948': 'http://www.wikidata.org/entity/Q123627',
#  '2911285': 'http://www.wikidata.org/entity/Q1833',
#  '2643027': 'http://www.wikidata.org/entity/Q783570',
#  '2653235': 'http://www.wikidata.org/entity/Q962767',
#  '4684888': 'http://www.wikidata.org/entity/Q16557',
#  '3337387': 'http://www.wikidata.org/entity/Q231',
#  '2634895': 'http://www.wikidata.org/entity/Q25',
#  '2636940': 'http://www.wikidata.org/entity/Q19795',
#  '2655351': 'http://www.wikidata.org/entity/Q127159',
#  '2639022': 'http://www.wikidata.org/entity/Q665489',
#  '2825297': 'http://www.wikidata.org/entity/Q1022',
#  '2641022': 'http://www.wikidata.org/entity/Q202628',
#  '2653265': 'http://www.wikidata.org/entity/Q743535',
#  '2759794': 'http://www.wikidata.org/entity/Q727',
#  '2643097': 'http://www.wikidata.org/entity/Q841979',
#  '2634864': 'http://www.wikidata.org/entity/Q1248150',
#  '2638976': 'http://www.wikidata.org/entity/Q2379971',
#  '2264397': 'http://www.wikidata.org/entity/Q45',
#  '3351879': 'http://www.wikidata.org/entity/Q916',
#  '3030300': 'http://www.wikidata.org/entity/Q49272175',
#  '2649463': 'http://www.wikidata.org/entity/Q82334',
#  '2657697': 'http://www.wikidata.org/entity/Q83609',
#  '2655524': 'http://www.wikidata.org/entity/Q188313',
#  '2643339': 'http://www.wikidata.org/entity/Q203889',
#  '3015904': 'http://www.wikidata.org/entity/Q241940',
#  '146669': 'http://www.wikidata.org/entity/Q229',
#  '587116': 'http://www.wikidata.org/entity/Q227',
#  '2637104': 'http://www.wikidata.org/entity/Q1000662',
#  '2647258': 'http://www.wikidata.org/entity/Q1010221',
#  '2647385': 'http://www.wikidata.org/entity/Q986049',
#  '2078025': 'http://www.wikidata.org/entity/Q5112',
#  '457954': 'http://www.wikidata.org/entity/Q167668',
#  '3378535': 'http://www.wikidata.org/entity/Q734',
#  '2080013': 'http://www.wikidata.org/entity/Q697840',
#  '3425505': 'http://www.wikidata.org/entity/Q223',
#  '2643198': 'http://www.wikidata.org/entity/Q1951431',
#  '5322039': 'http://www.wikidata.org/entity/Q49612836',
#  '2651383': 'http://www.wikidata.org/entity/Q2458566',
#  '2655642': 'http://www.wikidata.org/entity/Q863832',
#  '2647400': 'http://www.wikidata.org/entity/Q215752',
#  '2651474': 'http://www.wikidata.org/entity/Q1248368',
#  '2655459': 'http://www.wikidata.org/entity/Q170377',
#  '2643269': 'http://www.wikidata.org/entity/Q1882406',
#  '2657544': 'http://www.wikidata.org/entity/Q258642',
#  '2647317': 'http://www.wikidata.org/entity/Q1234712',
#  '2647261': 'http://www.wikidata.org/entity/Q678138',
#  '2641216': 'http://www.wikidata.org/entity/Q2090609',
#  '783754': 'http://www.wikidata.org/entity/Q222',
#  '2651385': 'http://www.wikidata.org/entity/Q650682',
#  '2647395': 'http://www.wikidata.org/entity/Q2174493',
#  '1258899': 'http://www.wikidata.org/entity/Q1437',
#  '2751773': 'http://www.wikidata.org/entity/Q33456378',
#  '2755812': 'http://www.wikidata.org/entity/Q770',
#  '2800931': 'http://www.wikidata.org/entity/Q12994',
#  '2993457': 'http://www.wikidata.org/entity/Q235',
#  '2655603': 'http://www.wikidata.org/entity/Q2256',
#  '6325494': 'http://www.wikidata.org/entity/Q2145',
#  '2647349': 'http://www.wikidata.org/entity/Q19788',
#  '2641181': 'http://www.wikidata.org/entity/Q130191',
#  '2655613': 'http://www.wikidata.org/entity/Q746718',
#  '2643312': 'http://www.wikidata.org/entity/Q1018133',
#  '2639192': 'http://www.wikidata.org/entity/Q1339305',
#  '2637106': 'http://www.wikidata.org/entity/Q1398653',
#  '5279098': 'http://www.wikidata.org/entity/Q1758449',
#  '2639201': 'http://www.wikidata.org/entity/Q2313624',
#  '2661604': 'http://www.wikidata.org/entity/Q56447734',
#  '2639223': 'http://www.wikidata.org/entity/Q3057456',
#  '2651357': 'http://www.wikidata.org/entity/Q2023476',
#  '4558188': 'http://www.wikidata.org/entity/Q5554764',
#  '2940132': 'http://www.wikidata.org/entity/Q31931477',
#  '5381396': 'http://www.wikidata.org/entity/Q485176',
#  '2641170': 'http://www.wikidata.org/entity/Q41262',
#  '2647428': 'http://www.wikidata.org/entity/Q215829',
#  '2997551': 'http://www.wikidata.org/entity/Q1137',
#  '2639268': 'http://www.wikidata.org/entity/Q507517',
#  '2643266': 'http://www.wikidata.org/entity/Q868637',
#  '3855719': 'http://www.wikidata.org/entity/Q1442288',
#  '2635167': 'http://www.wikidata.org/entity/Q145',
#  '2995469': 'http://www.wikidata.org/entity/Q49295409',
#  '2641267': 'http://www.wikidata.org/entity/Q746096',
#  '4930956': 'http://www.wikidata.org/entity/Q100',
#  '2639191': 'http://www.wikidata.org/entity/Q7363216',
#  '2147714': 'http://www.wikidata.org/entity/Q3130',
#  '2641235': 'http://www.wikidata.org/entity/Q23079',
#  '2641290': 'http://www.wikidata.org/entity/Q83399',
#  '2661786': 'http://www.wikidata.org/entity/Q1286',
#  '2647278': 'http://www.wikidata.org/entity/Q384570',
#  '2643186': 'http://www.wikidata.org/entity/Q238803',
#  '2647365': 'http://www.wikidata.org/entity/Q2449644',
#  '5879092': 'http://www.wikidata.org/entity/Q797',
#  '3595528': 'http://www.wikidata.org/entity/Q774',
#  '2637142': 'http://www.wikidata.org/entity/Q826782',
#  '2647451': 'http://www.wikidata.org/entity/Q19785',
#  '2651468': 'http://www.wikidata.org/entity/Q1011096',
#  '2647356': 'http://www.wikidata.org/entity/Q29245',
#  '2952539': 'http://www.wikidata.org/entity/Q153974',
#  '2643179': 'http://www.wikidata.org/entity/Q213180',
#  '2657540': 'http://www.wikidata.org/entity/Q646980',
#  '2651513': 'http://www.wikidata.org/entity/Q213181',
#  '2657613': 'http://www.wikidata.org/entity/Q408536',
#  '2655562': 'http://www.wikidata.org/entity/Q19797',
#  '3183875': 'http://www.wikidata.org/entity/Q19689',
#  '2637197': 'http://www.wikidata.org/entity/Q7580824',
#  '2639093': 'http://www.wikidata.org/entity/Q217039',
#  '2647461': 'http://www.wikidata.org/entity/Q852729',
#  '2651500': 'http://www.wikidata.org/entity/Q858775',
#  '2651498': 'http://www.wikidata.org/entity/Q1007083',
#  '2800866': 'http://www.wikidata.org/entity/Q239',
#  '7296382': 'http://www.wikidata.org/entity/Q24666452',
#  '2651378': 'http://www.wikidata.org/entity/Q988761',
#  '6542706': 'http://www.wikidata.org/entity/Q46791',
#  '2403846': 'http://www.wikidata.org/entity/Q1044',
#  '3143244': 'http://www.wikidata.org/entity/Q585',
#  '2809346': 'http://www.wikidata.org/entity/Q32067991',
#  '2934246': 'http://www.wikidata.org/entity/Q1718',
#  '745044': 'http://www.wikidata.org/entity/Q16869',
#  '2645460': 'http://www.wikidata.org/entity/Q19807',
#  '2747891': 'http://www.wikidata.org/entity/Q34370',
#  '5490263': 'http://www.wikidata.org/entity/Q38555',
#  '359888': 'http://www.wikidata.org/entity/Q203751',
#  '2637329': 'http://www.wikidata.org/entity/Q279000',
#  '2643558': 'http://www.wikidata.org/entity/Q373971',
#  '5248511': 'http://www.wikidata.org/entity/Q940349',
#  '5103116': 'http://www.wikidata.org/entity/Q1083371',
#  '2651621': 'http://www.wikidata.org/entity/Q1075299',
#  '7298552': 'http://www.wikidata.org/entity/Q2250427',
#  '458258': 'http://www.wikidata.org/entity/Q211',
#  '2647604': 'http://www.wikidata.org/entity/Q2282928',
#  '2643490': 'http://www.wikidata.org/entity/Q986007',
#  '746983': 'http://www.wikidata.org/entity/Q216907',
#  '2960860': 'http://www.wikidata.org/entity/Q788',
#  '4990510': 'http://www.wikidata.org/entity/Q430464',
#  '5391959': 'http://www.wikidata.org/entity/Q62',
#  '2661881': 'http://www.wikidata.org/entity/Q56434817',
#  '1809935': 'http://www.wikidata.org/entity/Q15175',
#  '3083829': 'http://www.wikidata.org/entity/Q49279731',
#  '4744746': 'http://www.wikidata.org/entity/Q216344',
#  '1861060': 'http://www.wikidata.org/entity/Q17',
#  '2655713': 'http://www.wikidata.org/entity/Q663588',
#  '2647632': 'http://www.wikidata.org/entity/Q826561',
#  '2637221': 'http://www.wikidata.org/entity/Q123219',
#  '2637277': 'http://www.wikidata.org/entity/Q1854554',
#  '2639334': 'http://www.wikidata.org/entity/Q1248943',
#  '2643425': 'http://www.wikidata.org/entity/Q839811',
#  '3128760': 'http://www.wikidata.org/entity/Q1492',
#  '2205218': 'http://www.wikidata.org/entity/Q712',
#  '1273294': 'http://www.wikidata.org/entity/Q49278601',
#  '2653775': 'http://www.wikidata.org/entity/Q192896',
#  '5037649': 'http://www.wikidata.org/entity/Q36091',
#  '5109177': 'http://www.wikidata.org/entity/Q213814',
#  '6252001': 'http://www.wikidata.org/entity/Q30',
#  '5391811': 'http://www.wikidata.org/entity/Q16552',
#  '2647553': 'http://www.wikidata.org/entity/Q25610',
#  '2645425': 'http://www.wikidata.org/entity/Q128147',
#  '2647550': 'http://www.wikidata.org/entity/Q766353',
#  '2637343': 'http://www.wikidata.org/entity/Q868647',
#  '2651715': 'http://www.wikidata.org/entity/Q996616',
#  '2641319': 'http://www.wikidata.org/entity/Q1020014',
#  '2637241': 'http://www.wikidata.org/entity/Q3492981',
#  '4335045': 'http://www.wikidata.org/entity/Q34404',
#  '4560349': 'http://www.wikidata.org/entity/Q1345',
#  '2647468': 'http://www.wikidata.org/entity/Q146335',
#  '2651653': 'http://www.wikidata.org/entity/Q5197235',
#  '2647508': 'http://www.wikidata.org/entity/Q3699290',
#  '4984247': 'http://www.wikidata.org/entity/Q485172',
#  '2080185': 'http://www.wikidata.org/entity/Q709',
#  '2649660': 'http://www.wikidata.org/entity/Q643160',
#  '2635274': 'http://www.wikidata.org/entity/Q23080',
#  '2649671': 'http://www.wikidata.org/entity/Q123229',
#  '2655775': 'http://www.wikidata.org/entity/Q146416',
#  '2645605': 'http://www.wikidata.org/entity/Q576562',
#  '2647639': 'http://www.wikidata.org/entity/Q612260',
#  '2637357': 'http://www.wikidata.org/entity/Q2265962',
#  '2649571': 'http://www.wikidata.org/entity/Q2545812',
#  '2635308': 'http://www.wikidata.org/entity/Q1143278',
#  '2651637': 'http://www.wikidata.org/entity/Q5199742',
#  '2661886': 'http://www.wikidata.org/entity/Q34',
#  '7294458': 'http://www.wikidata.org/entity/Q24664158',
#  '2647525': 'http://www.wikidata.org/entity/Q1575653',
#  '2651654': 'http://www.wikidata.org/entity/Q990153',
#  '2637268': 'http://www.wikidata.org/entity/Q2097530',
#  '2649548': 'http://www.wikidata.org/entity/Q580766',
#  '2635269': 'http://www.wikidata.org/entity/Q1755020',
#  '2637273': 'http://www.wikidata.org/entity/Q23095',
#  '1648148': 'http://www.wikidata.org/entity/Q36117',
#  '4509177': 'http://www.wikidata.org/entity/Q16567',
#  '6944338': 'http://www.wikidata.org/entity/Q215255',
#  '2649672': 'http://www.wikidata.org/entity/Q547071',
#  '2745912': 'http://www.wikidata.org/entity/Q39297398',
#  '2172517': 'http://www.wikidata.org/entity/Q3114',
#  '2641430': 'http://www.wikidata.org/entity/Q192240',
#  '2639323': 'http://www.wikidata.org/entity/Q661529',
#  '2803138': 'http://www.wikidata.org/entity/Q31467408',
#  '2623032': 'http://www.wikidata.org/entity/Q35',
#  '2657832': 'http://www.wikidata.org/entity/Q36405',
#  '2655654': 'http://www.wikidata.org/entity/Q1015967',
#  '7300653': 'http://www.wikidata.org/entity/Q2272941',
#  '8224216': 'http://www.wikidata.org/entity/Q19801',
#  '2639272': 'http://www.wikidata.org/entity/Q474605',
#  '7296581': 'http://www.wikidata.org/entity/Q5302695',
#  '2678287': 'http://www.wikidata.org/entity/Q103659',
#  '2158177': 'http://www.wikidata.org/entity/Q3141',
#  '4259418': 'http://www.wikidata.org/entity/Q6346',
#  '2637395': 'http://www.wikidata.org/entity/Q1045096',
#  '6251999': 'http://www.wikidata.org/entity/Q16',
#  '2637299': 'http://www.wikidata.org/entity/Q5273898',
#  '2655777': 'http://www.wikidata.org/entity/Q853012',
#  '3469034': 'http://www.wikidata.org/entity/Q155',
#  '290557': 'http://www.wikidata.org/entity/Q878',
#  '294640': 'http://www.wikidata.org/entity/Q801',
#  '2655984': 'http://www.wikidata.org/entity/Q10686',
#  '130758': 'http://www.wikidata.org/entity/Q794',
#  '2655856': 'http://www.wikidata.org/entity/Q23220',
#  '2637490': 'http://www.wikidata.org/entity/Q83434',
#  '2651852': 'http://www.wikidata.org/entity/Q179259',
#  '2637433': 'http://www.wikidata.org/entity/Q203995',
#  '2836084': 'http://www.wikidata.org/entity/Q32289922',
#  '2649723': 'http://www.wikidata.org/entity/Q623687',
#  '2641599': 'http://www.wikidata.org/entity/Q985594',
#  '2643620': 'http://www.wikidata.org/entity/Q1609815',
#  '2641617': 'http://www.wikidata.org/entity/Q3054629',
#  '1007311': 'http://www.wikidata.org/entity/Q5468',
#  '2907911': 'http://www.wikidata.org/entity/Q49277567',
#  '732800': 'http://www.wikidata.org/entity/Q219',
#  '1609350': 'http://www.wikidata.org/entity/Q1861',
#  '4265737': 'http://www.wikidata.org/entity/Q492478',
#  '2653822': 'http://www.wikidata.org/entity/Q10690',
#  '5318313': 'http://www.wikidata.org/entity/Q18575',
#  '357994': 'http://www.wikidata.org/entity/Q79',
#  '6115068': 'http://www.wikidata.org/entity/Q210907',
#  '390903': 'http://www.wikidata.org/entity/Q41',
#  '2649715': 'http://www.wikidata.org/entity/Q478029',
#  '2633373': 'http://www.wikidata.org/entity/Q550110',
#  '1269515': 'http://www.wikidata.org/entity/Q31856823',
#  '2633432': 'http://www.wikidata.org/entity/Q3570246',
#  '2635459': 'http://www.wikidata.org/entity/Q10999',
#  '5134086': 'http://www.wikidata.org/entity/Q49218',
#  '5355113': 'http://www.wikidata.org/entity/Q1950508',
#  '2645756': 'http://www.wikidata.org/entity/Q1025076',
#  '8505033': 'http://www.wikidata.org/entity/Q37024',
#  '2653947': 'http://www.wikidata.org/entity/Q741400',
#  '2649730': 'http://www.wikidata.org/entity/Q237650',
#  '2088628': 'http://www.wikidata.org/entity/Q691',
#  '953987': 'http://www.wikidata.org/entity/Q258',
#  '2655858': 'http://www.wikidata.org/entity/Q19784',
#  '7298744': 'http://www.wikidata.org/entity/Q2677260',
#  '2649872': 'http://www.wikidata.org/entity/Q2915922',
#  '5809844': 'http://www.wikidata.org/entity/Q5083',
#  '2633485': 'http://www.wikidata.org/entity/Q496368',
#  '5185267': 'http://www.wikidata.org/entity/Q1133674',
#  '2666199': 'http://www.wikidata.org/entity/Q25286',
#  '2653941': 'http://www.wikidata.org/entity/Q350',
#  '2651817': 'http://www.wikidata.org/entity/Q2213391',
#  '2656014': 'http://www.wikidata.org/entity/Q814121',
#  '2649808': 'http://www.wikidata.org/entity/Q134672',
#  '4138666': 'http://www.wikidata.org/entity/Q2019662',
#  '4361885': 'http://www.wikidata.org/entity/Q1391',
#  '5224151': 'http://www.wikidata.org/entity/Q18383',
#  '2639524': 'http://www.wikidata.org/entity/Q1010210',
#  '2639557': 'http://www.wikidata.org/entity/Q865716',
#  '2653877': 'http://www.wikidata.org/entity/Q29303',
#  '2635412': 'http://www.wikidata.org/entity/Q180803',
#  '2641557': 'http://www.wikidata.org/entity/Q660484',
#  '2909965': 'http://www.wikidata.org/entity/Q4186',
#  '3686110': 'http://www.wikidata.org/entity/Q739',
#  '4099753': 'http://www.wikidata.org/entity/Q1612',
#  '4990729': 'http://www.wikidata.org/entity/Q12439',
#  '2637487': 'http://www.wikidata.org/entity/Q79848',
#  '3032797': 'http://www.wikidata.org/entity/Q49346118',
#  '8394366': 'http://www.wikidata.org/entity/Q147127',
#  '2655861': 'http://www.wikidata.org/entity/Q584443',
#  '2645724': 'http://www.wikidata.org/entity/Q844062',
#  '2215636': 'http://www.wikidata.org/entity/Q1016',
#  '2655853': 'http://www.wikidata.org/entity/Q822040',
#  '4140704': 'http://www.wikidata.org/entity/Q35525',
#  '2965140': 'http://www.wikidata.org/entity/Q36647',
#  '2643567': 'http://www.wikidata.org/entity/Q537323',
#  '6690574': 'http://www.wikidata.org/entity/Q124129',
#  '2649800': 'http://www.wikidata.org/entity/Q1007093',
#  '2633352': 'http://www.wikidata.org/entity/Q42462',
#  '782061': 'http://www.wikidata.org/entity/Q223154',
#  '8505031': 'http://www.wikidata.org/entity/Q33946',
#  '2639577': 'http://www.wikidata.org/entity/Q161491',
#  '2641637': 'http://www.wikidata.org/entity/Q573788',
#  '2647793': 'http://www.wikidata.org/entity/Q213465',
#  '2635427': 'http://www.wikidata.org/entity/Q265647',
#  '2641673': 'http://www.wikidata.org/entity/Q1425428',
#  '2639545': 'http://www.wikidata.org/entity/Q1851095',
#  '2756253': 'http://www.wikidata.org/entity/Q33434749',
#  '5744337': 'http://www.wikidata.org/entity/Q824',
#  '2641546': 'http://www.wikidata.org/entity/Q750000',
#  '2879139': 'http://www.wikidata.org/entity/Q32067937',
#  '5279468': 'http://www.wikidata.org/entity/Q1537',
#  '5551752': 'http://www.wikidata.org/entity/Q816',
#  '2641661': 'http://www.wikidata.org/entity/Q369361',
#  '6942443': 'http://www.wikidata.org/entity/Q2309575',
#  '5037779': 'http://www.wikidata.org/entity/Q1527',
#  '2643697': 'http://www.wikidata.org/entity/Q1626288',
#  '2655942': 'http://www.wikidata.org/entity/Q2080375',
#  '4845193': 'http://www.wikidata.org/entity/Q49178',
#  '2267057': 'http://www.wikidata.org/entity/Q597',
#  '4566966': 'http://www.wikidata.org/entity/Q1183',
#  '5746545': 'http://www.wikidata.org/entity/Q6106',
#  '2641727': 'http://www.wikidata.org/entity/Q149691',
#  '2635650': 'http://www.wikidata.org/entity/Q209055',
#  '298795': 'http://www.wikidata.org/entity/Q43',
#  '2649873': 'http://www.wikidata.org/entity/Q617407',
#  '2652053': 'http://www.wikidata.org/entity/Q844908',
#  '2635703': 'http://www.wikidata.org/entity/Q936183',
#  '7294819': 'http://www.wikidata.org/entity/Q2134903',
#  '98228': 'http://www.wikidata.org/entity/Q5684',
#  '2510769': 'http://www.wikidata.org/entity/Q29',
#  '2641843': 'http://www.wikidata.org/entity/Q2003342',
#  '2641689': 'http://www.wikidata.org/entity/Q655874',
#  '2635571': 'http://www.wikidata.org/entity/Q940877',
#  '2643743': 'http://www.wikidata.org/entity/Q84',
#  '2635578': 'http://www.wikidata.org/entity/Q1757189',
#  '1275715': 'http://www.wikidata.org/entity/Q1165',
#  '2637607': 'http://www.wikidata.org/entity/Q1018565',
#  '4347778': 'http://www.wikidata.org/entity/Q5092',
#  '2637762': 'http://www.wikidata.org/entity/Q977991',
#  '4929376': 'http://www.wikidata.org/entity/Q2560090',
#  '3067696': 'http://www.wikidata.org/entity/Q1085',
#  '5506956': 'http://www.wikidata.org/entity/Q23768',
#  '6690593': 'http://www.wikidata.org/entity/Q2319878',
#  '5140405': 'http://www.wikidata.org/entity/Q128069',
#  '2633521': 'http://www.wikidata.org/entity/Q671348',
#  '2633583': 'http://www.wikidata.org/entity/Q1006232',
#  '2637627': 'http://www.wikidata.org/entity/Q211907',
#  '2635608': 'http://www.wikidata.org/entity/Q503375',
#  '2152274': 'http://www.wikidata.org/entity/Q36074',
#  '2652002': 'http://www.wikidata.org/entity/Q648810',
#  '2862926': 'http://www.wikidata.org/entity/Q1197',
#  '4140963': 'http://www.wikidata.org/entity/Q61',
#  '5259170': 'http://www.wikidata.org/entity/Q14714439',
#  '6690578': 'http://www.wikidata.org/entity/Q209714',
#  '6690590': 'http://www.wikidata.org/entity/Q122776',
#  '2332459': 'http://www.wikidata.org/entity/Q815913',
#  '6545170': 'http://www.wikidata.org/entity/Q123634',
#  '6545173': 'http://www.wikidata.org/entity/Q124010',
#  '2649937': 'http://www.wikidata.org/entity/Q146671',
#  '2647878': 'http://www.wikidata.org/entity/Q179406',
#  '2656046': 'http://www.wikidata.org/entity/Q208257',
#  '2652085': 'http://www.wikidata.org/entity/Q5182098',
#  '2656125': 'http://www.wikidata.org/entity/Q812895',
#  '2750405': 'http://www.wikidata.org/entity/Q29999',
#  '2647972': 'http://www.wikidata.org/entity/Q83475',
#  '2649957': 'http://www.wikidata.org/entity/Q993164',
#  '7626581': 'http://www.wikidata.org/entity/Q1919732',
#  '2510693': 'http://www.wikidata.org/entity/Q23979439',
#  '3028808': 'http://www.wikidata.org/entity/Q39984',
#  '2656173': 'http://www.wikidata.org/entity/Q22889',
#  '5105496': 'http://www.wikidata.org/entity/Q49278665',
#  '2635610': 'http://www.wikidata.org/entity/Q1007106',
#  '7296779': 'http://www.wikidata.org/entity/Q24666223',
#  '6545247': 'http://www.wikidata.org/entity/Q123024',
#  '2649911': 'http://www.wikidata.org/entity/Q637482',
#  '2645889': 'http://www.wikidata.org/entity/Q990168',
#  '2649963': 'http://www.wikidata.org/entity/Q990775',
#  '6690602': 'http://www.wikidata.org/entity/Q1138912',
#  '2633563': 'http://www.wikidata.org/entity/Q1646181',
#  '7300963': 'http://www.wikidata.org/entity/Q24670770',
#  '5140402': 'http://www.wikidata.org/entity/Q3056724',
#  '2656192': 'http://www.wikidata.org/entity/Q810196',
#  '5150529': 'http://www.wikidata.org/entity/Q37320',
#  '2647984': 'http://www.wikidata.org/entity/Q237253',
#  '2654141': 'http://www.wikidata.org/entity/Q971223',
#  '4839292': 'http://www.wikidata.org/entity/Q49172',
#  '2656065': 'http://www.wikidata.org/entity/Q123372',
#  '2645826': 'http://www.wikidata.org/entity/Q994575',
#  '7839574': 'http://www.wikidata.org/entity/Q969590',
#  '798549': 'http://www.wikidata.org/entity/Q218',
#  '6545250': 'http://www.wikidata.org/entity/Q148349',
#  '6545171': 'http://www.wikidata.org/entity/Q146747',
#  ...}

# %%
results = results.dropna(subset=['geonames_id', 'country_id'])
results[['geonames_id', 'country_id']] = results[['geonames_id', 'country_id']].astype(int).astype(str)

results['qid'] = results['geonames_id'].map(geoname_wikidata_mapping)
results['country_qid'] = results['country_id'].map(geoname_wikidata_mapping)

# %%
results.to_pickle("./places/placenames_to_qids.pkl")

# %%
results.head()
# Out:
#                                           place name  % collection  \
# 0    london, greater london, england, united kingdom     16.353221
# 1                            england, united kingdom      8.322525
# 2                                     united kingdom      4.790470
# 3                                             france      4.418350
# 4  manchester, manchester urban district, greater...      4.233834
#
#                                               name    geonames_address  \
# 0  london, greater london, england, united kingdom              London
# 1                                   united kingdom      United Kingdom
# 2                                   united kingdom      United Kingdom
# 3                                           france              France
# 4      greater manchester, england, united kingdom  Greater Manchester
#
#   geonames_id country_id                                    qid  \
# 0     2643743    2635167     http://www.wikidata.org/entity/Q84
# 1     2635167    2635167    http://www.wikidata.org/entity/Q145
# 2     2635167    2635167    http://www.wikidata.org/entity/Q145
# 3     3017382    3017382    http://www.wikidata.org/entity/Q142
# 4     2648108    2635167  http://www.wikidata.org/entity/Q23099
#
#                            country_qid
# 0  http://www.wikidata.org/entity/Q145
# 1  http://www.wikidata.org/entity/Q145
# 2  http://www.wikidata.org/entity/Q145
# 3  http://www.wikidata.org/entity/Q142
# 4  http://www.wikidata.org/entity/Q145

# %%
pd.read_pickle("./places/placenames_to_qids.pkl")
# Out:
#                                              place name  % collection  \
# 0       london, greater london, england, united kingdom     16.353221
# 1                               england, united kingdom      8.322525
# 2                                        united kingdom      4.790470
# 3                                                france      4.418350
# 4     manchester, manchester urban district, greater...      4.233834
# ...                                                 ...           ...
# 1794                                            grimsby      0.002316
# 1795    petersfield, hampshire, england, united kingdom      0.002316
# 1796                            schrobenhausen, germany      0.002316
# 1797  springfield, sangamon county, illinois, united...      0.002316
# 1799  fond du lac, fond du lac county, wisconsin, un...      0.002316
#
#                                                    name    geonames_address  \
# 0       london, greater london, england, united kingdom              London
# 1                                        united kingdom      United Kingdom
# 2                                        united kingdom      United Kingdom
# 3                                                france              France
# 4           greater manchester, england, united kingdom  Greater Manchester
# ...                                                 ...                 ...
# 1794                                            grimsby             Grimsby
# 1795    petersfield, hampshire, england, united kingdom         Petersfield
# 1796                            schrobenhausen, germany      Schrobenhausen
# 1797  springfield, sangamon county, illinois, united...         Springfield
# 1799  fond du lac, fond du lac county, wisconsin, un...         Fond du Lac
#
#      geonames_id country_id                                       qid  \
# 0        2643743    2635167        http://www.wikidata.org/entity/Q84
# 1        2635167    2635167       http://www.wikidata.org/entity/Q145
# 2        2635167    2635167       http://www.wikidata.org/entity/Q145
# 3        3017382    3017382       http://www.wikidata.org/entity/Q142
# 4        2648108    2635167     http://www.wikidata.org/entity/Q23099
# ...          ...        ...                                       ...
# 1794     2647878    2635167    http://www.wikidata.org/entity/Q179406
# 1795     2640348    2635167   http://www.wikidata.org/entity/Q1247815
# 1796     2836084    2921044  http://www.wikidata.org/entity/Q32289922
# 1797     4250542    6252001     http://www.wikidata.org/entity/Q28515
# 1799     5253352    6252001    http://www.wikidata.org/entity/Q985584
#
#                               country_qid
# 0     http://www.wikidata.org/entity/Q145
# 1     http://www.wikidata.org/entity/Q145
# 2     http://www.wikidata.org/entity/Q145
# 3     http://www.wikidata.org/entity/Q142
# 4     http://www.wikidata.org/entity/Q145
# ...                                   ...
# 1794  http://www.wikidata.org/entity/Q145
# 1795  http://www.wikidata.org/entity/Q145
# 1796  http://www.wikidata.org/entity/Q183
# 1797   http://www.wikidata.org/entity/Q30
# 1799   http://www.wikidata.org/entity/Q30
#
# [1690 rows x 8 columns]

# %%
results.loc[results['place name'] == 'united kingdom', 'qid'].values[0]
# Out:
# 'http://www.wikidata.org/entity/Q145'

# %%
results.loc[results['place name'] == str('united states').lower(), 'qid'].values
# Out:
# array([], dtype=object)
