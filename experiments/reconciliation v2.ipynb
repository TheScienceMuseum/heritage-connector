# %% [markdown]
# # Reconciliation v2: using text search

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("..")

import os

from heritageconnector.config import config, field_mapping
from heritageconnector.disambiguation.search import wikidata_text_search
from heritageconnector.utils.wikidata import url_to_qid
from heritageconnector.utils.data_transformation import transform_series_str_to_list
from heritageconnector.entity_matching.reconciler import reconciler

import pandas as pd
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)

from collections import Counter
from tqdm import tqdm

tqdm.pandas()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 1. load data sample

# %%
sample_no = 100
random_state = 42

# load mimsy_people
df = pd.read_csv(config.MIMSY_PEOPLE_PATH)
for col in ['FIRSTMID_NAME', 'LASTSUFF_NAME']:
    df[col] = df[col].fillna("").astype(str)
    
df['FREETEXT'] = df['DESCRIPTION'].astype(str) + " " + df['NOTE'].astype(str)

# load people df 
people_df = df[df['GENDER'].isin(('M', 'F'))]#.sample(sample_no, random_state=random_state)
people_df.loc[:, 'JOINED_NAME'] = people_df['FIRSTMID_NAME'] + " " + people_df['LASTSUFF_NAME']

# %% [markdown]
# ## 2. get subject items from PID
# We need to get types of entities that populate the `OCCUPATION` field in Wikidata.

# %%
qcode_filter = reconciler.get_subject_items_from_pid(field_mapping.PEOPLE['OCCUPATION']['PID'])
qcode_filter
# qcodes for profession, occupation
# Out:
# ['Q28640', 'Q12737077']

# %% [markdown]
# ## 3. get matches for one occupation

# %%
search = wikidata_text_search()
search.run_search("captain", instanceof_filter=qcode_filter, include_class_tree=True)
# Out:
#    rank                                     item         itemLabel  score
# 0     1   http://www.wikidata.org/entity/Q163500           captain    0.4
# 1     2   http://www.wikidata.org/entity/Q715772           captain    0.3
# 2     3  http://www.wikidata.org/entity/Q5036514           captain    0.2
# 3     4  http://www.wikidata.org/entity/Q1146304  pilot in command    0.1
# 4     5   http://www.wikidata.org/entity/Q849424      ship captain    0.0

# %%
# not an occupation
search.run_search("conjoined twin", instanceof_filter=qcode_filter, include_class_tree=True)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## 4. get matches for all occupations
# This will become a job in `smg_jobs`.

# %% [markdown]
# ### 4.1. create mapping table

# %%
def str_col_to_list(series, separator=";"):
    return series.fillna("").astype(str).apply(lambda i: [x.strip().lower() for x in i.split(separator)])

people_df['OCCUPATION_list'] = str_col_to_list(people_df['OCCUPATION'])

all_names = people_df['OCCUPATION_list'].sum()
all_names = [i for i in all_names if i != ""]
series_count = pd.Series(Counter(all_names)).sort_values(ascending=False)

print(len(series_count))
series_count.head()
# Out:
# 2216
# /Users/kalyan/.local/share/virtualenvs/heritage-connector-tkmarX41/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# artist           1097
# photographer      918
# physician         605
# inventor          579
# poster artist     569
# dtype: int64

# %%
map_df = pd.DataFrame(series_count).rename(columns={0: 'count'})
map_df.head()
# Out:
#                count
# artist          1097
# photographer     918
# physician        605
# inventor         579
# poster artist    569

# %%
def lookup_value(text):
    res_df = search.run_search(text, instanceof_filter=qcode_filter, include_class_tree=True)
    if len(res_df) == 0:
        return []
    else:
        return [url_to_qid(i) for i in res_df['item'].tolist()]

map_df['qid'] = map_df.index.to_series().progress_apply(lookup_value)
# Out:
# 100%|██████████| 82/82 [00:57<00:00,  1.42it/s]

# %%
map_df
# Out:
#                  count  \
# poster artist        9
# photographer         8
# artist               7
# inventor             6
# scientist            5
# ...                ...
# apprentice           1
# captain              1
# railway manager      1
# biologist            1
# conjoined twin       1
#
#                                                                                    qid
# poster artist                                                                [Q739437]
# photographer                                                        [Q7187777, Q33231]
# artist           [Q483501, Q706364, Q1320883, Q3391743, Q1797162, Q13381572, Q1630100]
# inventor                                                                     [Q205375]
# scientist                                                                       [Q901]
# ...                                                                                ...
# apprentice                                               [Q11353322, Q742585, Q253567]
# captain                                [Q163500, Q715772, Q5036514, Q1146304, Q849424]
# railway manager                                                                     []
# biologist                                                                    [Q864503]
# conjoined twin                                                                      []
#
# [82 rows x 2 columns]

# %%
map_df.loc[['scientist', 'captain'], 'qid'].values.sum()
# Out:
# ['Q901', 'Q163500', 'Q715772', 'Q5036514', 'Q1146304', 'Q849424']

# %% [markdown]
# ### 4.2 populate new field using mapping table

# %%
qid_col = "OCCUPATION" + "_qid"
list_col = "OCCUPATION_list"

people_df[qid_col] = people_df[list_col].progress_apply(lambda x: map_df.loc[x, 'qid'].values.sum() if x != [''] else [])
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 1532.23it/s]

# %%
people_df
# Out:
#        LINK_ID           PREFERRED_NAME TITLE_NAME  FIRSTMID_NAME  \
# 1055     30775          Dunlop, Gilbert        NaN        Gilbert
# 7730    100294                     T, F        NaN              F
# 16648   138234            Watt, Brandon        NaN
# 9785    116857        Cipriani, Galgano        NaN        Galgano
# 6500     92187   Bodonius, Giambattista        NaN   Giambattista
# ...        ...                      ...        ...            ...
# 11947    93651  Dieulafoy, Paul Georges        NaN   Paul Georges
# 499       2314           Gilfillan, Tom        NaN            Tom
# 13843   128523      Wood, Edward George        NaN  Edward George
# 5009      8041                 Short, J        NaN              J
# 5739     81619        Chulkhurst, Elisa        NaN          Elisa
#
#        LASTSUFF_NAME SUFFIX_NAME HONORARY_SUFFIX GENDER BRIEF_BIO  \
# 1055          Dunlop         NaN             NaN      M         N
# 7730               T         NaN             NaN      M         Y
# 16648  Watt, Brandon         NaN             NaN      M         N
# 9785        Cipriani         NaN             NaN      M         Y
# 6500        Bodonius         NaN             NaN      M         Y
# ...              ...         ...             ...    ...       ...
# 11947      Dieulafoy         NaN             NaN      M         Y
# 499        Gilfillan         NaN             NaN      M         N
# 13843           Wood         NaN             NaN      M         Y
# 5009           Short         NaN             NaN      M         Y
# 5739      Chulkhurst         NaN             NaN      F         Y
#
#                                                                                                                                                                                                                                                                   DESCRIPTION  \
# 1055                                                                                                                                                                                                                                                                      NaN
# 7730                                                                                                                                                                                                                                                                      NaN
# 16648                                                                                                                                                                                                                                                                     NaN
# 9785                                                                                                                                                                                                                                      object records 1923 -667 & 1923-668
# 6500                                                                                                                                                                                                                                                                    WIKI:
# ...                                                                                                                                                                                                                                                                       ...
# 11947  http://cancerweb.ncl.ac.uk/; http://en.wikipedia.org/wiki/Paul_Georges_Dieulafoy; A Bibliography of Medical and Biomeidcal Biography http://books.google.co.uk/books?id=EM-UsLI0P4IC&pg=PA279&dq=o%27dwyer+1841-1898&as_brr=3&sig=XIl6i4o2NpkSy5nxCLbKwqvayZM#PPA96,M1
# 499                                                                                                                                                                                                                                                        NRM Pictorial Coll
# 13843                                                                                                                                                                              Webster database – WOOD, EDWARD GEORGE [http://historydb.adlerplanetarium.org/signatures/]
# 5009                                                                                                                                                                                                                                                                      NaN
# 5739                                                                                                                                                                                                                        http://www.biddendenkent.co.uk/localhistory1.html
#
#                                                                                                                                                                                      NOTE  \
# 1055                                                                                                                                                                                  NaN
# 7730                                                                                                                                                                                  NaN
# 16648                                                                                                                                                                                 NaN
# 9785                                                                                                                                                                                  NaN
# 6500                                                                                                                                                                                  NaN
# ...                                                                                                                                                                                   ...
# 11947  Physician best known for his study of acute appendicitis and his description of Dieulafoy's lesion, a rare cause of gastric bleeding. c.f. Dieulafoy's erosion; Dieulafoy's theory
# 499                                                                                                                                                                                   NaN
# 13843                                                                                    Traded at 7 Shepperton Street, New North Road & 74 Cheapside (1851-93), both in London, England.
# 5009                                                                                                                                                2 Gladstone Street, Southwark, London
# 5739                                                                                                                                                                                  NaN
#
#        BIRTH_DATE                                     BIRTH_PLACE  DEATH_DATE  \
# 1055          NaN                                             NaN         NaN
# 7730          NaN                                             NaN         NaN
# 16648         NaN                                             NaN         NaN
# 9785          NaN                                             NaN         NaN
# 6500   1740-02-16                                         Saluzzo  1813-11-29
# ...           ...                                             ...         ...
# 11947        1839  Toulouse, Haute-Garonne, Midi-Pyrénées, France        1911
# 499           NaN                                             NaN         NaN
# 13843         NaN                                             NaN         NaN
# 5009          NaN                                             NaN         NaN
# 5739         1100        Biddenden, Kent, England, United Kingdom        1134
#
#                                         DEATH_PLACE CAUSE_OF_DEATH  \
# 1055                                            NaN            NaN
# 7730                                            NaN            NaN
# 16648                                           NaN            NaN
# 9785                                            NaN            NaN
# 6500   Parma, Parma province, Emilia-Romagna, Italy            NaN
# ...                                             ...            ...
# 11947  Paris, Ville de Paris, Île-de-France, France            NaN
# 499                                             NaN            NaN
# 13843                                           NaN            NaN
# 5009                                            NaN            NaN
# 5739                                            NaN            NaN
#
#             NATIONALITY                                      OCCUPATION  \
# 1055            British                      poster artist; illustrator
# 7730             French                                       medallist
# 16648               NaN                                             NaN
# 9785            Italian                      maker of telescope replica
# 6500            Italian  typographer; type-designer; printer; publisher
# ...                 ...                                             ...
# 11947            French                 physician; surgeon; pathologist
# 499             British                          painter; poster artist
# 13843  English; British        optical & philosophical instrument maker
# 5009            British                                             NaN
# 5739            English                                  conjoined twin
#
#                                  WEBSITE  AFFILIATION  LINGUISTIC_GROUP TYPE  \
# 1055                                 NaN          NaN               NaN  NaN
# 7730                                 NaN          NaN               NaN  NaN
# 16648  http://www.woi3d.com/thingiverse3          NaN               NaN  NaN
# 9785                                 NaN          NaN               NaN  NaN
# 6500                                 NaN          NaN               NaN  NaN
# ...                                  ...          ...               ...  ...
# 11947                                NaN          NaN               NaN  NaN
# 499                                  NaN          NaN               NaN  NaN
# 13843                                NaN          NaN               NaN  NaN
# 5009                                 NaN          NaN               NaN  NaN
# 5739                                 NaN          NaN               NaN  NaN
#
#        REFERENCE_NUMBER SOURCE CREATE_DATE UPDATE_DATE  \
# 1055                NaN      N   14-FEB-01   19-MAR-10
# 7730                NaN      N   06-JAN-05   23-JUL-15
# 16648               NaN      Y   20-JUN-13   03-OCT-17
# 9785                NaN      N   30-JAN-07   09-SEP-10
# 6500                NaN      N   06-JAN-05   23-JUL-15
# ...                 ...    ...         ...         ...
# 11947               NaN      N   06-JAN-05   14-DEC-15
# 499                 NaN      N   21-AUG-96   08-MAR-11
# 13843               NaN      N   05-JAN-10   25-OCT-11
# 5009                NaN      N   31-DEC-97   11-NOV-12
# 5739                NaN      N   06-JAN-05   14-DEC-15
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                         FREETEXT  \
# 1055                                                                                                                                                                                                                                                                                                                                                                                                                                                     nan nan
# 7730                                                                                                                                                                                                                                                                                                                                                                                                                                                     nan nan
# 16648                                                                                                                                                                                                                                                                                                                                                                                                                                                    nan nan
# 9785                                                                                                                                                                                                                                                                                                                                                                                                                     object records 1923 -667 & 1923-668 nan
# 6500                                                                                                                                                                                                                                                                                                                                                                                                                                                   WIKI: nan
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# 11947  http://cancerweb.ncl.ac.uk/; http://en.wikipedia.org/wiki/Paul_Georges_Dieulafoy; A Bibliography of Medical and Biomeidcal Biography http://books.google.co.uk/books?id=EM-UsLI0P4IC&pg=PA279&dq=o%27dwyer+1841-1898&as_brr=3&sig=XIl6i4o2NpkSy5nxCLbKwqvayZM#PPA96,M1 Physician best known for his study of acute appendicitis and his description of Dieulafoy's lesion, a rare cause of gastric bleeding. c.f. Dieulafoy's erosion; Dieulafoy's theory
# 499                                                                                                                                                                                                                                                                                                                                                                                                                                       NRM Pictorial Coll nan
# 13843                                                                                                                                                                                                                                                                Webster database – WOOD, EDWARD GEORGE [http://historydb.adlerplanetarium.org/signatures/] Traded at 7 Shepperton Street, New North Road & 74 Cheapside (1851-93), both in London, England.
# 5009                                                                                                                                                                                                                                                                                                                                                                                                                   nan 2 Gladstone Street, Southwark, London
# 5739                                                                                                                                                                                                                                                                                                                                                                                                       http://www.biddendenkent.co.uk/localhistory1.html nan
#
#                   JOINED_NAME  \
# 1055           Gilbert Dunlop
# 7730                      F T
# 16648           Watt, Brandon
# 9785         Galgano Cipriani
# 6500    Giambattista Bodonius
# ...                       ...
# 11947  Paul Georges Dieulafoy
# 499             Tom Gilfillan
# 13843      Edward George Wood
# 5009                  J Short
# 5739         Elisa Chulkhurst
#
#                                         OCCUPATION_list  \
# 1055                       [poster artist, illustrator]
# 7730                                        [medallist]
# 16648                                                []
# 9785                       [maker of telescope replica]
# 6500   [typographer, type-designer, printer, publisher]
# ...                                                 ...
# 11947                 [physician, surgeon, pathologist]
# 499                            [painter, poster artist]
# 13843        [optical & philosophical instrument maker]
# 5009                                                 []
# 5739                                   [conjoined twin]
#
#                                                                            OCCUPATION_qid
# 1055   [Q739437, Q644687, Q1114448, Q3148760, Q19507792, Q15296811, Q27943388, Q60558844]
# 7730                                                                           [Q1708232]
# 16648                                                                                  []
# 9785                                                                                   []
# 6500                          [Q1229025, Q354034, Q40881196, Q175151, Q2516866, Q7258095]
# ...                                                                                   ...
# 11947        [Q39631, Q551835, Q15924224, Q7646178, Q774306, Q1360697, Q781850, Q3368718]
# 499                          [Q288728, Q94320712, Q1028181, Q15301511, Q1630100, Q739437]
# 13843                                                                                  []
# 5009                                                                                   []
# 5739                                                                                   []
#
# [100 rows x 30 columns]

# %% [markdown]
# ## 5. Heritage Connector implementation

# %%
people_df_processed = people_df.copy()
people_df_processed['OCCUPATION'] = transform_series_str_to_list(people_df_processed['OCCUPATION'], separator=";")
people_df_processed.head(2)
# Out:
#    LINK_ID          PREFERRED_NAME TITLE_NAME  FIRSTMID_NAME LASTSUFF_NAME  \
# 1    10245  Zenthon, Edward Rupert        NaN  Edward Rupert       Zenthon
# 2    10269         Troughton, John        NaN           John     Troughton
#
#   SUFFIX_NAME HONORARY_SUFFIX GENDER BRIEF_BIO  \
# 1         NaN             NaN      M         Y
# 2         NaN             NaN      M         Y
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              DESCRIPTION  \
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                          REF: http://www.iwm.org.uk/collections/item/object/1030031461
# 2  1739 - Born in Corney, Cumbria, England; Apprenticed to his Uncle John Troughton \n1764 - traded at Surrey St., Strand, London \n1768-71 - traded at Crown Court, Fleet St., London\n1771-78 - traded at 17 Dean St., Fetter Lane, London \n1778-82 - traded at 1 Queen's Sq., Bartholomew Close, London \n1782 - purchased the business of Benjamin Cole  \n1782-1788 - traded at the sign of the Orrery, 136 Fleet St, London, England.  \n1788-1804 - in partnership as J & E Troughton, with brother Edward Troughton (1756-1835)
#
#                                                                                                                                                                                                                                                                                                                                                                                                                           NOTE  \
# 1                                                                                                                                                                                                                                                                                                                                                                                                                          NaN
# 2  ODNB: Anita McConnell, ‘Troughton, Edward (1753–1835)’, Oxford Dictionary of National Biography, Oxford University Press, 2004; online edn, May 2005 [http://www.oxforddnb.com/view/article/27767]\nREF: A. McConnell, Instrument makers to the world: a history of Cooke, Troughton & Simms (1992) · A. W. Skempton and J. Brown, ‘John and Edward Troughton’, Notes and Records of the Royal Society, 27 (1972–3), 233–62
#
#   BIRTH_DATE                                             BIRTH_PLACE  \
# 1    1920-07         London, Greater London, England, United Kingdom
# 2       1739  Broughton in Furness, Cumbria, England, United Kingdom
#
#   DEATH_DATE                                      DEATH_PLACE CAUSE_OF_DEATH  \
# 1    c. 2002                                              NaN            NaN
# 2       1807  London, Greater London, England, United Kingdom            NaN
#
#         NATIONALITY                       OCCUPATION WEBSITE  AFFILIATION  \
# 1           British                       [engineer]     NaN          NaN
# 2  English; British  [mathematical instrument maker]     NaN          NaN
#
#    LINGUISTIC_GROUP TYPE  REFERENCE_NUMBER SOURCE CREATE_DATE UPDATE_DATE  \
# 1               NaN  NaN               NaN      N   28-JAN-98   05-AUG-15
# 2               NaN  NaN               NaN      N   28-JAN-98   06-NOV-18
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             FREETEXT  \
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  REF: http://www.iwm.org.uk/collections/item/object/1030031461 nan
# 2  1739 - Born in Corney, Cumbria, England; Apprenticed to his Uncle John Troughton \n1764 - traded at Surrey St., Strand, London \n1768-71 - traded at Crown Court, Fleet St., London\n1771-78 - traded at 17 Dean St., Fetter Lane, London \n1778-82 - traded at 1 Queen's Sq., Bartholomew Close, London \n1782 - purchased the business of Benjamin Cole  \n1782-1788 - traded at the sign of the Orrery, 136 Fleet St, London, England.  \n1788-1804 - in partnership as J & E Troughton, with brother Edward Troughton (1756-1835) ODNB: Anita McConnell, ‘Troughton, Edward (1753–1835)’, Oxford Dictionary of National Biography, Oxford University Press, 2004; online edn, May 2005 [http://www.oxforddnb.com/view/article/27767]\nREF: A. McConnell, Instrument makers to the world: a history of Cooke, Troughton & Simms (1992) · A. W. Skempton and J. Brown, ‘John and Edward Troughton’, Notes and Records of the Royal Society, 27 (1972–3), 233–62
#
#              JOINED_NAME                  OCCUPATION_list
# 1  Edward Rupert Zenthon                       [engineer]
# 2         John Troughton  [mathematical instrument maker]

# %%
rec = reconciler(people_df_processed, table='people')
#people_df_processed['OCCUPATION_qids'] = 
map_df = rec.process_column('OCCUPATION', multiple_vals=True)
map_df
# Out:
#   0%|          | 0/2216 [00:00<?, ?it/s]
# Looking up Wikidata qcodes for unique items..
# 100%|██████████| 2216/2216 [18:05<00:00,  2.04it/s]
# 100%|██████████| 10352/10352 [00:04<00:00, 2172.56it/s]
# 1                                                                          [Q151197, Q81096]
# 2                                                                                [Q66060335]
# 3                                                                         [Q7187777, Q33231]
# 4                                                                                         []
# 5                                                                                  [Q205375]
#                                                 ...
# 18090                                                                    [Q157798, Q2700922]
# 18091                                                                    [Q157798, Q2700922]
# 18092    [Q482980, Q15296811, Q36180, Q901, Q947873, Q2722764, Q270389, Q1371925, Q13590141]
# 18093                  [Q483501, Q706364, Q1320883, Q3391743, Q1797162, Q13381572, Q1630100]
# 18094                          [Q7042855, Q589298, Q1607826, Q3024627, Q17342450, Q23016178]
# Name: OCCUPATION, Length: 10352, dtype: object
