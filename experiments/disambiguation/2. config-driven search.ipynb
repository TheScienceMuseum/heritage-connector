# %% [markdown]
# # Config-Driven Search
# We want the `search` step of the disambiguation driven by a SPARQL query which is automatically generated given the collection schema.

# %%
import sys
sys.path.append('../..')

from heritageconnector.config import config
from heritageconnector.utils.sparql import get_sparql_results

import os

import pandas as pd
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

# %% [markdown]
# ## 1. import data

# %%
df = pd.read_csv(os.path.join("..", config.MIMSY_PEOPLE_PATH))
df['FREETEXT'] = df['DESCRIPTION'].astype(str) + " " + (df['NOTE']).astype(str)

for col in ['FIRSTMID_NAME', 'LASTSUFF_NAME']:
    df[col] = df[col].fillna("").astype(str)

print(df.columns)
df.head(2)
# Out:
# Index(['LINK_ID', 'PREFERRED_NAME', 'TITLE_NAME', 'FIRSTMID_NAME',
#        'LASTSUFF_NAME', 'SUFFIX_NAME', 'HONORARY_SUFFIX', 'GENDER',
#        'BRIEF_BIO', 'DESCRIPTION', 'NOTE', 'BIRTH_DATE', 'BIRTH_PLACE',
#        'DEATH_DATE', 'DEATH_PLACE', 'CAUSE_OF_DEATH', 'NATIONALITY',
#        'OCCUPATION', 'WEBSITE', 'AFFILIATION', 'LINGUISTIC_GROUP', 'TYPE',
#        'REFERENCE_NUMBER', 'SOURCE', 'CREATE_DATE', 'UPDATE_DATE', 'FREETEXT'],
#       dtype='object')
#    LINK_ID          PREFERRED_NAME TITLE_NAME  FIRSTMID_NAME  \
# 0    10243   Brooklyn Arms Company        NaN
# 1    10245  Zenthon, Edward Rupert        NaN  Edward Rupert
#
#            LASTSUFF_NAME SUFFIX_NAME HONORARY_SUFFIX GENDER BRIEF_BIO  \
# 0  Brooklyn Arms Company         NaN             NaN      N         Y
# 1                Zenthon         NaN             NaN      M         Y
#
#                                                      DESCRIPTION  \
# 0                                                            NaN
# 1  REF: http://www.iwm.org.uk/collections/item/object/1030031461
#
#                        NOTE BIRTH_DATE  \
# 0  object record: 1987-1020    c. 1870
# 1                       NaN    1920-07
#
#                                          BIRTH_PLACE DEATH_DATE DEATH_PLACE  \
# 0  Brooklyn, New York, New York state, United States        NaN         NaN
# 1    London, Greater London, England, United Kingdom    c. 2002         NaN
#
#   CAUSE_OF_DEATH NATIONALITY                                OCCUPATION  \
# 0            NaN    American  manufacturer of mathematical instruments
# 1            NaN     British                                  engineer
#
#   WEBSITE  AFFILIATION  LINGUISTIC_GROUP TYPE  REFERENCE_NUMBER SOURCE  \
# 0     NaN          NaN               NaN  NaN               NaN      N
# 1     NaN          NaN               NaN  NaN               NaN      N
#
#   CREATE_DATE UPDATE_DATE  \
# 0   28-JAN-98   06-NOV-18
# 1   28-JAN-98   05-AUG-15
#
#                                                             FREETEXT
# 0                                       nan object record: 1987-1020
# 1  REF: http://www.iwm.org.uk/collections/item/object/1030031461 nan

# %%
people_df = df[df['GENDER'].isin(['M','F'])].copy()
org_df = df[df['GENDER'] == 'N'].copy()

people_df.loc[:, 'TYPE'] = 'Q5'
org_df.loc[:, 'TYPE'] = 'Q43229'

people_df.loc[:, 'GENDER_QID'] = people_df.loc[:, 'GENDER'].map({"M": "Q6581097", "F": "Q6581072"})
people_df.loc[:, 'JOINED_NAME'] = people_df['FIRSTMID_NAME'] + " " + people_df['LASTSUFF_NAME']

# %% [markdown]
# ## 2. build query driven from schema
# - label col used in EntitySearch
# - type & categorical cols used as filters on results (as we already have values for these)
# - other cols used as filters to narrow down list of entity candidates. Scoring function depends on their type
#
# **This query should get a list of entities matching the search term and filtered by any known QIDs, as well as all the other
# properties specified.**

# %%
sum(w * score(col))

# %%
# people
cols_use = ['JOINED_NAME',
'FIRSTMID_NAME',
'LASTSUFF_NAME',
'GENDER',
'FREETEXT',
'BIRTH_DATE',
'BIRTH_PLACE',
'DEATH_DATE',
'DEATH_PLACE',
'NATIONALITY',
'OCCUPATION']

# to query on
label_col = 'JOINED_NAME' # WD label/alias
type_col = 'TYPE' # instance or subclass of
subclass_of = False

# to return
desc_cols = ['FREETEXT'] # WD description
str_cols = {'FIRSTMID_NAME': 'P735', 'LASTSUFF_NAME': 'P734'} # short str for Levenshtein matching
date_cols = {'BIRTH_DATE': 'P569', 'DEATH_DATE': 'P570'} # to be converted to date (should have already been converted)
place_cols = {'BIRTH_PLACE': 'P19', 'DEATH_PLACE': 'P20'} # could be treated as location or string
cat_cols = {'GENDER': 'P21', 'NATIONALITY': 'P27', 'OCCUPATION': 'P106'} # to be treated as qcode or string
return_dict = {**str_cols, **date_cols, **place_cols, **cat_cols}

config_dict = {}
config_dict['label'] = label_col
config_dict['type'] = type_col
config_dict['subclass_flag'] = subclass_of
config_dict['return'] = return_dict

# functions to generate query subsets
def generate_return_expressions(return_dict):
    select_slug = "?" + " ?".join(return_dict.keys())
    body_exp = "\n".join([f"OPTIONAL{{ ?item wdt:{v} ?{k} .}}" for k,v in return_dict.items()])
    
    return select_slug, body_exp

generate_return_expressions(return_dict)
# Out:
# ('?FIRSTMID_NAME ?LASTSUFF_NAME ?BIRTH_DATE ?DEATH_DATE ?BIRTH_PLACE ?DEATH_PLACE ?GENDER ?NATIONALITY ?OCCUPATION',
#  'OPTIONAL{ ?item wdt:P735 ?FIRSTMID_NAME .}\nOPTIONAL{ ?item wdt:P734 ?LASTSUFF_NAME .}\nOPTIONAL{ ?item wdt:P569 ?BIRTH_DATE .}\nOPTIONAL{ ?item wdt:P570 ?DEATH_DATE .}\nOPTIONAL{ ?item wdt:P19 ?BIRTH_PLACE .}\nOPTIONAL{ ?item wdt:P20 ?DEATH_PLACE .}\nOPTIONAL{ ?item wdt:P21 ?GENDER .}\nOPTIONAL{ ?item wdt:P27 ?NATIONALITY .}\nOPTIONAL{ ?item wdt:P106 ?OCCUPATION .}')

# %%
# TODO: figure out a better way of doing string search - CONTAINS / remove punctuation?

def run_query(row, config_dict):
    endpoint_url = "https://query.wikidata.org/sparql"
    
    label_val = row[config_dict['label']].values[0]
    type_val = row[config_dict['type']].values[0]
    
    return_select, return_body = generate_return_expressions(config_dict['return'])
    
    class_tree = "/wdt:P279*" if config_dict['subclass_flag'] else ""
    sparq_instanceof = f"?item wdt:P31{class_tree} wd:{type_val}."
    
    query = f"""
    SELECT ?item ?itemLabel ?itemDescription ?altLabel {return_select}
        WHERE
        {{
            SERVICE wikibase:mwapi {{
                bd:serviceParam wikibase:api "EntitySearch" .
                bd:serviceParam wikibase:endpoint "www.wikidata.org" .
                bd:serviceParam mwapi:search "{label_val}" .
                bd:serviceParam mwapi:language "en" .
                # ?item wikibase:apiOutputItem mwapi:item .
                # ?num wikibase:apiOrdinal true .
              }}
            {sparq_instanceof}
            {return_body}
            
            OPTIONAL {{
                # ?item skos:altLabel ?altLabel .
                FILTER (lang(?altLabel) = "en")
                }}

            SERVICE wikibase:label {{ 
            bd:serviceParam wikibase:language "en" .
            }}
        }}
            """
    
    res = get_sparql_results(endpoint_url, query)['results']['bindings']
    res_df = pd.json_normalize(res)
    res_df = res_df[[col for col in res_df.columns if "value" in col]]
    return res_df

# %%
row = people_df[people_df['LINK_ID'] == 116957]
row
# Out:
#        LINK_ID PREFERRED_NAME TITLE_NAME FIRSTMID_NAME LASTSUFF_NAME  \
# 10013   116957   Draper, John        NaN          John        Draper
#
#       SUFFIX_NAME HONORARY_SUFFIX GENDER BRIEF_BIO  \
# 10013         NaN             NaN      M         Y
#
#                                                                                DESCRIPTION  \
# 10013  [http://encarta.msn.com/encyclopedia_762511344/Draper_John_William.html]; Wikipedia
#
#                                NOTE  BIRTH_DATE  \
# 10013  researched in photochemistry  1811-05-05
#
#                                                        BIRTH_PLACE  \
# 10013  St. Helens, St. Helens, Merseyside, England, United Kingdom
#
#        DEATH_DATE                        DEATH_PLACE CAUSE_OF_DEATH  \
# 10013  1882-01-04  Hastings, New York, United States            NaN
#
#              NATIONALITY          OCCUPATION WEBSITE  AFFILIATION  \
# 10013  English; American  chemist; historian     NaN          NaN
#
#        LINGUISTIC_GROUP TYPE  REFERENCE_NUMBER SOURCE CREATE_DATE UPDATE_DATE  \
# 10013               NaN   Q5               NaN      N   19-FEB-07   20-AUG-14
#
#                                                                                                                FREETEXT  \
# 10013  [http://encarta.msn.com/encyclopedia_762511344/Draper_John_William.html]; Wikipedia researched in photochemistry
#
#       GENDER_QID  JOINED_NAME
# 10013   Q6581097  John Draper

# %%
run_query(row, config_dict)
# Out:
#                                   item.value      altLabel.value  \
# 0     http://www.wikidata.org/entity/Q712546              Crunch
# 1     http://www.wikidata.org/entity/Q712546      Captain Crunch
# 2     http://www.wikidata.org/entity/Q712546           Crunchman
# 3     http://www.wikidata.org/entity/Q712546  John Thomas Draper
# 4     http://www.wikidata.org/entity/Q712546              Crunch
# 5     http://www.wikidata.org/entity/Q712546      Captain Crunch
# 6     http://www.wikidata.org/entity/Q712546           Crunchman
# 7     http://www.wikidata.org/entity/Q712546  John Thomas Draper
# 8    http://www.wikidata.org/entity/Q6230091                 NaN
# 9   http://www.wikidata.org/entity/Q18819516                 NaN
# 10  http://www.wikidata.org/entity/Q21955255                 NaN
# 11  http://www.wikidata.org/entity/Q25714097                 NaN
# 12  http://www.wikidata.org/entity/Q34377643                 NaN
# 13  http://www.wikidata.org/entity/Q53765114                 NaN
# 14  http://www.wikidata.org/entity/Q53765112                 NaN
# 15  http://www.wikidata.org/entity/Q63179508                 NaN
# 16  http://www.wikidata.org/entity/Q63179508                 NaN
#
#                         FIRSTMID_NAME.value  \
# 0   http://www.wikidata.org/entity/Q4925477
# 1   http://www.wikidata.org/entity/Q4925477
# 2   http://www.wikidata.org/entity/Q4925477
# 3   http://www.wikidata.org/entity/Q4925477
# 4   http://www.wikidata.org/entity/Q4925477
# 5   http://www.wikidata.org/entity/Q4925477
# 6   http://www.wikidata.org/entity/Q4925477
# 7   http://www.wikidata.org/entity/Q4925477
# 8   http://www.wikidata.org/entity/Q4925477
# 9   http://www.wikidata.org/entity/Q4925477
# 10  http://www.wikidata.org/entity/Q4925477
# 11  http://www.wikidata.org/entity/Q4925477
# 12  http://www.wikidata.org/entity/Q4925477
# 13  http://www.wikidata.org/entity/Q4925477
# 14  http://www.wikidata.org/entity/Q4925477
# 15  http://www.wikidata.org/entity/Q4925477
# 16  http://www.wikidata.org/entity/Q4925477
#
#                          LASTSUFF_NAME.value      BIRTH_DATE.value  \
# 0   http://www.wikidata.org/entity/Q16869665  1943-03-11T00:00:00Z
# 1   http://www.wikidata.org/entity/Q16869665  1943-03-11T00:00:00Z
# 2   http://www.wikidata.org/entity/Q16869665  1943-03-11T00:00:00Z
# 3   http://www.wikidata.org/entity/Q16869665  1943-03-11T00:00:00Z
# 4   http://www.wikidata.org/entity/Q16869665  1943-03-11T00:00:00Z
# 5   http://www.wikidata.org/entity/Q16869665  1943-03-11T00:00:00Z
# 6   http://www.wikidata.org/entity/Q16869665  1943-03-11T00:00:00Z
# 7   http://www.wikidata.org/entity/Q16869665  1943-03-11T00:00:00Z
# 8                                        NaN  1890-08-26T00:00:00Z
# 9                                        NaN                   NaN
# 10                                       NaN  1929-01-01T00:00:00Z
# 11                                       NaN                   NaN
# 12                                       NaN  1883-11-14T00:00:00Z
# 13  http://www.wikidata.org/entity/Q16869665                   NaN
# 14  http://www.wikidata.org/entity/Q16869665                   NaN
# 15                                       NaN  1702-01-01T00:00:00Z
# 16                                       NaN  1702-01-01T00:00:00Z
#
#                            BIRTH_PLACE.value  \
# 0   http://www.wikidata.org/entity/Q13147795
# 1   http://www.wikidata.org/entity/Q13147795
# 2   http://www.wikidata.org/entity/Q13147795
# 3   http://www.wikidata.org/entity/Q13147795
# 4   http://www.wikidata.org/entity/Q13147795
# 5   http://www.wikidata.org/entity/Q13147795
# 6   http://www.wikidata.org/entity/Q13147795
# 7   http://www.wikidata.org/entity/Q13147795
# 8                                        NaN
# 9                                        NaN
# 10   http://www.wikidata.org/entity/Q4917406
# 11                                       NaN
# 12                                       NaN
# 13                                       NaN
# 14                                       NaN
# 15                                       NaN
# 16                                       NaN
#
#                                GENDER.value  \
# 0   http://www.wikidata.org/entity/Q6581097
# 1   http://www.wikidata.org/entity/Q6581097
# 2   http://www.wikidata.org/entity/Q6581097
# 3   http://www.wikidata.org/entity/Q6581097
# 4   http://www.wikidata.org/entity/Q6581097
# 5   http://www.wikidata.org/entity/Q6581097
# 6   http://www.wikidata.org/entity/Q6581097
# 7   http://www.wikidata.org/entity/Q6581097
# 8   http://www.wikidata.org/entity/Q6581097
# 9   http://www.wikidata.org/entity/Q6581097
# 10  http://www.wikidata.org/entity/Q6581097
# 11  http://www.wikidata.org/entity/Q6581097
# 12  http://www.wikidata.org/entity/Q6581097
# 13  http://www.wikidata.org/entity/Q6581097
# 14  http://www.wikidata.org/entity/Q6581097
# 15  http://www.wikidata.org/entity/Q6581097
# 16  http://www.wikidata.org/entity/Q6581097
#
#                          NATIONALITY.value  \
# 0       http://www.wikidata.org/entity/Q30
# 1       http://www.wikidata.org/entity/Q30
# 2       http://www.wikidata.org/entity/Q30
# 3       http://www.wikidata.org/entity/Q30
# 4       http://www.wikidata.org/entity/Q30
# 5       http://www.wikidata.org/entity/Q30
# 6       http://www.wikidata.org/entity/Q30
# 7       http://www.wikidata.org/entity/Q30
# 8                                      NaN
# 9   http://www.wikidata.org/entity/Q179876
# 10                                     NaN
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
# 14                                     NaN
# 15                                     NaN
# 16                                     NaN
#
#                            OCCUPATION.value             itemLabel.value  \
# 0     http://www.wikidata.org/entity/Q82594                 John Draper
# 1     http://www.wikidata.org/entity/Q82594                 John Draper
# 2     http://www.wikidata.org/entity/Q82594                 John Draper
# 3     http://www.wikidata.org/entity/Q82594                 John Draper
# 4      http://www.wikidata.org/entity/Q1487                 John Draper
# 5      http://www.wikidata.org/entity/Q1487                 John Draper
# 6      http://www.wikidata.org/entity/Q1487                 John Draper
# 7      http://www.wikidata.org/entity/Q1487                 John Draper
# 8     http://www.wikidata.org/entity/Q43845          John Draper Perrin
# 9   http://www.wikidata.org/entity/Q2259532                 John Draper
# 10  http://www.wikidata.org/entity/Q3014296  John Draper (motorcyclist)
# 11                                      NaN                 John Draper
# 12  http://www.wikidata.org/entity/Q1930187                   Q34377643
# 13    http://www.wikidata.org/entity/Q82955                 John Draper
# 14    http://www.wikidata.org/entity/Q82955                 John Draper
# 15  http://www.wikidata.org/entity/Q2516866                 John Draper
# 16  http://www.wikidata.org/entity/Q1930187                 John Draper
#
#                                        itemDescription.value  \
# 0       American computer programmer and former phone phreak
# 1       American computer programmer and former phone phreak
# 2       American computer programmer and former phone phreak
# 3       American computer programmer and former phone phreak
# 4       American computer programmer and former phone phreak
# 5       American computer programmer and former phone phreak
# 6       American computer programmer and former phone phreak
# 7       American computer programmer and former phone phreak
# 8                                Canadian business executive
# 9       Augustinian canon and bishop-suffragan of Winchester
# 10                                                       NaN
# 11                               Royal College of Physicians
# 12                                                       NaN
# 13                                        of Rochester, Kent
# 14                                                politician
# 15  1702-1762 , journalist and publisher, Boston News-Letter
# 16  1702-1762 , journalist and publisher, Boston News-Letter
#
#         DEATH_DATE.value
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8   1967-09-19T00:00:00Z
# 9   1552-01-01T00:00:00Z
# 10  2002-12-24T00:00:00Z
# 11                   NaN
# 12  1983-02-26T00:00:00Z
# 13                   NaN
# 14                   NaN
# 15  1762-01-01T00:00:00Z
# 16  1762-01-01T00:00:00Z
