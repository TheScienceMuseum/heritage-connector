# %% [markdown]
# # Filtered Shortest Path
#
# Finding all the shortest paths between two nodes, using a filtered set of properties.
#
# *outstanding questions:*
# - can we order/filter these paths by 'uniqueness'? (e.g. connecting people because they are humans isn't that interesting!)

# %%
# !pip install networkx
# Out:
# Collecting networkx
#   Downloading networkx-2.6.2-py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 4.3 MB/s eta 0:00:01
# Installing collected packages: networkx
# Successfully installed networkx-2.6.2
# WARNING: You are using pip version 20.3.3; however, version 21.2.4 is available.
# You should consider upgrading via the '/Users/kalyan/.pyenv/versions/3.9.1/envs/hc/bin/python -m pip install --upgrade pip' command.

# %%
# Imports
from rdflib import Graph
from rdflib.extras.external_graph_libs import rdflib_to_networkx_graph
import networkx as nx
from networkx import Graph as NXGraph
from networkx.algorithms.traversal.beamsearch import bfs_beam_edges
from networkx.algorithms.shortest_paths.generic import all_shortest_paths
from itertools import islice
import matplotlib.pyplot as plt
import statistics
import collections
import numpy as np
from rdflib import URIRef, Literal
import requests
import json

# %%
url = "https://d0rgkq.deta.dev/labels"

def get_labels(entities):
    payload = json.dumps({
      "uris": entities
    })
    headers = {
      'Content-Type': 'application/json'
    }

    return requests.post(url, headers=headers, data=payload).json()

# %%
# RDF graph loading
# This takes a while (10+ minutes). If you're working on a local machine it'll 
# be better to download the file from `path` below and give this notebook a 
# local path.
path = "https://heritageconnector.s3.eu-west-2.amazonaws.com/rdf/hc_dump_latest.nt"
rg = Graph()
rg.parse(path, format='nt')
print("rdflib Graph loaded successfully with {} triples".format(len(rg)))
# Out:
# rdflib Graph loaded successfully with 4821010 triples

# %%
# Optionally get a subgraph
# Here we filter out all the triples with skos:hasTopConcept 
# one of ({OBJECT, PERSON or ORGANISATION}) and sdo:isPartOf (describes collection
# membership for objects)
properties = [
    "hc:entityPERSON",
    "hc:entityORG",
    "hc:entityNORP",
    "hc:entityFAC",
    "hc:entityLOC",
    "hc:entityOBJECT",
    "hc:entityLANGUAGE",
    "hc:entityDATE",
    "sdo:birthDate",
    "sdo:deathDate",
    "sdo:foundingDate",
    "sdo:dissolutionDate",
    "foaf:maker",
    "foaf:made",
    "sdo:mentions",
    "owl:sameAs",
    "skos:related",
    "skos:relatedMatch",
#     "wdt:P101", # field of work
    "wdt:P1056",
#     "wdt:P106", # occupation
    "wdt:P127",
    "wdt:P135",
    "wdt:P136",
    "wdt:P137",
    "wdt:P1535",
#     "wdt:P17", # country
    "wdt:P176",
    "wdt:P18",
    "wdt:P180",
    "wdt:P20",
#     "wdt:P21", # sex or gender
    "wdt:P27",
    "wdt:P279",
    "wdt:P287",
    "wdt:P31",
    "wdt:P3342",
    "wdt:P452",
#     "wdt:P495", # country of origin
    "wdt:P607",
    "wdt:P61",
    "wdt:P710",
    "wdt:P749",
    "wdt:P793",
    "sdo:birthPlace",
    "sdo:deathPlace",
]

query = f"""
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX sdo: <https://schema.org/>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX smgp: <https://collection.sciencemuseumgroup.org.uk/people/>
PREFIX smgo: <https://collection.sciencemuseumgroup.org.uk/objects/>
PREFIX smgd: <https://collection.sciencemuseumgroup.org.uk/documents/>
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
PREFIX hc: <http://www.heritageconnector.org/RDF/>
CONSTRUCT {{ ?s ?p ?o }}
WHERE {{ ?s ?p ?o. FILTER (?p in ({", ".join(properties)})). }}
"""
print(query)

subg = rg.query(query)
# Out:
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
# PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
# PREFIX sdo: <https://schema.org/>
# PREFIX foaf: <http://xmlns.com/foaf/0.1/>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX smgp: <https://collection.sciencemuseumgroup.org.uk/people/>
# PREFIX smgo: <https://collection.sciencemuseumgroup.org.uk/objects/>
# PREFIX smgd: <https://collection.sciencemuseumgroup.org.uk/documents/>
# PREFIX wd: <http://www.wikidata.org/entity/>
# PREFIX wdt: <http://www.wikidata.org/prop/direct/>
# PREFIX hc: <http://www.heritageconnector.org/RDF/>
# CONSTRUCT { ?s ?p ?o }
# WHERE { ?s ?p ?o. FILTER (?p in (hc:entityPERSON, hc:entityORG, hc:entityNORP, hc:entityFAC, hc:entityLOC, hc:entityOBJECT, hc:entityLANGUAGE, hc:entityDATE, sdo:birthDate, sdo:deathDate, sdo:foundingDate, sdo:dissolutionDate, foaf:maker, foaf:made, sdo:mentions, owl:sameAs, skos:related, skos:relatedMatch, wdt:P1056, wdt:P127, wdt:P135, wdt:P136, wdt:P137, wdt:P1535, wdt:P176, wdt:P18, wdt:P180, wdt:P20, wdt:P27, wdt:P279, wdt:P287, wdt:P31, wdt:P3342, wdt:P452, wdt:P607, wdt:P61, wdt:P710, wdt:P749, wdt:P793, sdo:birthPlace, sdo:deathPlace)). }

# %%
# Conversion of rdflib.Graph to networkx.Graph
if 'subg' in locals():
  print("Using subgraph generated in last cell")
  G = rdflib_to_networkx_graph(subg)
else:
  print("Using entire rdf graph")
  G = rdflib_to_networkx_graph(rg)
print("networkx Graph loaded successfully with length {}".format(len(G)))
# Out:
# Using subgraph generated in last cell
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-f3f78f0629d5> in <module>
#       2 if 'subg' in locals():
#       3   print("Using subgraph generated in last cell")
# ----> 4   G = rdflib_to_networkx_graph(subg)
#       5 else:
#       6   print("Using entire rdf graph")
#
# ~/.pyenv/versions/3.9.1/envs/hc/lib/python3.9/site-packages/rdflib/extras/external_graph_libs.py in rdflib_to_networkx_graph(graph, calc_weights, edge_attrs, **kwds)
#     238     import networkx as nx
#     239     g = nx.Graph()
# --> 240     _rdflib_to_networkx_graph(graph, g, calc_weights, edge_attrs, **kwds)
#     241     return g
#     242
#
# ~/.pyenv/versions/3.9.1/envs/hc/lib/python3.9/site-packages/rdflib/extras/external_graph_libs.py in _rdflib_to_networkx_graph(graph, nxgraph, calc_weights, edge_attrs, transform_s, transform_o)
#      51     assert callable(transform_o)
#      52     import networkx as nx
# ---> 53     for s, p, o in graph:
#      54         ts, to = transform_s(s), transform_o(o)  # apply possible transformations
#      55         data = nxgraph.get_edge_data(ts, to)
#
# ~/.pyenv/versions/3.9.1/envs/hc/lib/python3.9/site-packages/rdflib/query.py in __iter__(self)
#     267     def __iter__(self):
#     268         if self.type in ("CONSTRUCT", "DESCRIBE"):
# --> 269             for t in self.graph:
#     270                 yield t
#     271         elif self.type == 'ASK':
#
# ~/.pyenv/versions/3.9.1/envs/hc/lib/python3.9/site-packages/rdflib/graph.py in triples(self, triple)
#     419                 yield _s, p, _o
#     420         else:
# --> 421             for (s, p, o), cg in self.__store.triples((s, p, o), context=self):
#     422                 yield s, p, o
#     423
#
# ~/.pyenv/versions/3.9.1/envs/hc/lib/python3.9/site-packages/rdflib/plugins/memory.py in __all_triples(self, cid)
#     489             return
#     490         for enctriple in self.__contextTriples[cid].copy():
# --> 491             yield self.__decodeTriple(enctriple), self.__contexts(enctriple)
#     492
#     493     def __contexts(self, enctriple):
#
# ~/.pyenv/versions/3.9.1/envs/hc/lib/python3.9/site-packages/rdflib/plugins/memory.py in __contexts(self, enctriple)
#     494         """return a generator for all the non-quoted contexts
#     495            (unencoded) the encoded triple appears in"""
# --> 496         return (self.__int2obj.get(cid) for cid in self.__getTripleContexts(enctriple, skipQuoted=True) if cid is not None)
#     497
#     498     def __emptygen(self):
#
# ~/.pyenv/versions/3.9.1/envs/hc/lib/python3.9/site-packages/rdflib/plugins/memory.py in __getTripleContexts(self, enctriple, skipQuoted)
#     444             return ctxs.keys()
#     445
# --> 446         return [cid for cid, quoted in ctxs.items() if not quoted]
#     447
#     448     def __tripleHasContext(self, enctriple, cid):
#
# KeyboardInterrupt:

# %% [markdown]
# ## Shortest path

# %%
# Joy Division to Daphne Oram
ent_a, ent_b = URIRef("http://www.wikidata.org/entity/Q172763"), URIRef("https://collection.sciencemuseumgroup.org.uk/people/cp127589")

# Tim Burton to 'Vampire' aircraft
# ent_a, ent_b = URIRef("http://www.wikidata.org/entity/Q56008"), URIRef("https://collection.sciencemuseumgroup.org.uk/objects/co8223281")

# %%
all_sps = all_shortest_paths(G, ent_a, ent_b)
path_graphs = [nx.path_graph(sp) for sp in all_sps]

# %%
for idx, p in enumerate(path_graphs):
    print(f"Path {idx+1}")
    for idx, ea in enumerate(p.edges()):
        subj = ea[0]
        edges = [i[1] for i in G.edges[ea[0], ea[1]]['triples']]
        obj = ea[1]
        
        ent_labels = get_labels([e for e in ea if e.startswith("http")])

        if idx +1 < len(p.edges()):
            print(f"- {ent_labels.get(str(subj)) or subj} -> {edges[0]}")
        else:
            print(f"- {ent_labels.get(str(subj)) or subj} -> {edges[0]}")
            print(f"- {ent_labels.get(str(obj)) or obj}")
# Out:
# Path 1
# - Joy Division -> http://www.wikidata.org/prop/direct/P31
# - http://www.wikidata.org/entity/Q215380 -> http://www.wikidata.org/prop/direct/P31
# - Kraftwerk -> http://www.heritageconnector.org/RDF/entityORG
# - Kraftwerk Uncovered -> http://www.heritageconnector.org/RDF/entityPERSON
# - Daphne Oram
# Path 2
# - Joy Division -> http://www.wikidata.org/prop/direct/P31
# - http://www.wikidata.org/entity/Q215380 -> http://www.wikidata.org/prop/direct/P31
# - Icebreaker -> http://www.heritageconnector.org/RDF/entityORG
# - Kraftwerk Uncovered -> http://www.heritageconnector.org/RDF/entityPERSON
# - Daphne Oram
# Path 3
# - Joy Division -> http://www.wikidata.org/prop/direct/P31
# - http://www.wikidata.org/entity/Q215380 -> http://www.wikidata.org/prop/direct/P31
# - Boomkat -> http://www.heritageconnector.org/RDF/entityORG
# - Oramics To Electronica Phase Two -> http://www.heritageconnector.org/RDF/entityPERSON
# - Daphne Oram
# Path 4
# - Joy Division -> http://www.wikidata.org/prop/direct/P136
# - http://www.wikidata.org/entity/Q485395 -> http://www.wikidata.org/prop/direct/P136
# - The Horrors -> http://www.heritageconnector.org/RDF/entityORG
# - Oramics To Electronica Phase Two -> http://www.heritageconnector.org/RDF/entityPERSON
# - Daphne Oram
# Path 5
# - Joy Division -> http://www.wikidata.org/prop/direct/P136
# - http://www.wikidata.org/entity/Q3071 -> http://www.wikidata.org/prop/direct/P136
# - The Horrors -> http://www.heritageconnector.org/RDF/entityORG
# - Oramics To Electronica Phase Two -> http://www.heritageconnector.org/RDF/entityPERSON
# - Daphne Oram
# Path 6
# - Joy Division -> http://www.heritageconnector.org/RDF/entityORG
# - Joy Division - Peel Sessions -> http://www.heritageconnector.org/RDF/entityORG
# - BBC -> http://www.heritageconnector.org/RDF/entityORG
# - Oramics To Electronica Phase Two -> http://www.heritageconnector.org/RDF/entityPERSON
# - Daphne Oram
# Path 7
# - Joy Division -> http://www.wikidata.org/prop/direct/P31
# - http://www.wikidata.org/entity/Q215380 -> http://www.wikidata.org/prop/direct/P31
# - Boomkat -> http://www.heritageconnector.org/RDF/entityORG
# - Results From The OraMIX Competition -> http://www.heritageconnector.org/RDF/entityPERSON
# - Daphne Oram
# Path 8
# - Joy Division -> http://www.wikidata.org/prop/direct/P31
# - http://www.wikidata.org/entity/Q215380 -> http://www.wikidata.org/prop/direct/P31
# - The Beatles -> http://www.heritageconnector.org/RDF/entityORG
# - The Radiophonic Workshop at the Science Museum -> http://www.heritageconnector.org/RDF/entityPERSON
# - Daphne Oram
# Path 9
# - Joy Division -> http://www.heritageconnector.org/RDF/entityORG
# - Joy Division - Peel Sessions -> http://www.heritageconnector.org/RDF/entityORG
# - BBC -> http://www.heritageconnector.org/RDF/entityORG
# - The Radiophonic Workshop at the Science Museum -> http://www.heritageconnector.org/RDF/entityPERSON
# - Daphne Oram
# Path 10
# - Joy Division -> http://www.wikidata.org/prop/direct/P31
# - http://www.wikidata.org/entity/Q215380 -> http://www.wikidata.org/prop/direct/P31
# - Coldcut -> http://www.heritageconnector.org/RDF/entityPERSON
# - The Closure Of The BBC Radiophonic Workshop -> http://www.heritageconnector.org/RDF/entityPERSON
# - Daphne Oram
# Path 11
# - Joy Division -> http://www.heritageconnector.org/RDF/entityORG
# - Joy Division - Peel Sessions -> http://www.heritageconnector.org/RDF/entityORG
# - BBC -> http://www.heritageconnector.org/RDF/entityORG
# - The Closure Of The BBC Radiophonic Workshop -> http://www.heritageconnector.org/RDF/entityPERSON
# - Daphne Oram
# Path 12
# - Joy Division -> http://www.wikidata.org/prop/direct/P31
# - http://www.wikidata.org/entity/Q215380 -> http://www.wikidata.org/prop/direct/P31
# - Ottawan -> http://www.heritageconnector.org/RDF/entityORG
# - Make Your Own Tape Loop -> http://www.heritageconnector.org/RDF/entityPERSON
# - Daphne Oram
# Path 13
# - Joy Division -> http://www.heritageconnector.org/RDF/entityPERSON
# - FACT 10 Unknown Pleasures -> http://www.heritageconnector.org/RDF/entityDATE
# - 1977 -> http://www.heritageconnector.org/RDF/entityDATE
# - Make Your Own Tape Loop -> http://www.heritageconnector.org/RDF/entityPERSON
# - Daphne Oram
# Path 14
# - Joy Division -> http://www.heritageconnector.org/RDF/entityORG
# - The Ideal Beginning -> http://www.heritageconnector.org/RDF/entityDATE
# - 1977 -> http://www.heritageconnector.org/RDF/entityDATE
# - Make Your Own Tape Loop -> http://www.heritageconnector.org/RDF/entityPERSON
# - Daphne Oram
# Path 15
# - Joy Division -> http://www.wikidata.org/prop/direct/P136
# - http://www.wikidata.org/entity/Q598929 -> http://www.wikidata.org/prop/direct/P136
# - Mark E. Smith -> http://www.heritageconnector.org/RDF/entityPERSON
# - Make Your Own Tape Loop -> http://www.heritageconnector.org/RDF/entityPERSON
# - Daphne Oram
# Path 16
# - Joy Division -> http://www.heritageconnector.org/RDF/entityORG
# - Sounds magazine article -> http://www.heritageconnector.org/RDF/entityLOC
# - London -> http://www.heritageconnector.org/RDF/entityLOC
# - Electronic Musicians Wanted -> http://www.heritageconnector.org/RDF/entityPERSON
# - Daphne Oram
# Path 17
# - Joy Division -> http://www.heritageconnector.org/RDF/entityORG
# - Joy Division live at the Moonlight Club -> http://www.heritageconnector.org/RDF/entityLOC
# - London -> http://www.heritageconnector.org/RDF/entityLOC
# - Electronic Musicians Wanted -> http://www.heritageconnector.org/RDF/entityPERSON
# - Daphne Oram
# Path 18
# - Joy Division -> http://www.heritageconnector.org/RDF/entityPERSON
# - CD copy recording labelled YMCA -> http://www.heritageconnector.org/RDF/entityLOC
# - London -> http://www.heritageconnector.org/RDF/entityLOC
# - Electronic Musicians Wanted -> http://www.heritageconnector.org/RDF/entityPERSON
# - Daphne Oram
# Path 19
# - Joy Division -> http://www.heritageconnector.org/RDF/entityORG
# - Robert Leo Gretton -> http://www.heritageconnector.org/RDF/entityLOC
# - London -> http://www.heritageconnector.org/RDF/entityLOC
# - Electronic Musicians Wanted -> http://www.heritageconnector.org/RDF/entityPERSON
# - Daphne Oram
# Path 20
# - Joy Division -> http://www.heritageconnector.org/RDF/entityORG
# - CD copy recording -> http://www.heritageconnector.org/RDF/entityLOC
# - London -> http://www.heritageconnector.org/RDF/entityLOC
# - Electronic Musicians Wanted -> http://www.heritageconnector.org/RDF/entityPERSON
# - Daphne Oram
# Path 21
# - Joy Division -> http://www.heritageconnector.org/RDF/entityORG
# - CD copy recording -> http://www.heritageconnector.org/RDF/entityLOC
# - London -> http://www.heritageconnector.org/RDF/entityLOC
# - Electronic Musicians Wanted -> http://www.heritageconnector.org/RDF/entityPERSON
# - Daphne Oram
# Path 22
# - Joy Division -> http://www.heritageconnector.org/RDF/entityORG
# - Joy Division - Komackino -> http://www.heritageconnector.org/RDF/entityLOC
# - London -> http://www.heritageconnector.org/RDF/entityLOC
# - Electronic Musicians Wanted -> http://www.heritageconnector.org/RDF/entityPERSON
# - Daphne Oram
# Path 23
# - Joy Division -> http://www.heritageconnector.org/RDF/entityORG
# - Joy Division - Out of the Room: Cover Versions, Jam Sessions, Soundchecks -> http://www.heritageconnector.org/RDF/entityLOC
# - London -> http://www.heritageconnector.org/RDF/entityLOC
# - Electronic Musicians Wanted -> http://www.heritageconnector.org/RDF/entityPERSON
# - Daphne Oram
# Path 24
# - Joy Division -> http://www.heritageconnector.org/RDF/entityORG
# - Sounds magazine article -> http://www.heritageconnector.org/RDF/entityORG
# - Page -> http://www.heritageconnector.org/RDF/entityORG
# - Oramics To Electronica -> http://www.heritageconnector.org/RDF/entityPERSON
# - Daphne Oram
# Path 25
# - Joy Division -> http://www.heritageconnector.org/RDF/entityORG
# - Sounds magazine article -> http://www.heritageconnector.org/RDF/entityORG
# - Page -> http://www.heritageconnector.org/RDF/entityORG
# - Oramics To Electronica -> http://www.heritageconnector.org/RDF/entityPERSON
# - Daphne Oram
# Path 26
# - Joy Division -> http://www.heritageconnector.org/RDF/entityORG
# - Sounds magazine article -> http://www.heritageconnector.org/RDF/entityORG
# - Page -> http://www.heritageconnector.org/RDF/entityORG
# - Oramics To Electronica -> http://www.heritageconnector.org/RDF/entityPERSON
# - Daphne Oram
# Path 27
# - Joy Division -> http://www.heritageconnector.org/RDF/entityORG
# - Sounds magazine article -> http://www.heritageconnector.org/RDF/entityORG
# - Page -> http://www.heritageconnector.org/RDF/entityORG
# - Oramics To Electronica -> http://www.heritageconnector.org/RDF/entityPERSON
# - Daphne Oram
# Path 28
# - Joy Division -> http://www.heritageconnector.org/RDF/entityORG
# - Sounds magazine article -> http://www.heritageconnector.org/RDF/entityORG
# - Page -> http://www.heritageconnector.org/RDF/entityORG
# - Oramics To Electronica -> http://www.heritageconnector.org/RDF/entityPERSON
# - Daphne Oram
# Path 29
# - Joy Division -> http://www.heritageconnector.org/RDF/entityORG
# - Sounds magazine article -> http://www.heritageconnector.org/RDF/entityORG
# - Page -> http://www.heritageconnector.org/RDF/entityORG
# - Oramics To Electronica -> http://www.heritageconnector.org/RDF/entityPERSON
# - Daphne Oram
# Path 30
# - Joy Division -> http://www.heritageconnector.org/RDF/entityPERSON
# - Sounds magazine article -> http://www.heritageconnector.org/RDF/entityORG
# - Page -> http://www.heritageconnector.org/RDF/entityORG
# - Oramics To Electronica -> http://www.heritageconnector.org/RDF/entityPERSON
# - Daphne Oram
# Path 31
# - Joy Division -> http://www.heritageconnector.org/RDF/entityORG
# - She's Lost Control -> http://www.heritageconnector.org/RDF/entityDATE
# - 2007 -> http://www.heritageconnector.org/RDF/entityDATE
# - Oramics to electronica: investigating lay understandings of the history of technology through a participatory project -> http://www.heritageconnector.org/RDF/entityPERSON
# - Daphne Oram
